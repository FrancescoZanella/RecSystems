# %% [markdown]
# # XGBoost

# %% [markdown]
# ### Importing github repository

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
token = user_secrets.get_secret("token")

# %% [markdown]
# ## Compiling cython

# %%
# !git clone https://FrancescoZanella:{token}@github.com/FrancescoZanella/RecSys.git
# %cd RecSys
# Out:
# Cloning into 'RecSys'...
# remote: Enumerating objects: 1876, done.
# remote: Counting objects: 100% (198/198), done.
# remote: Compressing objects: 100% (164/164), done.
# remote: Total 1876 (delta 113), reused 79 (delta 31), pack-reused 1678
# Receiving objects: 100% (1876/1876), 22.31 MiB | 20.20 MiB/s, done.
# Resolving deltas: 100% (1010/1010), done.
# /kaggle/working/RecSys

# %%
import sys
sys.path.append("/kaggle/working/RecSys")

# %%
# !pip install Cython==0.29.23
# !pip install nltk==3.6.1
# !pip install nose==1.3.7
# !pip install numpy>=1.19
! python run_compile_all_cython.py
# Out:
# Collecting Cython==0.29.23
#   Downloading Cython-0.29.23-py2.py3-none-any.whl (978 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.0/978.0 kB 11.1 MB/s eta 0:00:00
# Installing collected packages: Cython
#   Attempting uninstall: Cython
#     Found existing installation: Cython 3.0.0
#     Uninstalling Cython-3.0.0:
#       Successfully uninstalled Cython-3.0.0
# Successfully installed Cython-0.29.23
# Collecting nltk==3.6.1
#   Downloading nltk-3.6.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk==3.6.1) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk==3.6.1) (1.3.2)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from nltk==3.6.1) (2023.8.8)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk==3.6.1) (4.66.1)
# Installing collected packages: nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.2.4
#     Uninstalling nltk-3.2.4:
#       Successfully uninstalled nltk-3.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.6.1 which is incompatible.
# Successfully installed nltk-3.6.1
# Requirement already satisfied: nose==1.3.7 in /opt/conda/lib/python3.10/site-packages (1.3.7)
# run_compile_all_cython: Found 10 Cython files in 4 folders...
# run_compile_all_cython: All files will be compiled using your current python environment: '/opt/conda/bin/python'
# Compiling [1/10]: MatrixFactorizationImpressions_Cython_Epoch.pyx...
# In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1940,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from MatrixFactorizationImpressions_Cython_Epoch.c:612:
# /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# MatrixFactorizationImpressions_Cython_Epoch.c: In function '__pyx_f_43MatrixFactorizationImpressions_Cython_Epoch_32MatrixFactorization_Cython_Epoch_sampleBPR_Cython':
# MatrixFactorizationImpressions_Cython_Epoch.c:12585:17: warning: '__pyx_v_start_pos_impression_items' may be used uninitialized in this function [-Wmaybe-uninitialized]
# 12585 |       __pyx_t_4 = (__pyx_v_start_pos_impression_items + __pyx_v_index);
#       |       ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# MatrixFactorizationImpressions_Cython_Epoch.c: In function '__pyx_pf_43MatrixFactorizationImpressions_Cython_Epoch_32MatrixFactorization_Cython_Epoch_10epochIteration_Cython_ASY_SVD_SGD':
# MatrixFactorizationImpressions_Cython_Epoch.c:8589:7: warning: '__pyx_v_end_pos_seen_items' may be used uninitialized in this function [-Wmaybe-uninitialized]
#  8589 |       for (__pyx_t_19 = __pyx_v_start_pos_seen_items; __pyx_t_19 < __pyx_t_18; __pyx_t_19+=1) {
#       |       ^~~
# MatrixFactorizationImpressions_Cython_Epoch.c:8589:7: warning: '__pyx_v_start_pos_seen_items' may be used uninitialized in this function [-Wmaybe-uninitialized]
# /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/RecSys/Recommenders/MatrixFactorization/Cython/MatrixFactorizationImpressions_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [1/10]: MatrixFactorizationImpressions_Cython_Epoch.pyx... PASS
#
# Compiling [2/10]: MatrixFactorization_Cython_Epoch.pyx...
# In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1940,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from MatrixFactorization_Cython_Epoch.c:612:
# /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# MatrixFactorization_Cython_Epoch.c: In function '__pyx_pf_32MatrixFactorization_Cython_Epoch_32MatrixFactorization_Cython_Epoch_10epochIteration_Cython_ASY_SVD_SGD':
# MatrixFactorization_Cython_Epoch.c:8638:9: warning: '__pyx_v_end_pos_seen_items' may be used uninitialized in this function [-Wmaybe-uninitialized]
#  8638 |         for (__pyx_t_19 = __pyx_v_start_pos_seen_items; __pyx_t_19 < __pyx_t_18; __pyx_t_19+=1) {
#       |         ^~~
# MatrixFactorization_Cython_Epoch.c:8638:9: warning: '__pyx_v_start_pos_seen_items' may be used uninitialized in this function [-Wmaybe-uninitialized]
# /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/RecSys/Recommenders/MatrixFactorization/Cython/MatrixFactorization_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [2/10]: MatrixFactorization_Cython_Epoch.pyx... PASS
#
# Compiling [3/10]: Compute_Similarity_Cython.pyx...
# In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1940,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from Compute_Similarity_Cython.c:612:
# /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/RecSys/Recommenders/Similarity/Cython/Compute_Similarity_Cython.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [3/10]: Compute_Similarity_Cython.pyx... PASS
#
# Compiling [4/10]: SLIM_BPR_Cython_Epoch.pyx...
# warning: SLIM_BPR_Cython_Epoch.pyx:632:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:632:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:817:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:817:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:916:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:916:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:916:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1051:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1051:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1940,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from SLIM_BPR_Cython_Epoch.c:612:
# /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# SLIM_BPR_Cython_Epoch.c: In function '__pyx_f_21SLIM_BPR_Cython_Epoch_22Sparse_Matrix_Tree_CSR_test_list_tee_conversion':
# SLIM_BPR_Cython_Epoch.c:10703:15: warning: '__pyx_v_previous_element' may be used uninitialized in this function [-Wmaybe-uninitialized]
# 10703 |     __pyx_t_7 = __pyx_v_current_element->lower;
#       |     ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/RecSys/Recommenders/SLIM/Cython/SLIM_BPR_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: SLIM_BPR_Cython_Epoch.pyx:632:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:632:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:817:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:817:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:916:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:916:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:916:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1051:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1051:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# Compiling [4/10]: SLIM_BPR_Cython_Epoch.pyx... PASS
#
# Compiling [5/10]: Triangular_Matrix.pyx...
# In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1940,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from Triangular_Matrix.c:612:
# /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/RecSys/Recommenders/SLIM/Cython/Triangular_Matrix.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [5/10]: Triangular_Matrix.pyx... PASS
#
# Compiling [6/10]: Sparse_Matrix_Tree_CSR.pyx...
# warning: Sparse_Matrix_Tree_CSR.pyx:132:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:132:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1940,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from Sparse_Matrix_Tree_CSR.c:612:
# /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# Sparse_Matrix_Tree_CSR.c: In function '__pyx_f_22Sparse_Matrix_Tree_CSR_22Sparse_Matrix_Tree_CSR_test_list_tree_conversion':
# Sparse_Matrix_Tree_CSR.c:5701:15: warning: '__pyx_v_previous_element' may be used uninitialized in this function [-Wmaybe-uninitialized]
#  5701 |     __pyx_t_7 = __pyx_v_current_element->lower;
#       |     ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/RecSys/Recommenders/SLIM/Cython/Sparse_Matrix_Tree_CSR.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: Sparse_Matrix_Tree_CSR.pyx:132:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:132:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# Compiling [6/10]: Sparse_Matrix_Tree_CSR.pyx... PASS
#
# Compiling [7/10]: HP3_Similarity_Cython_SGD.pyx...
# warning: HP3_Similarity_Cython_SGD.pyx:113:40: Index should be typed for more efficient access
# In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1940,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from HP3_Similarity_Cython_SGD.c:612:
# /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# HP3_Similarity_Cython_SGD.c: In function '__pyx_pf_25HP3_Similarity_Cython_SGD_25HP3_Similarity_Cython_SGD_4fit':
# HP3_Similarity_Cython_SGD.c:6144:55: warning: '__pyx_v_sample_num' may be used uninitialized in this function [-Wmaybe-uninitialized]
#  6144 |   __pyx_t_1 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_sample_num))); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 291, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/RecSys/Recommenders/FeatureWeighting/Cython/HP3_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: HP3_Similarity_Cython_SGD.pyx:113:40: Index should be typed for more efficient access
# Compiling [7/10]: HP3_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [8/10]: CFW_D_Similarity_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1940,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from CFW_D_Similarity_Cython_SGD.c:612:
# /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# CFW_D_Similarity_Cython_SGD.c: In function '__pyx_pf_27CFW_D_Similarity_Cython_SGD_27CFW_D_Similarity_Cython_SGD_6fit':
# CFW_D_Similarity_Cython_SGD.c:5905:55: warning: '__pyx_v_sample_num' may be used uninitialized in this function [-Wmaybe-uninitialized]
#  5905 |   __pyx_t_3 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_sample_num))); if (unlikely(!__pyx_t_3)) __PYX_ERR(0, 290, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/RecSys/Recommenders/FeatureWeighting/Cython/CFW_D_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [8/10]: CFW_D_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [9/10]: FBSM_Rating_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1940,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from FBSM_Rating_Cython_SGD.c:612:
# /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# FBSM_Rating_Cython_SGD.c: In function '__pyx_pf_22FBSM_Rating_Cython_SGD_22FBSM_Rating_Cython_SGD_2fit':
# FBSM_Rating_Cython_SGD.c:8880:55: warning: '__pyx_v_num_sample' may be used uninitialized in this function [-Wmaybe-uninitialized]
#  8880 |   __pyx_t_5 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_num_sample))); if (unlikely(!__pyx_t_5)) __PYX_ERR(0, 551, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/RecSys/Recommenders/FeatureWeighting/Cython/FBSM_Rating_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [9/10]: FBSM_Rating_Cython_SGD.pyx... PASS
#
# Compiling [10/10]: CFW_DVV_Similarity_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarraytypes.h:1940,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/arrayobject.h:5,
#                  from CFW_DVV_Similarity_Cython_SGD.c:612:
# /opt/conda/lib/python3.10/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/RecSys/Recommenders/FeatureWeighting/Cython/CFW_DVV_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [10/10]: CFW_DVV_Similarity_Cython_SGD.pyx... PASS
#
# run_compile_all_cython: Compilation finished. SUCCESS.
# Compilation log can be found here: './result_experiments/run_compile_all_cython.txt'

# %% [markdown]
# ## Importing libraries

# %%
import scipy.sparse as sps
import pandas as pd
import numpy as np
import os
import matplotlib.pyplot as pyplot
import csv
from datetime import datetime
import time
from tqdm import tqdm
import xgboost as xgb
from xgboost import XGBRanker
from xgboost import plot_importance

# %%
from Utils.seconds_to_biggest_unit import *
from Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample
from Recommenders.GraphBased.RP3betaRecommender import RP3betaRecommender
from Recommenders.SLIM.SLIMElasticNetRecommender import SLIMElasticNetRecommender
from Recommenders.KNN.ItemKNNCFRecommender import ItemKNNCFRecommender
from Recommenders.KNN.ItemKNNCustomSimilarityRecommender import ItemKNNCustomSimilarityRecommender
from Recommenders.GraphBased.P3alphaRecommender import P3alphaRecommender
from Recommenders.EASE_R.EASE_R_Recommender import EASE_R_Recommender
from Recommenders.SLIM.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython
from Recommenders.NonPersonalizedRecommender import TopPop
from Recommenders.MatrixFactorization.IALSRecommender import IALSRecommender
from Recommenders.SLIM.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython

from MyTuning.Recall.best_pars_recall import *
from MyTuning.best_pars import *

# %% [markdown]
# ## Importing URM

# %%
# open the dataset
path = "/kaggle/working/RecSys/recsys1/data_train.csv"
path_target = "/kaggle/working/RecSys/recsys1/data_target_users_test.csv"

file = open(path, 'r')



file1 = open(path_target, 'r')

# load the dataset removing the header
df = pd.read_csv(filepath_or_buffer=path,
                 header=0,
                 dtype={0:int, 1:int, 2:int},     
                 sep=",",
                 engine='python')

df_users = pd.read_csv(
    filepath_or_buffer = path_target,
    header=0,
    dtype={0: int},
    sep=",",
    engine="python"   , 
)


df_users.columns = ["UserID"]



# rename the columns
df.columns = ["UserID", "ItemID", "Interaction"]



mapped_id, original_id = pd.factorize(df["ItemID"].unique())
item_original_ID_to_index = pd.Series(mapped_id, index=original_id)



mapped_id, original_id = pd.factorize(df["UserID"].unique())
user_original_ID_to_index = pd.Series(mapped_id, index=original_id)


df["UserID"] = df["UserID"].map(user_original_ID_to_index)
df["ItemID"] = df["ItemID"].map(item_original_ID_to_index)


URM_all = sps.coo_matrix((df["Interaction"].values, 
                          (df["UserID"].values, df["ItemID"].values)))

# %%
URM_all
# Out:
# <12638x22222 sparse matrix of type '<class 'numpy.int64'>'
# 	with 478730 stored elements in COOrdinate format>

# %% [markdown]
# ## Creating the splits

# %%
URM_train, URM_test = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.85)
# Out:
# Warning: 166 (1.31 %) of 12638 users have no train items
# Warning: 2691 (21.29 %) of 12638 users have no sampled items

# %%
def create_dataframe_with_label(URM_features,URM_label,other_algorithms,cutoff):
    n_users_features, n_items_features = URM_features.shape
    training_dataframe = pd.DataFrame(index=range(0,n_users_features), columns = ["ItemID"])
    training_dataframe.index.name='UserID'
    #print(training_dataframe.columns)

    for user_id in tqdm(range(n_users_features)):    
        recommendations = other_algorithms["candidate_generator"].recommend(user_id, cutoff = cutoff)
        training_dataframe.loc[user_id, "ItemID"] = recommendations
        
    #print(training_dataframe.columns)
    training_dataframe = training_dataframe.explode("ItemID")

    URM_label_coo = sps.coo_matrix(URM_label)

    correct_recommendations = pd.DataFrame({"UserID": URM_label_coo.row,
                                        "ItemID": URM_label_coo.col})

    training_dataframe = pd.merge(training_dataframe, correct_recommendations, on=['UserID','ItemID'], how='left', indicator='Exist')
    training_dataframe["Label"] = training_dataframe["Exist"] == "both"
    training_dataframe.drop(columns = ['Exist'], inplace=True)
    
    training_dataframe = training_dataframe.set_index('UserID')

    for user_id in tqdm(range(n_users_features)):  
        for rec_label, rec_instance in other_algorithms.items():
            if rec_label!= "candidate_generator":
                item_list = training_dataframe.loc[user_id, "ItemID"].values.tolist()
        
                all_item_scores = rec_instance._compute_item_score([user_id], items_to_compute = item_list)

                training_dataframe.loc[user_id, rec_label] = all_item_scores[0, item_list] 

    training_dataframe = training_dataframe.reset_index()
    training_dataframe = training_dataframe.rename(columns = {"index": "UserID"})
    
    item_popularity = np.ediff1d(sps.csc_matrix(URM_features).indptr)

    training_dataframe['item_popularity'] = item_popularity[training_dataframe["ItemID"].values.astype(int)]
    
    user_popularity = np.ediff1d(sps.csr_matrix(URM_features).indptr)

    training_dataframe['user_profile_len'] = user_popularity[training_dataframe["UserID"].values.astype(int)]
    
    training_dataframe = training_dataframe.sort_values("UserID").reset_index()
    training_dataframe.drop(columns = ['index'], inplace=True)
    
    return training_dataframe

# %%
def create_dataframe_without_label(URM_features,other_algorithms,cutoff):
    n_users_features, n_items_features = URM_features.shape
    training_dataframe = pd.DataFrame(index=range(0,n_users_features), columns = ["ItemID"])
    training_dataframe.index.name='UserID'
    #print(training_dataframe.columns)
    #print(training_dataframe)
    
    for user_id in tqdm(range(n_users_features)):    
        recommendations = other_algorithms["candidate_generator"].recommend(user_id, cutoff = cutoff)
        training_dataframe.loc[user_id, "ItemID"] = recommendations
        
    #print(training_dataframe.columns)
    #print(training_dataframe)
    training_dataframe = training_dataframe.explode("ItemID")
    #training_dataframe = training_dataframe.set_index('UserID')

    for user_id in tqdm(range(n_users_features)):  
        for rec_label, rec_instance in other_algorithms.items():
            if rec_label!= "candidate_generator":
                item_list = training_dataframe.loc[user_id, "ItemID"].values.tolist()
        
                all_item_scores = rec_instance._compute_item_score([user_id], items_to_compute = item_list)

                training_dataframe.loc[user_id, rec_label] = all_item_scores[0, item_list] 

    training_dataframe = training_dataframe.reset_index()
    training_dataframe = training_dataframe.rename(columns = {"index": "UserID"})
    
    item_popularity = np.ediff1d(sps.csc_matrix(URM_features).indptr)

    training_dataframe['item_popularity'] = item_popularity[training_dataframe["ItemID"].values.astype(int)]
    
    user_popularity = np.ediff1d(sps.csr_matrix(URM_features).indptr)

    training_dataframe['user_profile_len'] = user_popularity[training_dataframe["UserID"].values.astype(int)]
    
    training_dataframe = training_dataframe.sort_values("UserID").reset_index()
    training_dataframe.drop(columns = ['index'], inplace=True)
    
    return training_dataframe

# %% [markdown]
# ### Creating the hybrid recommender

# %%
def evaluate_algorithm(URM_test, recommender_object, at=10):
    
    cumulative_AP = 0.0
    
    num_eval = 0

    # we look for all the users 
    for user_id in tqdm(range(URM_test.shape[0])):
        
        # we get the relevant items for this user
        relevant_items = URM_test.indices[URM_test.indptr[user_id]:URM_test.indptr[user_id+1]]
        
        # if the user have something in the test data we evaluate it
        if len(relevant_items)>0:
            
            recommended_items = recommender_object.recommend(user_id)
            num_eval+=1

            cumulative_AP += AP(recommended_items, relevant_items)
            
    MAP = cumulative_AP / num_eval
    
    return MAP

def AP(recommended_items, relevant_items):
   
    is_relevant = np.in1d(recommended_items, relevant_items, assume_unique=True)
    
    # Cumulative sum: precision at 1, at 2, at 3 ...
    p_at_k = is_relevant * np.cumsum(is_relevant, dtype=np.float32) / (1 + np.arange(is_relevant.shape[0]))
    
    ap_score = np.sum(p_at_k) / np.min([relevant_items.shape[0], is_relevant.shape[0]])

    return ap_score

# %%
def evaluate_algorithm_xgboost(URM_test,dataframe_to_evaluate,model):
    
    cumulative_AP = 0.0
    
    num_eval = 0

    # we look for all the users 
    for user_id in tqdm(range(URM_test.shape[0])):
        
        # we get the relevant items for this user
        relevant_items = URM_test.indices[URM_test.indptr[user_id]:URM_test.indptr[user_id+1]]
        
        # if the user have something in the test data we evaluate it
        if len(relevant_items)>0:
            
            X_to_predict = dataframe_to_evaluate[dataframe_to_evaluate["UserID"] == user_id].copy()

            preds = model.predict(X_to_predict)
            X_to_predict["rank"] = preds
            X_to_predict = X_to_predict.sort_values(by = "rank", ascending = False)
            recommended_items = np.array(X_to_predict["ItemID"])[:10]
            
            num_eval+=1

            cumulative_AP += AP(recommended_items, relevant_items)
            
    MAP = cumulative_AP / num_eval
    
    return MAP

# %%
SLIM_ElasticRecall = SLIMElasticNetRecommender(URM_train)
SLIM_ElasticRecall.fit(**best_pars_recall_dict["SLIMElasticNetRecommender"]
    
)
# Out:
# SLIMElasticNetRecommender: URM Detected 166 ( 1.3%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 63 ( 0.3%) items with no interactions.
# SLIMElasticNetRecommender: Processed 7705 (34.7%) in 5.00 min. Items per second: 25.68
# SLIMElasticNetRecommender: Processed 16460 (74.1%) in 10.00 min. Items per second: 27.43
# SLIMElasticNetRecommender: Processed 22222 (100.0%) in 13.18 min. Items per second: 28.09

# %%
SLIM_Elastic = SLIMElasticNetRecommender(URM_train)
SLIM_Elastic.fit(**best_pars_dict["SLIMElasticNetRecommender"]
    
)
# Out:
# SLIMElasticNetRecommender: URM Detected 166 ( 1.3%) users with no interactions.
# SLIMElasticNetRecommender: URM Detected 63 ( 0.3%) items with no interactions.
# SLIMElasticNetRecommender: Processed 10353 (46.6%) in 5.00 min. Items per second: 34.51
# SLIMElasticNetRecommender: Processed 22222 (100.0%) in 9.86 min. Items per second: 37.54

# %%
RP3Beta = RP3betaRecommender(URM_train)
RP3Beta.fit(
    **best_pars_dict["RP3betaRecommender"]
)
# Out:
# RP3betaRecommender: URM Detected 166 ( 1.3%) users with no interactions.
# RP3betaRecommender: URM Detected 63 ( 0.3%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 3306.10 column/sec. Elapsed time 6.72 sec

# %%
RP3BetaRecall = RP3betaRecommender(URM_train)
RP3BetaRecall.fit(
    **best_pars_recall_dict["RP3betaRecommender"]
)
# Out:
# RP3betaRecommender: URM Detected 166 ( 1.3%) users with no interactions.
# RP3betaRecommender: URM Detected 63 ( 0.3%) items with no interactions.
# RP3betaRecommender: Similarity column 22222 (100.0%), 1393.48 column/sec. Elapsed time 15.95 sec

# %%
topPop = TopPop(URM_train)
topPop.fit()
# Out:
# TopPopRecommender: URM Detected 166 ( 1.3%) users with no interactions.
# TopPopRecommender: URM Detected 63 ( 0.3%) items with no interactions.

# %%
item_knn = ItemKNNCFRecommender(URM_train)
item_knn.fit(**best_pars_dict["ItemKNNCFRecommender"])
# Out:
# ItemKNNCFRecommender: URM Detected 166 ( 1.3%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 63 ( 0.3%) items with no interactions.
# Similarity column 22222 (100.0%), 4523.27 column/sec. Elapsed time 4.91 sec

# %%
item_knnRecall = ItemKNNCFRecommender(URM_train)
item_knnRecall.fit(**best_pars_recall_dict["ItemKNNCFRecommender"])
# Out:
# ItemKNNCFRecommender: URM Detected 166 ( 1.3%) users with no interactions.
# ItemKNNCFRecommender: URM Detected 63 ( 0.3%) items with no interactions.
# Similarity column 22222 (100.0%), 4372.16 column/sec. Elapsed time 5.08 sec

# %%
ease_r = EASE_R_Recommender(URM_train)
ease_r.fit(**best_pars_dict["EASE_R_Recommender"])
# Out:
# EASE_R_Recommender: URM Detected 166 ( 1.3%) users with no interactions.
# EASE_R_Recommender: URM Detected 63 ( 0.3%) items with no interactions.
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 7.00 min

# %%
new_similarity = 0.6 * SLIM_Elastic.W_sparse + 0.2 * RP3Beta.W_sparse + 0.2 * item_knn.W_sparse
best_hybrid = ItemKNNCustomSimilarityRecommender(URM_train)
best_hybrid.fit(new_similarity)
# Out:
# ItemKNNCustomSimilarityRecommender: URM Detected 166 ( 1.3%) users with no interactions.
# ItemKNNCustomSimilarityRecommender: URM Detected 63 ( 0.3%) items with no interactions.

# %%
SLIM_bpr=SLIM_BPR_Cython(URM_train)
SLIM_bpr.fit(**best_pars_dict["SLIM_BPR_Cython"])
# Out:
# SLIM_BPR_Recommender: URM Detected 166 ( 1.3%) users with no interactions.
# SLIM_BPR_Recommender: URM Detected 63 ( 0.3%) items with no interactions.
# SLIM_BPR_Recommender: Automatic selection of fastest train mode. Available RAM is 28782.00 MB (89.64%) of 32110.00 MB, required is 1975.27 MB. Using dense matrix.
# Processed 12638 (100.0%) in 0.85 sec. BPR loss is 4.64E-03. Sample per second: 14831
# SLIM_BPR_Recommender: Epoch 1 of 445. Elapsed time 0.06 sec
# Processed 12638 (100.0%) in 0.91 sec. BPR loss is 1.09E-02. Sample per second: 13822
# SLIM_BPR_Recommender: Epoch 2 of 445. Elapsed time 0.12 sec
# Processed 12638 (100.0%) in 0.98 sec. BPR loss is 2.04E-02. Sample per second: 12929
# SLIM_BPR_Recommender: Epoch 3 of 445. Elapsed time 0.19 sec
# Processed 12638 (100.0%) in 1.04 sec. BPR loss is 2.43E-02. Sample per second: 12197
# SLIM_BPR_Recommender: Epoch 4 of 445. Elapsed time 0.25 sec
# Processed 12638 (100.0%) in 0.10 sec. BPR loss is 3.27E-02. Sample per second: 128999
# SLIM_BPR_Recommender: Epoch 5 of 445. Elapsed time 0.31 sec
# Processed 12638 (100.0%) in 0.16 sec. BPR loss is 4.12E-02. Sample per second: 79739
# SLIM_BPR_Recommender: Epoch 6 of 445. Elapsed time 0.37 sec
# Processed 12638 (100.0%) in 0.22 sec. BPR loss is 4.74E-02. Sample per second: 57241
# SLIM_BPR_Recommender: Epoch 7 of 445. Elapsed time 0.43 sec
# Processed 12638 (100.0%) in 0.28 sec. BPR loss is 5.40E-02. Sample per second: 45291
# SLIM_BPR_Recommender: Epoch 8 of 445. Elapsed time 0.49 sec
# Processed 12638 (100.0%) in 0.34 sec. BPR loss is 6.44E-02. Sample per second: 37284
# SLIM_BPR_Recommender: Epoch 9 of 445. Elapsed time 0.55 sec
# Processed 12638 (100.0%) in 0.40 sec. BPR loss is 6.80E-02. Sample per second: 31755
# SLIM_BPR_Recommender: Epoch 10 of 445. Elapsed time 0.61 sec
# Processed 12638 (100.0%) in 0.46 sec. BPR loss is 7.59E-02. Sample per second: 27676
# SLIM_BPR_Recommender: Epoch 11 of 445. Elapsed time 0.67 sec
# Processed 12638 (100.0%) in 0.52 sec. BPR loss is 8.22E-02. Sample per second: 24429
# SLIM_BPR_Recommender: Epoch 12 of 445. Elapsed time 0.73 sec
# Processed 12638 (100.0%) in 0.58 sec. BPR loss is 8.54E-02. Sample per second: 21883
# SLIM_BPR_Recommender: Epoch 13 of 445. Elapsed time 0.79 sec
# Processed 12638 (100.0%) in 0.64 sec. BPR loss is 9.26E-02. Sample per second: 19719
# SLIM_BPR_Recommender: Epoch 14 of 445. Elapsed time 0.85 sec
# Processed 12638 (100.0%) in 0.71 sec. BPR loss is 1.07E-01. Sample per second: 17811
# SLIM_BPR_Recommender: Epoch 15 of 445. Elapsed time 0.92 sec
# Processed 12638 (100.0%) in 0.78 sec. BPR loss is 1.06E-01. Sample per second: 16219
# SLIM_BPR_Recommender: Epoch 16 of 445. Elapsed time 0.99 sec
# Processed 12638 (100.0%) in 0.84 sec. BPR loss is 1.04E-01. Sample per second: 14957
# SLIM_BPR_Recommender: Epoch 17 of 445. Elapsed time 1.05 sec
# Processed 12638 (100.0%) in 0.91 sec. BPR loss is 1.08E-01. Sample per second: 13831
# SLIM_BPR_Recommender: Epoch 18 of 445. Elapsed time 1.12 sec
# Processed 12638 (100.0%) in 0.98 sec. BPR loss is 1.14E-01. Sample per second: 12861
# SLIM_BPR_Recommender: Epoch 19 of 445. Elapsed time 1.19 sec
# Processed 12638 (100.0%) in 1.05 sec. BPR loss is 1.30E-01. Sample per second: 12002
# SLIM_BPR_Recommender: Epoch 20 of 445. Elapsed time 1.26 sec
# Processed 12638 (100.0%) in 0.12 sec. BPR loss is 1.35E-01. Sample per second: 104968
# SLIM_BPR_Recommender: Epoch 21 of 445. Elapsed time 1.33 sec
# Processed 12638 (100.0%) in 0.19 sec. BPR loss is 1.48E-01. Sample per second: 65554
# SLIM_BPR_Recommender: Epoch 22 of 445. Elapsed time 1.40 sec
# Processed 12638 (100.0%) in 0.26 sec. BPR loss is 1.42E-01. Sample per second: 48026
# SLIM_BPR_Recommender: Epoch 23 of 445. Elapsed time 1.47 sec
# Processed 12638 (100.0%) in 0.33 sec. BPR loss is 1.56E-01. Sample per second: 37750
# SLIM_BPR_Recommender: Epoch 24 of 445. Elapsed time 1.54 sec
# Processed 12638 (100.0%) in 0.40 sec. BPR loss is 1.50E-01. Sample per second: 31382
# SLIM_BPR_Recommender: Epoch 25 of 445. Elapsed time 1.61 sec
# Processed 12638 (100.0%) in 0.47 sec. BPR loss is 1.66E-01. Sample per second: 26862
# SLIM_BPR_Recommender: Epoch 26 of 445. Elapsed time 1.68 sec
# Processed 12638 (100.0%) in 0.54 sec. BPR loss is 1.67E-01. Sample per second: 23459
# SLIM_BPR_Recommender: Epoch 27 of 445. Elapsed time 1.75 sec
# Processed 12638 (100.0%) in 0.61 sec. BPR loss is 1.73E-01. Sample per second: 20684
# SLIM_BPR_Recommender: Epoch 28 of 445. Elapsed time 1.82 sec
# Processed 12638 (100.0%) in 0.68 sec. BPR loss is 1.74E-01. Sample per second: 18657
# SLIM_BPR_Recommender: Epoch 29 of 445. Elapsed time 1.89 sec
# Processed 12638 (100.0%) in 0.75 sec. BPR loss is 1.80E-01. Sample per second: 16951
# SLIM_BPR_Recommender: Epoch 30 of 445. Elapsed time 1.95 sec
# Processed 12638 (100.0%) in 0.81 sec. BPR loss is 1.99E-01. Sample per second: 15530
# SLIM_BPR_Recommender: Epoch 31 of 445. Elapsed time 2.02 sec
# Processed 12638 (100.0%) in 0.88 sec. BPR loss is 2.05E-01. Sample per second: 14329
# SLIM_BPR_Recommender: Epoch 32 of 445. Elapsed time 2.09 sec
# Processed 12638 (100.0%) in 0.95 sec. BPR loss is 1.94E-01. Sample per second: 13335
# SLIM_BPR_Recommender: Epoch 33 of 445. Elapsed time 2.16 sec
# Processed 12638 (100.0%) in 1.01 sec. BPR loss is 2.11E-01. Sample per second: 12479
# SLIM_BPR_Recommender: Epoch 34 of 445. Elapsed time 2.22 sec
# Processed 12638 (100.0%) in 0.08 sec. BPR loss is 2.13E-01. Sample per second: 155223
# SLIM_BPR_Recommender: Epoch 35 of 445. Elapsed time 2.29 sec
# Processed 12638 (100.0%) in 0.15 sec. BPR loss is 2.20E-01. Sample per second: 84075
# SLIM_BPR_Recommender: Epoch 36 of 445. Elapsed time 2.36 sec
# Processed 12638 (100.0%) in 0.22 sec. BPR loss is 2.22E-01. Sample per second: 57890
# SLIM_BPR_Recommender: Epoch 37 of 445. Elapsed time 2.43 sec
# Processed 12638 (100.0%) in 0.28 sec. BPR loss is 2.32E-01. Sample per second: 44386
# SLIM_BPR_Recommender: Epoch 38 of 445. Elapsed time 2.50 sec
# Processed 12638 (100.0%) in 0.36 sec. BPR loss is 2.31E-01. Sample per second: 35517
# SLIM_BPR_Recommender: Epoch 39 of 445. Elapsed time 2.57 sec
# Processed 12638 (100.0%) in 0.42 sec. BPR loss is 2.41E-01. Sample per second: 29790
# SLIM_BPR_Recommender: Epoch 40 of 445. Elapsed time 2.63 sec
# Processed 12638 (100.0%) in 0.49 sec. BPR loss is 2.39E-01. Sample per second: 25592
# SLIM_BPR_Recommender: Epoch 41 of 445. Elapsed time 2.70 sec
# Processed 12638 (100.0%) in 0.56 sec. BPR loss is 2.49E-01. Sample per second: 22466
# SLIM_BPR_Recommender: Epoch 42 of 445. Elapsed time 2.77 sec
# Processed 12638 (100.0%) in 0.63 sec. BPR loss is 2.66E-01. Sample per second: 20031
# SLIM_BPR_Recommender: Epoch 43 of 445. Elapsed time 2.84 sec
# Processed 12638 (100.0%) in 0.70 sec. BPR loss is 2.47E-01. Sample per second: 18070
# SLIM_BPR_Recommender: Epoch 44 of 445. Elapsed time 2.91 sec
# Processed 12638 (100.0%) in 0.76 sec. BPR loss is 2.59E-01. Sample per second: 16638
# SLIM_BPR_Recommender: Epoch 45 of 445. Elapsed time 2.97 sec
# Processed 12638 (100.0%) in 0.82 sec. BPR loss is 2.58E-01. Sample per second: 15453
# SLIM_BPR_Recommender: Epoch 46 of 445. Elapsed time 3.03 sec
# Processed 12638 (100.0%) in 0.88 sec. BPR loss is 2.67E-01. Sample per second: 14425
# SLIM_BPR_Recommender: Epoch 47 of 445. Elapsed time 3.09 sec
# Processed 12638 (100.0%) in 0.93 sec. BPR loss is 2.91E-01. Sample per second: 13524
# SLIM_BPR_Recommender: Epoch 48 of 445. Elapsed time 3.14 sec
# Processed 12638 (100.0%) in 0.99 sec. BPR loss is 2.77E-01. Sample per second: 12733
# SLIM_BPR_Recommender: Epoch 49 of 445. Elapsed time 3.20 sec
# Processed 12638 (100.0%) in 1.05 sec. BPR loss is 3.01E-01. Sample per second: 12007
# SLIM_BPR_Recommender: Epoch 50 of 445. Elapsed time 3.26 sec
# Processed 12638 (100.0%) in 0.11 sec. BPR loss is 2.94E-01. Sample per second: 110077
# SLIM_BPR_Recommender: Epoch 51 of 445. Elapsed time 3.32 sec
# Processed 12638 (100.0%) in 0.17 sec. BPR loss is 3.06E-01. Sample per second: 72899
# SLIM_BPR_Recommender: Epoch 52 of 445. Elapsed time 3.38 sec
# Processed 12638 (100.0%) in 0.24 sec. BPR loss is 3.01E-01. Sample per second: 53408
# SLIM_BPR_Recommender: Epoch 53 of 445. Elapsed time 3.45 sec
# Processed 12638 (100.0%) in 0.30 sec. BPR loss is 2.97E-01. Sample per second: 42394
# SLIM_BPR_Recommender: Epoch 54 of 445. Elapsed time 3.51 sec
# Processed 12638 (100.0%) in 0.36 sec. BPR loss is 3.19E-01. Sample per second: 35076
# SLIM_BPR_Recommender: Epoch 55 of 445. Elapsed time 3.57 sec
# Processed 12638 (100.0%) in 0.42 sec. BPR loss is 3.27E-01. Sample per second: 29873
# SLIM_BPR_Recommender: Epoch 56 of 445. Elapsed time 3.63 sec
# Processed 12638 (100.0%) in 0.49 sec. BPR loss is 3.29E-01. Sample per second: 25940
# SLIM_BPR_Recommender: Epoch 57 of 445. Elapsed time 3.70 sec
# Processed 12638 (100.0%) in 0.55 sec. BPR loss is 3.36E-01. Sample per second: 23046
# SLIM_BPR_Recommender: Epoch 58 of 445. Elapsed time 3.76 sec
# Processed 12638 (100.0%) in 0.61 sec. BPR loss is 3.09E-01. Sample per second: 20747
# SLIM_BPR_Recommender: Epoch 59 of 445. Elapsed time 3.82 sec
# Processed 12638 (100.0%) in 0.67 sec. BPR loss is 3.34E-01. Sample per second: 18848
# SLIM_BPR_Recommender: Epoch 60 of 445. Elapsed time 3.88 sec
# Processed 12638 (100.0%) in 0.73 sec. BPR loss is 3.38E-01. Sample per second: 17291
# SLIM_BPR_Recommender: Epoch 61 of 445. Elapsed time 3.94 sec
# Processed 12638 (100.0%) in 0.79 sec. BPR loss is 3.37E-01. Sample per second: 15945
# SLIM_BPR_Recommender: Epoch 62 of 445. Elapsed time 4.00 sec
# Processed 12638 (100.0%) in 0.85 sec. BPR loss is 3.42E-01. Sample per second: 14801
# SLIM_BPR_Recommender: Epoch 63 of 445. Elapsed time 4.06 sec
# Processed 12638 (100.0%) in 0.91 sec. BPR loss is 3.66E-01. Sample per second: 13811
# SLIM_BPR_Recommender: Epoch 64 of 445. Elapsed time 4.12 sec
# Processed 12638 (100.0%) in 0.97 sec. BPR loss is 3.29E-01. Sample per second: 12966
# SLIM_BPR_Recommender: Epoch 65 of 445. Elapsed time 4.18 sec
# Processed 12638 (100.0%) in 1.04 sec. BPR loss is 3.47E-01. Sample per second: 12198
# SLIM_BPR_Recommender: Epoch 66 of 445. Elapsed time 4.25 sec
# Processed 12638 (100.0%) in 0.10 sec. BPR loss is 3.54E-01. Sample per second: 131185
# SLIM_BPR_Recommender: Epoch 67 of 445. Elapsed time 4.31 sec
# Processed 12638 (100.0%) in 0.16 sec. BPR loss is 3.74E-01. Sample per second: 80501
# SLIM_BPR_Recommender: Epoch 68 of 445. Elapsed time 4.37 sec
# Processed 12638 (100.0%) in 0.22 sec. BPR loss is 3.69E-01. Sample per second: 57821
# SLIM_BPR_Recommender: Epoch 69 of 445. Elapsed time 4.43 sec
# Processed 12638 (100.0%) in 0.28 sec. BPR loss is 3.85E-01. Sample per second: 45210
# SLIM_BPR_Recommender: Epoch 70 of 445. Elapsed time 4.49 sec
# Processed 12638 (100.0%) in 0.34 sec. BPR loss is 3.83E-01. Sample per second: 37536
# SLIM_BPR_Recommender: Epoch 71 of 445. Elapsed time 4.55 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 3.99E-01. Sample per second: 32000
# SLIM_BPR_Recommender: Epoch 72 of 445. Elapsed time 4.60 sec
# Processed 12638 (100.0%) in 0.45 sec. BPR loss is 4.03E-01. Sample per second: 27872
# SLIM_BPR_Recommender: Epoch 73 of 445. Elapsed time 4.66 sec
# Processed 12638 (100.0%) in 0.51 sec. BPR loss is 4.13E-01. Sample per second: 24616
# SLIM_BPR_Recommender: Epoch 74 of 445. Elapsed time 4.72 sec
# Processed 12638 (100.0%) in 0.57 sec. BPR loss is 3.89E-01. Sample per second: 22169
# SLIM_BPR_Recommender: Epoch 75 of 445. Elapsed time 4.78 sec
# Processed 12638 (100.0%) in 0.63 sec. BPR loss is 4.12E-01. Sample per second: 20135
# SLIM_BPR_Recommender: Epoch 76 of 445. Elapsed time 4.84 sec
# Processed 12638 (100.0%) in 0.69 sec. BPR loss is 4.23E-01. Sample per second: 18424
# SLIM_BPR_Recommender: Epoch 77 of 445. Elapsed time 4.90 sec
# Processed 12638 (100.0%) in 0.75 sec. BPR loss is 3.75E-01. Sample per second: 16950
# SLIM_BPR_Recommender: Epoch 78 of 445. Elapsed time 4.96 sec
# Processed 12638 (100.0%) in 0.81 sec. BPR loss is 4.11E-01. Sample per second: 15685
# SLIM_BPR_Recommender: Epoch 79 of 445. Elapsed time 5.02 sec
# Processed 12638 (100.0%) in 0.86 sec. BPR loss is 3.98E-01. Sample per second: 14608
# SLIM_BPR_Recommender: Epoch 80 of 445. Elapsed time 5.07 sec
# Processed 12638 (100.0%) in 0.93 sec. BPR loss is 4.15E-01. Sample per second: 13537
# SLIM_BPR_Recommender: Epoch 81 of 445. Elapsed time 5.14 sec
# Processed 12638 (100.0%) in 1.00 sec. BPR loss is 4.16E-01. Sample per second: 12634
# SLIM_BPR_Recommender: Epoch 82 of 445. Elapsed time 5.21 sec
# Processed 12638 (100.0%) in 0.07 sec. BPR loss is 4.42E-01. Sample per second: 187148
# SLIM_BPR_Recommender: Epoch 83 of 445. Elapsed time 5.28 sec
# Processed 12638 (100.0%) in 0.13 sec. BPR loss is 4.26E-01. Sample per second: 94480
# SLIM_BPR_Recommender: Epoch 84 of 445. Elapsed time 5.34 sec
# Processed 12638 (100.0%) in 0.20 sec. BPR loss is 4.35E-01. Sample per second: 62756
# SLIM_BPR_Recommender: Epoch 85 of 445. Elapsed time 5.41 sec
# Processed 12638 (100.0%) in 0.27 sec. BPR loss is 4.31E-01. Sample per second: 46875
# SLIM_BPR_Recommender: Epoch 86 of 445. Elapsed time 5.48 sec
# Processed 12638 (100.0%) in 0.34 sec. BPR loss is 4.51E-01. Sample per second: 37495
# SLIM_BPR_Recommender: Epoch 87 of 445. Elapsed time 5.55 sec
# Processed 12638 (100.0%) in 0.41 sec. BPR loss is 4.54E-01. Sample per second: 30945
# SLIM_BPR_Recommender: Epoch 88 of 445. Elapsed time 5.62 sec
# Processed 12638 (100.0%) in 0.48 sec. BPR loss is 4.46E-01. Sample per second: 26349
# SLIM_BPR_Recommender: Epoch 89 of 445. Elapsed time 5.69 sec
# Processed 12638 (100.0%) in 0.56 sec. BPR loss is 4.62E-01. Sample per second: 22593
# SLIM_BPR_Recommender: Epoch 90 of 445. Elapsed time 5.77 sec
# Processed 12638 (100.0%) in 0.64 sec. BPR loss is 4.66E-01. Sample per second: 19768
# SLIM_BPR_Recommender: Epoch 91 of 445. Elapsed time 5.85 sec
# Processed 12638 (100.0%) in 0.71 sec. BPR loss is 4.64E-01. Sample per second: 17806
# SLIM_BPR_Recommender: Epoch 92 of 445. Elapsed time 5.92 sec
# Processed 12638 (100.0%) in 0.78 sec. BPR loss is 4.68E-01. Sample per second: 16258
# SLIM_BPR_Recommender: Epoch 93 of 445. Elapsed time 5.99 sec
# Processed 12638 (100.0%) in 0.84 sec. BPR loss is 4.68E-01. Sample per second: 15121
# SLIM_BPR_Recommender: Epoch 94 of 445. Elapsed time 6.05 sec
# Processed 12638 (100.0%) in 0.89 sec. BPR loss is 4.71E-01. Sample per second: 14138
# SLIM_BPR_Recommender: Epoch 95 of 445. Elapsed time 6.10 sec
# Processed 12638 (100.0%) in 0.95 sec. BPR loss is 4.69E-01. Sample per second: 13261
# SLIM_BPR_Recommender: Epoch 96 of 445. Elapsed time 6.16 sec
# Processed 12638 (100.0%) in 1.01 sec. BPR loss is 5.01E-01. Sample per second: 12484
# SLIM_BPR_Recommender: Epoch 97 of 445. Elapsed time 6.22 sec
# Processed 12638 (100.0%) in 0.07 sec. BPR loss is 5.10E-01. Sample per second: 175354
# SLIM_BPR_Recommender: Epoch 98 of 445. Elapsed time 6.28 sec
# Processed 12638 (100.0%) in 0.13 sec. BPR loss is 4.93E-01. Sample per second: 94472
# SLIM_BPR_Recommender: Epoch 99 of 445. Elapsed time 6.34 sec
# Processed 12638 (100.0%) in 0.19 sec. BPR loss is 5.23E-01. Sample per second: 65689
# SLIM_BPR_Recommender: Epoch 100 of 445. Elapsed time 6.40 sec
# Processed 12638 (100.0%) in 0.25 sec. BPR loss is 5.08E-01. Sample per second: 50004
# SLIM_BPR_Recommender: Epoch 101 of 445. Elapsed time 6.46 sec
# Processed 12638 (100.0%) in 0.31 sec. BPR loss is 4.97E-01. Sample per second: 40455
# SLIM_BPR_Recommender: Epoch 102 of 445. Elapsed time 6.52 sec
# Processed 12638 (100.0%) in 0.37 sec. BPR loss is 5.18E-01. Sample per second: 34055
# SLIM_BPR_Recommender: Epoch 103 of 445. Elapsed time 6.58 sec
# Processed 12638 (100.0%) in 0.43 sec. BPR loss is 5.20E-01. Sample per second: 29347
# SLIM_BPR_Recommender: Epoch 104 of 445. Elapsed time 6.64 sec
# Processed 12638 (100.0%) in 0.49 sec. BPR loss is 5.24E-01. Sample per second: 25672
# SLIM_BPR_Recommender: Epoch 105 of 445. Elapsed time 6.70 sec
# Processed 12638 (100.0%) in 0.55 sec. BPR loss is 5.20E-01. Sample per second: 22977
# SLIM_BPR_Recommender: Epoch 106 of 445. Elapsed time 6.76 sec
# Processed 12638 (100.0%) in 0.61 sec. BPR loss is 5.28E-01. Sample per second: 20710
# SLIM_BPR_Recommender: Epoch 107 of 445. Elapsed time 6.82 sec
# Processed 12638 (100.0%) in 0.67 sec. BPR loss is 5.36E-01. Sample per second: 18843
# SLIM_BPR_Recommender: Epoch 108 of 445. Elapsed time 6.88 sec
# Processed 12638 (100.0%) in 0.73 sec. BPR loss is 5.70E-01. Sample per second: 17309
# SLIM_BPR_Recommender: Epoch 109 of 445. Elapsed time 6.94 sec
# Processed 12638 (100.0%) in 0.79 sec. BPR loss is 5.45E-01. Sample per second: 16030
# SLIM_BPR_Recommender: Epoch 110 of 445. Elapsed time 7.00 sec
# Processed 12638 (100.0%) in 0.85 sec. BPR loss is 5.34E-01. Sample per second: 14929
# SLIM_BPR_Recommender: Epoch 111 of 445. Elapsed time 7.06 sec
# Processed 12638 (100.0%) in 0.90 sec. BPR loss is 5.61E-01. Sample per second: 13982
# SLIM_BPR_Recommender: Epoch 112 of 445. Elapsed time 7.11 sec
# Processed 12638 (100.0%) in 0.96 sec. BPR loss is 5.73E-01. Sample per second: 13104
# SLIM_BPR_Recommender: Epoch 113 of 445. Elapsed time 7.17 sec
# Processed 12638 (100.0%) in 1.02 sec. BPR loss is 5.66E-01. Sample per second: 12339
# SLIM_BPR_Recommender: Epoch 114 of 445. Elapsed time 7.23 sec
# Processed 12638 (100.0%) in 0.08 sec. BPR loss is 5.77E-01. Sample per second: 149869
# SLIM_BPR_Recommender: Epoch 115 of 445. Elapsed time 7.29 sec
# Processed 12638 (100.0%) in 0.14 sec. BPR loss is 5.53E-01. Sample per second: 88807
# SLIM_BPR_Recommender: Epoch 116 of 445. Elapsed time 7.35 sec
# Processed 12638 (100.0%) in 0.20 sec. BPR loss is 5.67E-01. Sample per second: 62141
# SLIM_BPR_Recommender: Epoch 117 of 445. Elapsed time 7.41 sec
# Processed 12638 (100.0%) in 0.26 sec. BPR loss is 5.67E-01. Sample per second: 48311
# SLIM_BPR_Recommender: Epoch 118 of 445. Elapsed time 7.47 sec
# Processed 12638 (100.0%) in 0.32 sec. BPR loss is 5.44E-01. Sample per second: 39463
# SLIM_BPR_Recommender: Epoch 119 of 445. Elapsed time 7.53 sec
# Processed 12638 (100.0%) in 0.38 sec. BPR loss is 5.89E-01. Sample per second: 33288
# SLIM_BPR_Recommender: Epoch 120 of 445. Elapsed time 7.59 sec
# Processed 12638 (100.0%) in 0.44 sec. BPR loss is 5.92E-01. Sample per second: 28880
# SLIM_BPR_Recommender: Epoch 121 of 445. Elapsed time 7.65 sec
# Processed 12638 (100.0%) in 0.50 sec. BPR loss is 5.77E-01. Sample per second: 25457
# SLIM_BPR_Recommender: Epoch 122 of 445. Elapsed time 7.71 sec
# Processed 12638 (100.0%) in 0.55 sec. BPR loss is 5.89E-01. Sample per second: 22789
# SLIM_BPR_Recommender: Epoch 123 of 445. Elapsed time 7.76 sec
# Processed 12638 (100.0%) in 0.61 sec. BPR loss is 5.98E-01. Sample per second: 20581
# SLIM_BPR_Recommender: Epoch 124 of 445. Elapsed time 7.82 sec
# Processed 12638 (100.0%) in 0.67 sec. BPR loss is 5.83E-01. Sample per second: 18792
# SLIM_BPR_Recommender: Epoch 125 of 445. Elapsed time 7.88 sec
# Processed 12638 (100.0%) in 0.74 sec. BPR loss is 6.16E-01. Sample per second: 17186
# SLIM_BPR_Recommender: Epoch 126 of 445. Elapsed time 7.94 sec
# Processed 12638 (100.0%) in 0.80 sec. BPR loss is 5.83E-01. Sample per second: 15853
# SLIM_BPR_Recommender: Epoch 127 of 445. Elapsed time 8.01 sec
# Processed 12638 (100.0%) in 0.85 sec. BPR loss is 6.09E-01. Sample per second: 14784
# SLIM_BPR_Recommender: Epoch 128 of 445. Elapsed time 8.06 sec
# Processed 12638 (100.0%) in 0.91 sec. BPR loss is 6.26E-01. Sample per second: 13839
# SLIM_BPR_Recommender: Epoch 129 of 445. Elapsed time 8.12 sec
# Processed 12638 (100.0%) in 0.97 sec. BPR loss is 6.21E-01. Sample per second: 13010
# SLIM_BPR_Recommender: Epoch 130 of 445. Elapsed time 8.18 sec
# Processed 12638 (100.0%) in 1.03 sec. BPR loss is 6.19E-01. Sample per second: 12275
# SLIM_BPR_Recommender: Epoch 131 of 445. Elapsed time 8.24 sec
# Processed 12638 (100.0%) in 0.09 sec. BPR loss is 6.35E-01. Sample per second: 145148
# SLIM_BPR_Recommender: Epoch 132 of 445. Elapsed time 8.30 sec
# Processed 12638 (100.0%) in 0.15 sec. BPR loss is 6.06E-01. Sample per second: 86968
# SLIM_BPR_Recommender: Epoch 133 of 445. Elapsed time 8.35 sec
# Processed 12638 (100.0%) in 0.20 sec. BPR loss is 6.62E-01. Sample per second: 61726
# SLIM_BPR_Recommender: Epoch 134 of 445. Elapsed time 8.41 sec
# Processed 12638 (100.0%) in 0.26 sec. BPR loss is 6.27E-01. Sample per second: 48150
# SLIM_BPR_Recommender: Epoch 135 of 445. Elapsed time 8.47 sec
# Processed 12638 (100.0%) in 0.32 sec. BPR loss is 6.33E-01. Sample per second: 39239
# SLIM_BPR_Recommender: Epoch 136 of 445. Elapsed time 8.53 sec
# Processed 12638 (100.0%) in 0.38 sec. BPR loss is 6.60E-01. Sample per second: 33299
# SLIM_BPR_Recommender: Epoch 137 of 445. Elapsed time 8.59 sec
# Processed 12638 (100.0%) in 0.44 sec. BPR loss is 6.30E-01. Sample per second: 28822
# SLIM_BPR_Recommender: Epoch 138 of 445. Elapsed time 8.65 sec
# Processed 12638 (100.0%) in 0.49 sec. BPR loss is 6.31E-01. Sample per second: 25562
# SLIM_BPR_Recommender: Epoch 139 of 445. Elapsed time 8.70 sec
# Processed 12638 (100.0%) in 0.56 sec. BPR loss is 6.26E-01. Sample per second: 22622
# SLIM_BPR_Recommender: Epoch 140 of 445. Elapsed time 8.77 sec
# Processed 12638 (100.0%) in 0.62 sec. BPR loss is 6.24E-01. Sample per second: 20222
# SLIM_BPR_Recommender: Epoch 141 of 445. Elapsed time 8.83 sec
# Processed 12638 (100.0%) in 0.69 sec. BPR loss is 6.36E-01. Sample per second: 18347
# SLIM_BPR_Recommender: Epoch 142 of 445. Elapsed time 8.90 sec
# Processed 12638 (100.0%) in 0.75 sec. BPR loss is 6.57E-01. Sample per second: 16738
# SLIM_BPR_Recommender: Epoch 143 of 445. Elapsed time 8.96 sec
# Processed 12638 (100.0%) in 0.82 sec. BPR loss is 6.67E-01. Sample per second: 15368
# SLIM_BPR_Recommender: Epoch 144 of 445. Elapsed time 9.03 sec
# Processed 12638 (100.0%) in 0.89 sec. BPR loss is 6.99E-01. Sample per second: 14203
# SLIM_BPR_Recommender: Epoch 145 of 445. Elapsed time 9.10 sec
# Processed 12638 (100.0%) in 0.96 sec. BPR loss is 6.56E-01. Sample per second: 13193
# SLIM_BPR_Recommender: Epoch 146 of 445. Elapsed time 9.17 sec
# Processed 12638 (100.0%) in 1.03 sec. BPR loss is 6.40E-01. Sample per second: 12301
# SLIM_BPR_Recommender: Epoch 147 of 445. Elapsed time 9.24 sec
# Processed 12638 (100.0%) in 0.10 sec. BPR loss is 6.66E-01. Sample per second: 131447
# SLIM_BPR_Recommender: Epoch 148 of 445. Elapsed time 9.31 sec
# Processed 12638 (100.0%) in 0.17 sec. BPR loss is 6.83E-01. Sample per second: 75887
# SLIM_BPR_Recommender: Epoch 149 of 445. Elapsed time 9.38 sec
# Processed 12638 (100.0%) in 0.24 sec. BPR loss is 6.74E-01. Sample per second: 53306
# SLIM_BPR_Recommender: Epoch 150 of 445. Elapsed time 9.45 sec
# Processed 12638 (100.0%) in 0.31 sec. BPR loss is 6.68E-01. Sample per second: 41175
# SLIM_BPR_Recommender: Epoch 151 of 445. Elapsed time 9.52 sec
# Processed 12638 (100.0%) in 0.37 sec. BPR loss is 6.63E-01. Sample per second: 33843
# SLIM_BPR_Recommender: Epoch 152 of 445. Elapsed time 9.58 sec
# Processed 12638 (100.0%) in 0.44 sec. BPR loss is 6.99E-01. Sample per second: 28642
# SLIM_BPR_Recommender: Epoch 153 of 445. Elapsed time 9.65 sec
# Processed 12638 (100.0%) in 0.51 sec. BPR loss is 7.36E-01. Sample per second: 24780
# SLIM_BPR_Recommender: Epoch 154 of 445. Elapsed time 9.72 sec
# Processed 12638 (100.0%) in 0.58 sec. BPR loss is 6.90E-01. Sample per second: 21918
# SLIM_BPR_Recommender: Epoch 155 of 445. Elapsed time 9.79 sec
# Processed 12638 (100.0%) in 0.64 sec. BPR loss is 7.02E-01. Sample per second: 19771
# SLIM_BPR_Recommender: Epoch 156 of 445. Elapsed time 9.85 sec
# Processed 12638 (100.0%) in 0.70 sec. BPR loss is 7.10E-01. Sample per second: 18068
# SLIM_BPR_Recommender: Epoch 157 of 445. Elapsed time 9.91 sec
# Processed 12638 (100.0%) in 0.76 sec. BPR loss is 7.09E-01. Sample per second: 16525
# SLIM_BPR_Recommender: Epoch 158 of 445. Elapsed time 9.97 sec
# Processed 12638 (100.0%) in 0.83 sec. BPR loss is 7.39E-01. Sample per second: 15155
# SLIM_BPR_Recommender: Epoch 159 of 445. Elapsed time 10.04 sec
# Processed 12638 (100.0%) in 0.90 sec. BPR loss is 7.15E-01. Sample per second: 13964
# SLIM_BPR_Recommender: Epoch 160 of 445. Elapsed time 10.11 sec
# Processed 12638 (100.0%) in 0.97 sec. BPR loss is 6.99E-01. Sample per second: 12966
# SLIM_BPR_Recommender: Epoch 161 of 445. Elapsed time 10.18 sec
# Processed 12638 (100.0%) in 1.05 sec. BPR loss is 7.14E-01. Sample per second: 12080
# SLIM_BPR_Recommender: Epoch 162 of 445. Elapsed time 10.26 sec
# Processed 12638 (100.0%) in 0.12 sec. BPR loss is 6.98E-01. Sample per second: 108612
# SLIM_BPR_Recommender: Epoch 163 of 445. Elapsed time 10.33 sec
# Processed 12638 (100.0%) in 0.19 sec. BPR loss is 7.77E-01. Sample per second: 67399
# SLIM_BPR_Recommender: Epoch 164 of 445. Elapsed time 10.40 sec
# Processed 12638 (100.0%) in 0.26 sec. BPR loss is 7.34E-01. Sample per second: 48897
# SLIM_BPR_Recommender: Epoch 165 of 445. Elapsed time 10.47 sec
# Processed 12638 (100.0%) in 0.33 sec. BPR loss is 7.25E-01. Sample per second: 38602
# SLIM_BPR_Recommender: Epoch 166 of 445. Elapsed time 10.54 sec
# Processed 12638 (100.0%) in 0.40 sec. BPR loss is 7.28E-01. Sample per second: 31941
# SLIM_BPR_Recommender: Epoch 167 of 445. Elapsed time 10.61 sec
# Processed 12638 (100.0%) in 0.46 sec. BPR loss is 7.77E-01. Sample per second: 27222
# SLIM_BPR_Recommender: Epoch 168 of 445. Elapsed time 10.67 sec
# Processed 12638 (100.0%) in 0.53 sec. BPR loss is 7.46E-01. Sample per second: 23684
# SLIM_BPR_Recommender: Epoch 169 of 445. Elapsed time 10.74 sec
# Processed 12638 (100.0%) in 0.60 sec. BPR loss is 7.51E-01. Sample per second: 20948
# SLIM_BPR_Recommender: Epoch 170 of 445. Elapsed time 10.81 sec
# Processed 12638 (100.0%) in 0.66 sec. BPR loss is 7.34E-01. Sample per second: 19061
# SLIM_BPR_Recommender: Epoch 171 of 445. Elapsed time 10.87 sec
# Processed 12638 (100.0%) in 0.72 sec. BPR loss is 8.03E-01. Sample per second: 17529
# SLIM_BPR_Recommender: Epoch 172 of 445. Elapsed time 10.93 sec
# Processed 12638 (100.0%) in 0.78 sec. BPR loss is 7.49E-01. Sample per second: 16170
# SLIM_BPR_Recommender: Epoch 173 of 445. Elapsed time 10.99 sec
# Processed 12638 (100.0%) in 0.84 sec. BPR loss is 7.91E-01. Sample per second: 15012
# SLIM_BPR_Recommender: Epoch 174 of 445. Elapsed time 11.05 sec
# Processed 12638 (100.0%) in 0.90 sec. BPR loss is 7.24E-01. Sample per second: 14024
# SLIM_BPR_Recommender: Epoch 175 of 445. Elapsed time 11.11 sec
# Processed 12638 (100.0%) in 0.96 sec. BPR loss is 7.74E-01. Sample per second: 13152
# SLIM_BPR_Recommender: Epoch 176 of 445. Elapsed time 11.17 sec
# Processed 12638 (100.0%) in 1.02 sec. BPR loss is 7.59E-01. Sample per second: 12384
# SLIM_BPR_Recommender: Epoch 177 of 445. Elapsed time 11.23 sec
# Processed 12638 (100.0%) in 0.08 sec. BPR loss is 8.25E-01. Sample per second: 153545
# SLIM_BPR_Recommender: Epoch 178 of 445. Elapsed time 11.29 sec
# Processed 12638 (100.0%) in 0.14 sec. BPR loss is 7.79E-01. Sample per second: 89054
# SLIM_BPR_Recommender: Epoch 179 of 445. Elapsed time 11.35 sec
# Processed 12638 (100.0%) in 0.20 sec. BPR loss is 8.07E-01. Sample per second: 64019
# SLIM_BPR_Recommender: Epoch 180 of 445. Elapsed time 11.41 sec
# Processed 12638 (100.0%) in 0.25 sec. BPR loss is 8.18E-01. Sample per second: 49557
# SLIM_BPR_Recommender: Epoch 181 of 445. Elapsed time 11.46 sec
# Processed 12638 (100.0%) in 0.31 sec. BPR loss is 8.19E-01. Sample per second: 40192
# SLIM_BPR_Recommender: Epoch 182 of 445. Elapsed time 11.52 sec
# Processed 12638 (100.0%) in 0.37 sec. BPR loss is 8.07E-01. Sample per second: 33990
# SLIM_BPR_Recommender: Epoch 183 of 445. Elapsed time 11.58 sec
# Processed 12638 (100.0%) in 0.43 sec. BPR loss is 8.19E-01. Sample per second: 29315
# SLIM_BPR_Recommender: Epoch 184 of 445. Elapsed time 11.64 sec
# Processed 12638 (100.0%) in 0.49 sec. BPR loss is 8.19E-01. Sample per second: 25746
# SLIM_BPR_Recommender: Epoch 185 of 445. Elapsed time 11.70 sec
# Processed 12638 (100.0%) in 0.55 sec. BPR loss is 7.69E-01. Sample per second: 22964
# SLIM_BPR_Recommender: Epoch 186 of 445. Elapsed time 11.76 sec
# Processed 12638 (100.0%) in 0.61 sec. BPR loss is 7.78E-01. Sample per second: 20650
# SLIM_BPR_Recommender: Epoch 187 of 445. Elapsed time 11.82 sec
# Processed 12638 (100.0%) in 0.67 sec. BPR loss is 8.01E-01. Sample per second: 18790
# SLIM_BPR_Recommender: Epoch 188 of 445. Elapsed time 11.88 sec
# Processed 12638 (100.0%) in 0.73 sec. BPR loss is 8.35E-01. Sample per second: 17225
# SLIM_BPR_Recommender: Epoch 189 of 445. Elapsed time 11.94 sec
# Processed 12638 (100.0%) in 0.79 sec. BPR loss is 8.28E-01. Sample per second: 15928
# SLIM_BPR_Recommender: Epoch 190 of 445. Elapsed time 12.00 sec
# Processed 12638 (100.0%) in 0.85 sec. BPR loss is 8.22E-01. Sample per second: 14830
# SLIM_BPR_Recommender: Epoch 191 of 445. Elapsed time 12.06 sec
# Processed 12638 (100.0%) in 0.91 sec. BPR loss is 8.13E-01. Sample per second: 13885
# SLIM_BPR_Recommender: Epoch 192 of 445. Elapsed time 12.12 sec
# Processed 12638 (100.0%) in 0.97 sec. BPR loss is 8.36E-01. Sample per second: 13073
# SLIM_BPR_Recommender: Epoch 193 of 445. Elapsed time 12.18 sec
# Processed 12638 (100.0%) in 1.02 sec. BPR loss is 8.13E-01. Sample per second: 12364
# SLIM_BPR_Recommender: Epoch 194 of 445. Elapsed time 12.23 sec
# Processed 12638 (100.0%) in 0.08 sec. BPR loss is 8.09E-01. Sample per second: 157952
# SLIM_BPR_Recommender: Epoch 195 of 445. Elapsed time 12.29 sec
# Processed 12638 (100.0%) in 0.14 sec. BPR loss is 8.39E-01. Sample per second: 91958
# SLIM_BPR_Recommender: Epoch 196 of 445. Elapsed time 12.35 sec
# Processed 12638 (100.0%) in 0.20 sec. BPR loss is 8.13E-01. Sample per second: 64570
# SLIM_BPR_Recommender: Epoch 197 of 445. Elapsed time 12.41 sec
# Processed 12638 (100.0%) in 0.26 sec. BPR loss is 8.45E-01. Sample per second: 49466
# SLIM_BPR_Recommender: Epoch 198 of 445. Elapsed time 12.46 sec
# Processed 12638 (100.0%) in 0.31 sec. BPR loss is 8.47E-01. Sample per second: 40400
# SLIM_BPR_Recommender: Epoch 199 of 445. Elapsed time 12.52 sec
# Processed 12638 (100.0%) in 0.37 sec. BPR loss is 8.37E-01. Sample per second: 34318
# SLIM_BPR_Recommender: Epoch 200 of 445. Elapsed time 12.58 sec
# Processed 12638 (100.0%) in 0.43 sec. BPR loss is 8.44E-01. Sample per second: 29571
# SLIM_BPR_Recommender: Epoch 201 of 445. Elapsed time 12.64 sec
# Processed 12638 (100.0%) in 0.48 sec. BPR loss is 8.49E-01. Sample per second: 26060
# SLIM_BPR_Recommender: Epoch 202 of 445. Elapsed time 12.69 sec
# Processed 12638 (100.0%) in 0.54 sec. BPR loss is 8.60E-01. Sample per second: 23280
# SLIM_BPR_Recommender: Epoch 203 of 445. Elapsed time 12.75 sec
# Processed 12638 (100.0%) in 0.60 sec. BPR loss is 8.61E-01. Sample per second: 21055
# SLIM_BPR_Recommender: Epoch 204 of 445. Elapsed time 12.81 sec
# Processed 12638 (100.0%) in 0.66 sec. BPR loss is 8.38E-01. Sample per second: 19227
# SLIM_BPR_Recommender: Epoch 205 of 445. Elapsed time 12.87 sec
# Processed 12638 (100.0%) in 0.72 sec. BPR loss is 8.50E-01. Sample per second: 17658
# SLIM_BPR_Recommender: Epoch 206 of 445. Elapsed time 12.93 sec
# Processed 12638 (100.0%) in 0.78 sec. BPR loss is 8.53E-01. Sample per second: 16298
# SLIM_BPR_Recommender: Epoch 207 of 445. Elapsed time 12.98 sec
# Processed 12638 (100.0%) in 0.83 sec. BPR loss is 9.06E-01. Sample per second: 15160
# SLIM_BPR_Recommender: Epoch 208 of 445. Elapsed time 13.04 sec
# Processed 12638 (100.0%) in 0.89 sec. BPR loss is 8.98E-01. Sample per second: 14159
# SLIM_BPR_Recommender: Epoch 209 of 445. Elapsed time 13.10 sec
# Processed 12638 (100.0%) in 0.95 sec. BPR loss is 8.58E-01. Sample per second: 13276
# SLIM_BPR_Recommender: Epoch 210 of 445. Elapsed time 13.16 sec
# Processed 12638 (100.0%) in 1.01 sec. BPR loss is 8.86E-01. Sample per second: 12502
# SLIM_BPR_Recommender: Epoch 211 of 445. Elapsed time 13.22 sec
# Processed 12638 (100.0%) in 0.07 sec. BPR loss is 8.49E-01. Sample per second: 184210
# SLIM_BPR_Recommender: Epoch 212 of 445. Elapsed time 13.28 sec
# Processed 12638 (100.0%) in 0.13 sec. BPR loss is 9.12E-01. Sample per second: 100082
# SLIM_BPR_Recommender: Epoch 213 of 445. Elapsed time 13.34 sec
# Processed 12638 (100.0%) in 0.18 sec. BPR loss is 9.42E-01. Sample per second: 68308
# SLIM_BPR_Recommender: Epoch 214 of 445. Elapsed time 13.39 sec
# Processed 12638 (100.0%) in 0.24 sec. BPR loss is 8.88E-01. Sample per second: 51548
# SLIM_BPR_Recommender: Epoch 215 of 445. Elapsed time 13.45 sec
# Processed 12638 (100.0%) in 0.30 sec. BPR loss is 8.83E-01. Sample per second: 41640
# SLIM_BPR_Recommender: Epoch 216 of 445. Elapsed time 13.51 sec
# Processed 12638 (100.0%) in 0.36 sec. BPR loss is 8.87E-01. Sample per second: 34937
# SLIM_BPR_Recommender: Epoch 217 of 445. Elapsed time 13.57 sec
# Processed 12638 (100.0%) in 0.42 sec. BPR loss is 8.95E-01. Sample per second: 29977
# SLIM_BPR_Recommender: Epoch 218 of 445. Elapsed time 13.63 sec
# Processed 12638 (100.0%) in 0.48 sec. BPR loss is 8.83E-01. Sample per second: 26212
# SLIM_BPR_Recommender: Epoch 219 of 445. Elapsed time 13.69 sec
# Processed 12638 (100.0%) in 0.54 sec. BPR loss is 9.32E-01. Sample per second: 23383
# SLIM_BPR_Recommender: Epoch 220 of 445. Elapsed time 13.75 sec
# Processed 12638 (100.0%) in 0.60 sec. BPR loss is 9.22E-01. Sample per second: 21008
# SLIM_BPR_Recommender: Epoch 221 of 445. Elapsed time 13.81 sec
# Processed 12638 (100.0%) in 0.66 sec. BPR loss is 9.19E-01. Sample per second: 19110
# SLIM_BPR_Recommender: Epoch 222 of 445. Elapsed time 13.87 sec
# Processed 12638 (100.0%) in 0.72 sec. BPR loss is 9.41E-01. Sample per second: 17497
# SLIM_BPR_Recommender: Epoch 223 of 445. Elapsed time 13.93 sec
# Processed 12638 (100.0%) in 0.78 sec. BPR loss is 9.13E-01. Sample per second: 16156
# SLIM_BPR_Recommender: Epoch 224 of 445. Elapsed time 13.99 sec
# Processed 12638 (100.0%) in 0.84 sec. BPR loss is 9.53E-01. Sample per second: 15031
# SLIM_BPR_Recommender: Epoch 225 of 445. Elapsed time 14.05 sec
# Processed 12638 (100.0%) in 0.90 sec. BPR loss is 9.43E-01. Sample per second: 14058
# SLIM_BPR_Recommender: Epoch 226 of 445. Elapsed time 14.11 sec
# Processed 12638 (100.0%) in 0.96 sec. BPR loss is 9.55E-01. Sample per second: 13196
# SLIM_BPR_Recommender: Epoch 227 of 445. Elapsed time 14.17 sec
# Processed 12638 (100.0%) in 1.02 sec. BPR loss is 9.14E-01. Sample per second: 12383
# SLIM_BPR_Recommender: Epoch 228 of 445. Elapsed time 14.23 sec
# Processed 12638 (100.0%) in 0.08 sec. BPR loss is 9.26E-01. Sample per second: 154536
# SLIM_BPR_Recommender: Epoch 229 of 445. Elapsed time 14.29 sec
# Processed 12638 (100.0%) in 0.15 sec. BPR loss is 9.58E-01. Sample per second: 86043
# SLIM_BPR_Recommender: Epoch 230 of 445. Elapsed time 14.36 sec
# Processed 12638 (100.0%) in 0.21 sec. BPR loss is 9.32E-01. Sample per second: 59165
# SLIM_BPR_Recommender: Epoch 231 of 445. Elapsed time 14.42 sec
# Processed 12638 (100.0%) in 0.27 sec. BPR loss is 9.51E-01. Sample per second: 46125
# SLIM_BPR_Recommender: Epoch 232 of 445. Elapsed time 14.48 sec
# Processed 12638 (100.0%) in 0.33 sec. BPR loss is 9.46E-01. Sample per second: 37823
# SLIM_BPR_Recommender: Epoch 233 of 445. Elapsed time 14.54 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 9.74E-01. Sample per second: 32056
# SLIM_BPR_Recommender: Epoch 234 of 445. Elapsed time 14.60 sec
# Processed 12638 (100.0%) in 0.45 sec. BPR loss is 9.60E-01. Sample per second: 27902
# SLIM_BPR_Recommender: Epoch 235 of 445. Elapsed time 14.66 sec
# Processed 12638 (100.0%) in 0.51 sec. BPR loss is 9.52E-01. Sample per second: 24673
# SLIM_BPR_Recommender: Epoch 236 of 445. Elapsed time 14.72 sec
# Processed 12638 (100.0%) in 0.57 sec. BPR loss is 9.62E-01. Sample per second: 22177
# SLIM_BPR_Recommender: Epoch 237 of 445. Elapsed time 14.78 sec
# Processed 12638 (100.0%) in 0.63 sec. BPR loss is 9.91E-01. Sample per second: 20113
# SLIM_BPR_Recommender: Epoch 238 of 445. Elapsed time 14.84 sec
# Processed 12638 (100.0%) in 0.69 sec. BPR loss is 9.70E-01. Sample per second: 18422
# SLIM_BPR_Recommender: Epoch 239 of 445. Elapsed time 14.90 sec
# Processed 12638 (100.0%) in 0.75 sec. BPR loss is 9.78E-01. Sample per second: 16928
# SLIM_BPR_Recommender: Epoch 240 of 445. Elapsed time 14.96 sec
# Processed 12638 (100.0%) in 0.81 sec. BPR loss is 9.80E-01. Sample per second: 15683
# SLIM_BPR_Recommender: Epoch 241 of 445. Elapsed time 15.02 sec
# Processed 12638 (100.0%) in 0.86 sec. BPR loss is 9.99E-01. Sample per second: 14624
# SLIM_BPR_Recommender: Epoch 242 of 445. Elapsed time 15.07 sec
# Processed 12638 (100.0%) in 0.92 sec. BPR loss is 9.92E-01. Sample per second: 13720
# SLIM_BPR_Recommender: Epoch 243 of 445. Elapsed time 15.13 sec
# Processed 12638 (100.0%) in 0.98 sec. BPR loss is 1.00E+00. Sample per second: 12880
# SLIM_BPR_Recommender: Epoch 244 of 445. Elapsed time 15.19 sec
# Processed 12638 (100.0%) in 1.04 sec. BPR loss is 9.92E-01. Sample per second: 12161
# SLIM_BPR_Recommender: Epoch 245 of 445. Elapsed time 15.25 sec
# Processed 12638 (100.0%) in 0.10 sec. BPR loss is 9.73E-01. Sample per second: 130760
# SLIM_BPR_Recommender: Epoch 246 of 445. Elapsed time 15.31 sec
# Processed 12638 (100.0%) in 0.15 sec. BPR loss is 9.81E-01. Sample per second: 82652
# SLIM_BPR_Recommender: Epoch 247 of 445. Elapsed time 15.36 sec
# Processed 12638 (100.0%) in 0.21 sec. BPR loss is 9.87E-01. Sample per second: 59494
# SLIM_BPR_Recommender: Epoch 248 of 445. Elapsed time 15.42 sec
# Processed 12638 (100.0%) in 0.27 sec. BPR loss is 1.04E+00. Sample per second: 46454
# SLIM_BPR_Recommender: Epoch 249 of 445. Elapsed time 15.48 sec
# Processed 12638 (100.0%) in 0.33 sec. BPR loss is 9.82E-01. Sample per second: 37906
# SLIM_BPR_Recommender: Epoch 250 of 445. Elapsed time 15.54 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 9.82E-01. Sample per second: 32187
# SLIM_BPR_Recommender: Epoch 251 of 445. Elapsed time 15.60 sec
# Processed 12638 (100.0%) in 0.45 sec. BPR loss is 1.01E+00. Sample per second: 27773
# SLIM_BPR_Recommender: Epoch 252 of 445. Elapsed time 15.66 sec
# Processed 12638 (100.0%) in 0.52 sec. BPR loss is 1.03E+00. Sample per second: 24334
# SLIM_BPR_Recommender: Epoch 253 of 445. Elapsed time 15.73 sec
# Processed 12638 (100.0%) in 0.60 sec. BPR loss is 1.01E+00. Sample per second: 21083
# SLIM_BPR_Recommender: Epoch 254 of 445. Elapsed time 15.81 sec
# Processed 12638 (100.0%) in 0.66 sec. BPR loss is 1.04E+00. Sample per second: 19139
# SLIM_BPR_Recommender: Epoch 255 of 445. Elapsed time 15.87 sec
# Processed 12638 (100.0%) in 0.72 sec. BPR loss is 1.01E+00. Sample per second: 17509
# SLIM_BPR_Recommender: Epoch 256 of 445. Elapsed time 15.93 sec
# Processed 12638 (100.0%) in 0.78 sec. BPR loss is 9.86E-01. Sample per second: 16158
# SLIM_BPR_Recommender: Epoch 257 of 445. Elapsed time 15.99 sec
# Processed 12638 (100.0%) in 0.84 sec. BPR loss is 1.02E+00. Sample per second: 15018
# SLIM_BPR_Recommender: Epoch 258 of 445. Elapsed time 16.05 sec
# Processed 12638 (100.0%) in 0.90 sec. BPR loss is 1.05E+00. Sample per second: 14014
# SLIM_BPR_Recommender: Epoch 259 of 445. Elapsed time 16.11 sec
# Processed 12638 (100.0%) in 0.96 sec. BPR loss is 1.04E+00. Sample per second: 13122
# SLIM_BPR_Recommender: Epoch 260 of 445. Elapsed time 16.17 sec
# Processed 12638 (100.0%) in 1.02 sec. BPR loss is 1.05E+00. Sample per second: 12339
# SLIM_BPR_Recommender: Epoch 261 of 445. Elapsed time 16.23 sec
# Processed 12638 (100.0%) in 0.08 sec. BPR loss is 1.01E+00. Sample per second: 154802
# SLIM_BPR_Recommender: Epoch 262 of 445. Elapsed time 16.29 sec
# Processed 12638 (100.0%) in 0.14 sec. BPR loss is 1.07E+00. Sample per second: 90762
# SLIM_BPR_Recommender: Epoch 263 of 445. Elapsed time 16.35 sec
# Processed 12638 (100.0%) in 0.20 sec. BPR loss is 9.80E-01. Sample per second: 63366
# SLIM_BPR_Recommender: Epoch 264 of 445. Elapsed time 16.41 sec
# Processed 12638 (100.0%) in 0.26 sec. BPR loss is 1.03E+00. Sample per second: 48960
# SLIM_BPR_Recommender: Epoch 265 of 445. Elapsed time 16.47 sec
# Processed 12638 (100.0%) in 0.32 sec. BPR loss is 1.01E+00. Sample per second: 39991
# SLIM_BPR_Recommender: Epoch 266 of 445. Elapsed time 16.53 sec
# Processed 12638 (100.0%) in 0.37 sec. BPR loss is 1.07E+00. Sample per second: 33860
# SLIM_BPR_Recommender: Epoch 267 of 445. Elapsed time 16.58 sec
# Processed 12638 (100.0%) in 0.43 sec. BPR loss is 1.03E+00. Sample per second: 29221
# SLIM_BPR_Recommender: Epoch 268 of 445. Elapsed time 16.64 sec
# Processed 12638 (100.0%) in 0.49 sec. BPR loss is 1.03E+00. Sample per second: 25693
# SLIM_BPR_Recommender: Epoch 269 of 445. Elapsed time 16.70 sec
# Processed 12638 (100.0%) in 0.55 sec. BPR loss is 1.08E+00. Sample per second: 22964
# SLIM_BPR_Recommender: Epoch 270 of 445. Elapsed time 16.76 sec
# Processed 12638 (100.0%) in 0.61 sec. BPR loss is 1.05E+00. Sample per second: 20733
# SLIM_BPR_Recommender: Epoch 271 of 445. Elapsed time 16.82 sec
# Processed 12638 (100.0%) in 0.67 sec. BPR loss is 1.02E+00. Sample per second: 18978
# SLIM_BPR_Recommender: Epoch 272 of 445. Elapsed time 16.88 sec
# Processed 12638 (100.0%) in 0.72 sec. BPR loss is 1.09E+00. Sample per second: 17428
# SLIM_BPR_Recommender: Epoch 273 of 445. Elapsed time 16.93 sec
# Processed 12638 (100.0%) in 0.78 sec. BPR loss is 1.11E+00. Sample per second: 16146
# SLIM_BPR_Recommender: Epoch 274 of 445. Elapsed time 16.99 sec
# Processed 12638 (100.0%) in 0.84 sec. BPR loss is 1.07E+00. Sample per second: 15036
# SLIM_BPR_Recommender: Epoch 275 of 445. Elapsed time 17.05 sec
# Processed 12638 (100.0%) in 0.90 sec. BPR loss is 1.07E+00. Sample per second: 14065
# SLIM_BPR_Recommender: Epoch 276 of 445. Elapsed time 17.11 sec
# Processed 12638 (100.0%) in 0.96 sec. BPR loss is 1.12E+00. Sample per second: 13192
# SLIM_BPR_Recommender: Epoch 277 of 445. Elapsed time 17.17 sec
# Processed 12638 (100.0%) in 1.02 sec. BPR loss is 1.08E+00. Sample per second: 12432
# SLIM_BPR_Recommender: Epoch 278 of 445. Elapsed time 17.23 sec
# Processed 12638 (100.0%) in 0.08 sec. BPR loss is 1.05E+00. Sample per second: 166390
# SLIM_BPR_Recommender: Epoch 279 of 445. Elapsed time 17.29 sec
# Processed 12638 (100.0%) in 0.13 sec. BPR loss is 1.10E+00. Sample per second: 94053
# SLIM_BPR_Recommender: Epoch 280 of 445. Elapsed time 17.34 sec
# Processed 12638 (100.0%) in 0.20 sec. BPR loss is 1.08E+00. Sample per second: 64367
# SLIM_BPR_Recommender: Epoch 281 of 445. Elapsed time 17.41 sec
# Processed 12638 (100.0%) in 0.27 sec. BPR loss is 1.10E+00. Sample per second: 47379
# SLIM_BPR_Recommender: Epoch 282 of 445. Elapsed time 17.48 sec
# Processed 12638 (100.0%) in 0.33 sec. BPR loss is 1.09E+00. Sample per second: 37839
# SLIM_BPR_Recommender: Epoch 283 of 445. Elapsed time 17.54 sec
# Processed 12638 (100.0%) in 0.40 sec. BPR loss is 1.09E+00. Sample per second: 31389
# SLIM_BPR_Recommender: Epoch 284 of 445. Elapsed time 17.61 sec
# Processed 12638 (100.0%) in 0.47 sec. BPR loss is 1.04E+00. Sample per second: 26959
# SLIM_BPR_Recommender: Epoch 285 of 445. Elapsed time 17.68 sec
# Processed 12638 (100.0%) in 0.54 sec. BPR loss is 1.11E+00. Sample per second: 23459
# SLIM_BPR_Recommender: Epoch 286 of 445. Elapsed time 17.75 sec
# Processed 12638 (100.0%) in 0.61 sec. BPR loss is 1.08E+00. Sample per second: 20697
# SLIM_BPR_Recommender: Epoch 287 of 445. Elapsed time 17.82 sec
# Processed 12638 (100.0%) in 0.68 sec. BPR loss is 1.07E+00. Sample per second: 18539
# SLIM_BPR_Recommender: Epoch 288 of 445. Elapsed time 17.89 sec
# Processed 12638 (100.0%) in 0.75 sec. BPR loss is 1.09E+00. Sample per second: 16819
# SLIM_BPR_Recommender: Epoch 289 of 445. Elapsed time 17.96 sec
# Processed 12638 (100.0%) in 0.82 sec. BPR loss is 1.14E+00. Sample per second: 15396
# SLIM_BPR_Recommender: Epoch 290 of 445. Elapsed time 18.03 sec
# Processed 12638 (100.0%) in 0.89 sec. BPR loss is 1.06E+00. Sample per second: 14228
# SLIM_BPR_Recommender: Epoch 291 of 445. Elapsed time 18.10 sec
# Processed 12638 (100.0%) in 0.96 sec. BPR loss is 1.09E+00. Sample per second: 13168
# SLIM_BPR_Recommender: Epoch 292 of 445. Elapsed time 18.17 sec
# Processed 12638 (100.0%) in 1.03 sec. BPR loss is 1.14E+00. Sample per second: 12282
# SLIM_BPR_Recommender: Epoch 293 of 445. Elapsed time 18.24 sec
# Processed 12638 (100.0%) in 0.09 sec. BPR loss is 1.10E+00. Sample per second: 132934
# SLIM_BPR_Recommender: Epoch 294 of 445. Elapsed time 18.30 sec
# Processed 12638 (100.0%) in 0.15 sec. BPR loss is 1.12E+00. Sample per second: 82382
# SLIM_BPR_Recommender: Epoch 295 of 445. Elapsed time 18.36 sec
# Processed 12638 (100.0%) in 0.22 sec. BPR loss is 1.10E+00. Sample per second: 58687
# SLIM_BPR_Recommender: Epoch 296 of 445. Elapsed time 18.42 sec
# Processed 12638 (100.0%) in 0.28 sec. BPR loss is 1.10E+00. Sample per second: 45655
# SLIM_BPR_Recommender: Epoch 297 of 445. Elapsed time 18.49 sec
# Processed 12638 (100.0%) in 0.34 sec. BPR loss is 1.13E+00. Sample per second: 37699
# SLIM_BPR_Recommender: Epoch 298 of 445. Elapsed time 18.55 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 1.16E+00. Sample per second: 32169
# SLIM_BPR_Recommender: Epoch 299 of 445. Elapsed time 18.60 sec
# Processed 12638 (100.0%) in 0.46 sec. BPR loss is 1.15E+00. Sample per second: 27699
# SLIM_BPR_Recommender: Epoch 300 of 445. Elapsed time 18.67 sec
# Processed 12638 (100.0%) in 0.51 sec. BPR loss is 1.09E+00. Sample per second: 24606
# SLIM_BPR_Recommender: Epoch 301 of 445. Elapsed time 18.72 sec
# Processed 12638 (100.0%) in 0.57 sec. BPR loss is 1.14E+00. Sample per second: 22069
# SLIM_BPR_Recommender: Epoch 302 of 445. Elapsed time 18.78 sec
# Processed 12638 (100.0%) in 0.63 sec. BPR loss is 1.15E+00. Sample per second: 20044
# SLIM_BPR_Recommender: Epoch 303 of 445. Elapsed time 18.84 sec
# Processed 12638 (100.0%) in 0.69 sec. BPR loss is 1.13E+00. Sample per second: 18391
# SLIM_BPR_Recommender: Epoch 304 of 445. Elapsed time 18.90 sec
# Processed 12638 (100.0%) in 0.75 sec. BPR loss is 1.14E+00. Sample per second: 16945
# SLIM_BPR_Recommender: Epoch 305 of 445. Elapsed time 18.96 sec
# Processed 12638 (100.0%) in 0.80 sec. BPR loss is 1.14E+00. Sample per second: 15706
# SLIM_BPR_Recommender: Epoch 306 of 445. Elapsed time 19.01 sec
# Processed 12638 (100.0%) in 0.86 sec. BPR loss is 1.13E+00. Sample per second: 14662
# SLIM_BPR_Recommender: Epoch 307 of 445. Elapsed time 19.07 sec
# Processed 12638 (100.0%) in 0.92 sec. BPR loss is 1.15E+00. Sample per second: 13698
# SLIM_BPR_Recommender: Epoch 308 of 445. Elapsed time 19.13 sec
# Processed 12638 (100.0%) in 0.98 sec. BPR loss is 1.18E+00. Sample per second: 12877
# SLIM_BPR_Recommender: Epoch 309 of 445. Elapsed time 19.19 sec
# Processed 12638 (100.0%) in 1.04 sec. BPR loss is 1.17E+00. Sample per second: 12143
# SLIM_BPR_Recommender: Epoch 310 of 445. Elapsed time 19.25 sec
# Processed 12638 (100.0%) in 0.10 sec. BPR loss is 1.18E+00. Sample per second: 125766
# SLIM_BPR_Recommender: Epoch 311 of 445. Elapsed time 19.31 sec
# Processed 12638 (100.0%) in 0.16 sec. BPR loss is 1.13E+00. Sample per second: 80579
# SLIM_BPR_Recommender: Epoch 312 of 445. Elapsed time 19.37 sec
# Processed 12638 (100.0%) in 0.21 sec. BPR loss is 1.21E+00. Sample per second: 58885
# SLIM_BPR_Recommender: Epoch 313 of 445. Elapsed time 19.43 sec
# Processed 12638 (100.0%) in 0.27 sec. BPR loss is 1.16E+00. Sample per second: 45995
# SLIM_BPR_Recommender: Epoch 314 of 445. Elapsed time 19.48 sec
# Processed 12638 (100.0%) in 0.33 sec. BPR loss is 1.21E+00. Sample per second: 37738
# SLIM_BPR_Recommender: Epoch 315 of 445. Elapsed time 19.54 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 1.16E+00. Sample per second: 32122
# SLIM_BPR_Recommender: Epoch 316 of 445. Elapsed time 19.60 sec
# Processed 12638 (100.0%) in 0.45 sec. BPR loss is 1.23E+00. Sample per second: 27975
# SLIM_BPR_Recommender: Epoch 317 of 445. Elapsed time 19.66 sec
# Processed 12638 (100.0%) in 0.51 sec. BPR loss is 1.15E+00. Sample per second: 24717
# SLIM_BPR_Recommender: Epoch 318 of 445. Elapsed time 19.72 sec
# Processed 12638 (100.0%) in 0.57 sec. BPR loss is 1.20E+00. Sample per second: 22165
# SLIM_BPR_Recommender: Epoch 319 of 445. Elapsed time 19.78 sec
# Processed 12638 (100.0%) in 0.63 sec. BPR loss is 1.15E+00. Sample per second: 20138
# SLIM_BPR_Recommender: Epoch 320 of 445. Elapsed time 19.84 sec
# Processed 12638 (100.0%) in 0.69 sec. BPR loss is 1.18E+00. Sample per second: 18441
# SLIM_BPR_Recommender: Epoch 321 of 445. Elapsed time 19.89 sec
# Processed 12638 (100.0%) in 0.74 sec. BPR loss is 1.15E+00. Sample per second: 17016
# SLIM_BPR_Recommender: Epoch 322 of 445. Elapsed time 19.95 sec
# Processed 12638 (100.0%) in 0.80 sec. BPR loss is 1.18E+00. Sample per second: 15765
# SLIM_BPR_Recommender: Epoch 323 of 445. Elapsed time 20.01 sec
# Processed 12638 (100.0%) in 0.86 sec. BPR loss is 1.21E+00. Sample per second: 14722
# ...
# Processed 12638 (100.0%) in 0.73 sec. BPR loss is 1.20E+00. Sample per second: 17215
# SLIM_BPR_Recommender: Epoch 339 of 445. Elapsed time 20.94 sec
# Processed 12638 (100.0%) in 0.79 sec. BPR loss is 1.21E+00. Sample per second: 15942
# SLIM_BPR_Recommender: Epoch 340 of 445. Elapsed time 21.00 sec
# Processed 12638 (100.0%) in 0.85 sec. BPR loss is 1.20E+00. Sample per second: 14825
# SLIM_BPR_Recommender: Epoch 341 of 445. Elapsed time 21.06 sec
# Processed 12638 (100.0%) in 0.91 sec. BPR loss is 1.24E+00. Sample per second: 13879
# SLIM_BPR_Recommender: Epoch 342 of 445. Elapsed time 21.12 sec
# Processed 12638 (100.0%) in 0.97 sec. BPR loss is 1.24E+00. Sample per second: 13050
# SLIM_BPR_Recommender: Epoch 343 of 445. Elapsed time 21.18 sec
# Processed 12638 (100.0%) in 1.03 sec. BPR loss is 1.24E+00. Sample per second: 12265
# SLIM_BPR_Recommender: Epoch 344 of 445. Elapsed time 21.24 sec
# Processed 12638 (100.0%) in 0.09 sec. BPR loss is 1.24E+00. Sample per second: 141374
# SLIM_BPR_Recommender: Epoch 345 of 445. Elapsed time 21.30 sec
# Processed 12638 (100.0%) in 0.15 sec. BPR loss is 1.25E+00. Sample per second: 84456
# SLIM_BPR_Recommender: Epoch 346 of 445. Elapsed time 21.36 sec
# Processed 12638 (100.0%) in 0.21 sec. BPR loss is 1.24E+00. Sample per second: 60303
# SLIM_BPR_Recommender: Epoch 347 of 445. Elapsed time 21.42 sec
# Processed 12638 (100.0%) in 0.27 sec. BPR loss is 1.30E+00. Sample per second: 46716
# SLIM_BPR_Recommender: Epoch 348 of 445. Elapsed time 21.48 sec
# Processed 12638 (100.0%) in 0.33 sec. BPR loss is 1.25E+00. Sample per second: 38162
# SLIM_BPR_Recommender: Epoch 349 of 445. Elapsed time 21.54 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 1.25E+00. Sample per second: 32268
# SLIM_BPR_Recommender: Epoch 350 of 445. Elapsed time 21.60 sec
# Processed 12638 (100.0%) in 0.45 sec. BPR loss is 1.25E+00. Sample per second: 27854
# SLIM_BPR_Recommender: Epoch 351 of 445. Elapsed time 21.66 sec
# Processed 12638 (100.0%) in 0.51 sec. BPR loss is 1.25E+00. Sample per second: 24598
# SLIM_BPR_Recommender: Epoch 352 of 445. Elapsed time 21.72 sec
# Processed 12638 (100.0%) in 0.58 sec. BPR loss is 1.29E+00. Sample per second: 21931
# SLIM_BPR_Recommender: Epoch 353 of 445. Elapsed time 21.79 sec
# Processed 12638 (100.0%) in 0.64 sec. BPR loss is 1.29E+00. Sample per second: 19844
# SLIM_BPR_Recommender: Epoch 354 of 445. Elapsed time 21.85 sec
# Processed 12638 (100.0%) in 0.70 sec. BPR loss is 1.22E+00. Sample per second: 18047
# SLIM_BPR_Recommender: Epoch 355 of 445. Elapsed time 21.91 sec
# Processed 12638 (100.0%) in 0.76 sec. BPR loss is 1.23E+00. Sample per second: 16566
# SLIM_BPR_Recommender: Epoch 356 of 445. Elapsed time 21.97 sec
# Processed 12638 (100.0%) in 0.83 sec. BPR loss is 1.24E+00. Sample per second: 15306
# SLIM_BPR_Recommender: Epoch 357 of 445. Elapsed time 22.04 sec
# Processed 12638 (100.0%) in 0.89 sec. BPR loss is 1.29E+00. Sample per second: 14240
# SLIM_BPR_Recommender: Epoch 358 of 445. Elapsed time 22.10 sec
# Processed 12638 (100.0%) in 0.95 sec. BPR loss is 1.28E+00. Sample per second: 13328
# SLIM_BPR_Recommender: Epoch 359 of 445. Elapsed time 22.16 sec
# Processed 12638 (100.0%) in 1.01 sec. BPR loss is 1.30E+00. Sample per second: 12535
# SLIM_BPR_Recommender: Epoch 360 of 445. Elapsed time 22.22 sec
# Processed 12638 (100.0%) in 0.07 sec. BPR loss is 1.28E+00. Sample per second: 182721
# SLIM_BPR_Recommender: Epoch 361 of 445. Elapsed time 22.28 sec
# Processed 12638 (100.0%) in 0.13 sec. BPR loss is 1.31E+00. Sample per second: 99555
# SLIM_BPR_Recommender: Epoch 362 of 445. Elapsed time 22.34 sec
# Processed 12638 (100.0%) in 0.19 sec. BPR loss is 1.27E+00. Sample per second: 68236
# SLIM_BPR_Recommender: Epoch 363 of 445. Elapsed time 22.39 sec
# Processed 12638 (100.0%) in 0.24 sec. BPR loss is 1.26E+00. Sample per second: 51558
# SLIM_BPR_Recommender: Epoch 364 of 445. Elapsed time 22.46 sec
# Processed 12638 (100.0%) in 0.31 sec. BPR loss is 1.34E+00. Sample per second: 41368
# SLIM_BPR_Recommender: Epoch 365 of 445. Elapsed time 22.52 sec
# Processed 12638 (100.0%) in 0.37 sec. BPR loss is 1.28E+00. Sample per second: 34535
# SLIM_BPR_Recommender: Epoch 366 of 445. Elapsed time 22.58 sec
# Processed 12638 (100.0%) in 0.43 sec. BPR loss is 1.34E+00. Sample per second: 29419
# SLIM_BPR_Recommender: Epoch 367 of 445. Elapsed time 22.64 sec
# Processed 12638 (100.0%) in 0.49 sec. BPR loss is 1.33E+00. Sample per second: 25723
# SLIM_BPR_Recommender: Epoch 368 of 445. Elapsed time 22.70 sec
# Processed 12638 (100.0%) in 0.55 sec. BPR loss is 1.30E+00. Sample per second: 22898
# SLIM_BPR_Recommender: Epoch 369 of 445. Elapsed time 22.76 sec
# Processed 12638 (100.0%) in 0.61 sec. BPR loss is 1.30E+00. Sample per second: 20573
# SLIM_BPR_Recommender: Epoch 370 of 445. Elapsed time 22.82 sec
# Processed 12638 (100.0%) in 0.68 sec. BPR loss is 1.29E+00. Sample per second: 18710
# SLIM_BPR_Recommender: Epoch 371 of 445. Elapsed time 22.88 sec
# Processed 12638 (100.0%) in 0.74 sec. BPR loss is 1.28E+00. Sample per second: 17150
# SLIM_BPR_Recommender: Epoch 372 of 445. Elapsed time 22.95 sec
# Processed 12638 (100.0%) in 0.80 sec. BPR loss is 1.26E+00. Sample per second: 15829
# SLIM_BPR_Recommender: Epoch 373 of 445. Elapsed time 23.01 sec
# Processed 12638 (100.0%) in 0.86 sec. BPR loss is 1.36E+00. Sample per second: 14717
# SLIM_BPR_Recommender: Epoch 374 of 445. Elapsed time 23.07 sec
# Processed 12638 (100.0%) in 0.92 sec. BPR loss is 1.34E+00. Sample per second: 13747
# SLIM_BPR_Recommender: Epoch 375 of 445. Elapsed time 23.13 sec
# Processed 12638 (100.0%) in 0.98 sec. BPR loss is 1.34E+00. Sample per second: 12919
# SLIM_BPR_Recommender: Epoch 376 of 445. Elapsed time 23.19 sec
# Processed 12638 (100.0%) in 1.04 sec. BPR loss is 1.31E+00. Sample per second: 12190
# SLIM_BPR_Recommender: Epoch 377 of 445. Elapsed time 23.25 sec
# Processed 12638 (100.0%) in 0.10 sec. BPR loss is 1.34E+00. Sample per second: 131976
# SLIM_BPR_Recommender: Epoch 378 of 445. Elapsed time 23.31 sec
# Processed 12638 (100.0%) in 0.15 sec. BPR loss is 1.32E+00. Sample per second: 82245
# SLIM_BPR_Recommender: Epoch 379 of 445. Elapsed time 23.36 sec
# Processed 12638 (100.0%) in 0.21 sec. BPR loss is 1.27E+00. Sample per second: 59506
# SLIM_BPR_Recommender: Epoch 380 of 445. Elapsed time 23.42 sec
# Processed 12638 (100.0%) in 0.27 sec. BPR loss is 1.38E+00. Sample per second: 46371
# SLIM_BPR_Recommender: Epoch 381 of 445. Elapsed time 23.48 sec
# Processed 12638 (100.0%) in 0.33 sec. BPR loss is 1.35E+00. Sample per second: 38081
# SLIM_BPR_Recommender: Epoch 382 of 445. Elapsed time 23.54 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 1.36E+00. Sample per second: 32473
# SLIM_BPR_Recommender: Epoch 383 of 445. Elapsed time 23.60 sec
# Processed 12638 (100.0%) in 0.45 sec. BPR loss is 1.36E+00. Sample per second: 28085
# SLIM_BPR_Recommender: Epoch 384 of 445. Elapsed time 23.66 sec
# Processed 12638 (100.0%) in 0.51 sec. BPR loss is 1.38E+00. Sample per second: 24778
# SLIM_BPR_Recommender: Epoch 385 of 445. Elapsed time 23.72 sec
# Processed 12638 (100.0%) in 0.57 sec. BPR loss is 1.34E+00. Sample per second: 22115
# SLIM_BPR_Recommender: Epoch 386 of 445. Elapsed time 23.78 sec
# Processed 12638 (100.0%) in 0.63 sec. BPR loss is 1.30E+00. Sample per second: 20032
# SLIM_BPR_Recommender: Epoch 387 of 445. Elapsed time 23.84 sec
# Processed 12638 (100.0%) in 0.69 sec. BPR loss is 1.30E+00. Sample per second: 18309
# SLIM_BPR_Recommender: Epoch 388 of 445. Elapsed time 23.90 sec
# Processed 12638 (100.0%) in 0.75 sec. BPR loss is 1.36E+00. Sample per second: 16804
# SLIM_BPR_Recommender: Epoch 389 of 445. Elapsed time 23.96 sec
# Processed 12638 (100.0%) in 0.81 sec. BPR loss is 1.32E+00. Sample per second: 15590
# SLIM_BPR_Recommender: Epoch 390 of 445. Elapsed time 24.02 sec
# Processed 12638 (100.0%) in 0.87 sec. BPR loss is 1.36E+00. Sample per second: 14551
# SLIM_BPR_Recommender: Epoch 391 of 445. Elapsed time 24.08 sec
# Processed 12638 (100.0%) in 0.93 sec. BPR loss is 1.37E+00. Sample per second: 13621
# SLIM_BPR_Recommender: Epoch 392 of 445. Elapsed time 24.14 sec
# Processed 12638 (100.0%) in 0.99 sec. BPR loss is 1.37E+00. Sample per second: 12804
# SLIM_BPR_Recommender: Epoch 393 of 445. Elapsed time 24.20 sec
# Processed 12638 (100.0%) in 1.05 sec. BPR loss is 1.33E+00. Sample per second: 12089
# SLIM_BPR_Recommender: Epoch 394 of 445. Elapsed time 24.25 sec
# Processed 12638 (100.0%) in 0.10 sec. BPR loss is 1.41E+00. Sample per second: 121962
# SLIM_BPR_Recommender: Epoch 395 of 445. Elapsed time 24.31 sec
# Processed 12638 (100.0%) in 0.16 sec. BPR loss is 1.34E+00. Sample per second: 77365
# SLIM_BPR_Recommender: Epoch 396 of 445. Elapsed time 24.37 sec
# Processed 12638 (100.0%) in 0.22 sec. BPR loss is 1.36E+00. Sample per second: 56501
# SLIM_BPR_Recommender: Epoch 397 of 445. Elapsed time 24.43 sec
# Processed 12638 (100.0%) in 0.28 sec. BPR loss is 1.42E+00. Sample per second: 44596
# SLIM_BPR_Recommender: Epoch 398 of 445. Elapsed time 24.49 sec
# Processed 12638 (100.0%) in 0.34 sec. BPR loss is 1.35E+00. Sample per second: 36749
# SLIM_BPR_Recommender: Epoch 399 of 445. Elapsed time 24.55 sec
# Processed 12638 (100.0%) in 0.40 sec. BPR loss is 1.35E+00. Sample per second: 31428
# SLIM_BPR_Recommender: Epoch 400 of 445. Elapsed time 24.61 sec
# Processed 12638 (100.0%) in 0.46 sec. BPR loss is 1.34E+00. Sample per second: 27381
# SLIM_BPR_Recommender: Epoch 401 of 445. Elapsed time 24.67 sec
# Processed 12638 (100.0%) in 0.52 sec. BPR loss is 1.36E+00. Sample per second: 24268
# SLIM_BPR_Recommender: Epoch 402 of 445. Elapsed time 24.73 sec
# Processed 12638 (100.0%) in 0.58 sec. BPR loss is 1.36E+00. Sample per second: 21767
# SLIM_BPR_Recommender: Epoch 403 of 445. Elapsed time 24.79 sec
# Processed 12638 (100.0%) in 0.64 sec. BPR loss is 1.41E+00. Sample per second: 19725
# SLIM_BPR_Recommender: Epoch 404 of 445. Elapsed time 24.85 sec
# Processed 12638 (100.0%) in 0.70 sec. BPR loss is 1.41E+00. Sample per second: 18065
# SLIM_BPR_Recommender: Epoch 405 of 445. Elapsed time 24.91 sec
# Processed 12638 (100.0%) in 0.76 sec. BPR loss is 1.36E+00. Sample per second: 16591
# SLIM_BPR_Recommender: Epoch 406 of 445. Elapsed time 24.97 sec
# Processed 12638 (100.0%) in 0.82 sec. BPR loss is 1.41E+00. Sample per second: 15407
# SLIM_BPR_Recommender: Epoch 407 of 445. Elapsed time 25.03 sec
# Processed 12638 (100.0%) in 0.88 sec. BPR loss is 1.43E+00. Sample per second: 14372
# SLIM_BPR_Recommender: Epoch 408 of 445. Elapsed time 25.09 sec
# Processed 12638 (100.0%) in 0.94 sec. BPR loss is 1.36E+00. Sample per second: 13455
# SLIM_BPR_Recommender: Epoch 409 of 445. Elapsed time 25.15 sec
# Processed 12638 (100.0%) in 1.00 sec. BPR loss is 1.44E+00. Sample per second: 12606
# SLIM_BPR_Recommender: Epoch 410 of 445. Elapsed time 25.21 sec
# Processed 12638 (100.0%) in 0.06 sec. BPR loss is 1.40E+00. Sample per second: 196026
# SLIM_BPR_Recommender: Epoch 411 of 445. Elapsed time 25.27 sec
# Processed 12638 (100.0%) in 0.12 sec. BPR loss is 1.40E+00. Sample per second: 101722
# SLIM_BPR_Recommender: Epoch 412 of 445. Elapsed time 25.33 sec
# Processed 12638 (100.0%) in 0.18 sec. BPR loss is 1.41E+00. Sample per second: 69130
# SLIM_BPR_Recommender: Epoch 413 of 445. Elapsed time 25.39 sec
# Processed 12638 (100.0%) in 0.24 sec. BPR loss is 1.36E+00. Sample per second: 51815
# SLIM_BPR_Recommender: Epoch 414 of 445. Elapsed time 25.45 sec
# Processed 12638 (100.0%) in 0.30 sec. BPR loss is 1.44E+00. Sample per second: 41570
# SLIM_BPR_Recommender: Epoch 415 of 445. Elapsed time 25.51 sec
# Processed 12638 (100.0%) in 0.36 sec. BPR loss is 1.43E+00. Sample per second: 34626
# SLIM_BPR_Recommender: Epoch 416 of 445. Elapsed time 25.57 sec
# Processed 12638 (100.0%) in 0.42 sec. BPR loss is 1.38E+00. Sample per second: 29841
# SLIM_BPR_Recommender: Epoch 417 of 445. Elapsed time 25.63 sec
# Processed 12638 (100.0%) in 0.49 sec. BPR loss is 1.42E+00. Sample per second: 25805
# SLIM_BPR_Recommender: Epoch 418 of 445. Elapsed time 25.70 sec
# Processed 12638 (100.0%) in 0.56 sec. BPR loss is 1.46E+00. Sample per second: 22476
# SLIM_BPR_Recommender: Epoch 419 of 445. Elapsed time 25.77 sec
# Processed 12638 (100.0%) in 0.63 sec. BPR loss is 1.41E+00. Sample per second: 19947
# SLIM_BPR_Recommender: Epoch 420 of 445. Elapsed time 25.84 sec
# Processed 12638 (100.0%) in 0.69 sec. BPR loss is 1.42E+00. Sample per second: 18263
# SLIM_BPR_Recommender: Epoch 421 of 445. Elapsed time 25.90 sec
# Processed 12638 (100.0%) in 0.75 sec. BPR loss is 1.38E+00. Sample per second: 16759
# SLIM_BPR_Recommender: Epoch 422 of 445. Elapsed time 25.96 sec
# Processed 12638 (100.0%) in 0.81 sec. BPR loss is 1.43E+00. Sample per second: 15508
# SLIM_BPR_Recommender: Epoch 423 of 445. Elapsed time 26.02 sec
# Processed 12638 (100.0%) in 0.88 sec. BPR loss is 1.37E+00. Sample per second: 14421
# SLIM_BPR_Recommender: Epoch 424 of 445. Elapsed time 26.09 sec
# Processed 12638 (100.0%) in 0.94 sec. BPR loss is 1.42E+00. Sample per second: 13460
# SLIM_BPR_Recommender: Epoch 425 of 445. Elapsed time 26.15 sec
# Processed 12638 (100.0%) in 1.00 sec. BPR loss is 1.45E+00. Sample per second: 12657
# SLIM_BPR_Recommender: Epoch 426 of 445. Elapsed time 26.21 sec
# Processed 12638 (100.0%) in 0.06 sec. BPR loss is 1.40E+00. Sample per second: 227658
# SLIM_BPR_Recommender: Epoch 427 of 445. Elapsed time 26.26 sec
# Processed 12638 (100.0%) in 0.11 sec. BPR loss is 1.43E+00. Sample per second: 112304
# SLIM_BPR_Recommender: Epoch 428 of 445. Elapsed time 26.32 sec
# Processed 12638 (100.0%) in 0.17 sec. BPR loss is 1.38E+00. Sample per second: 74139
# SLIM_BPR_Recommender: Epoch 429 of 445. Elapsed time 26.38 sec
# Processed 12638 (100.0%) in 0.23 sec. BPR loss is 1.46E+00. Sample per second: 54958
# SLIM_BPR_Recommender: Epoch 430 of 445. Elapsed time 26.44 sec
# Processed 12638 (100.0%) in 0.29 sec. BPR loss is 1.43E+00. Sample per second: 43802
# SLIM_BPR_Recommender: Epoch 431 of 445. Elapsed time 26.50 sec
# Processed 12638 (100.0%) in 0.35 sec. BPR loss is 1.47E+00. Sample per second: 36475
# SLIM_BPR_Recommender: Epoch 432 of 445. Elapsed time 26.56 sec
# Processed 12638 (100.0%) in 0.40 sec. BPR loss is 1.48E+00. Sample per second: 31280
# SLIM_BPR_Recommender: Epoch 433 of 445. Elapsed time 26.61 sec
# Processed 12638 (100.0%) in 0.46 sec. BPR loss is 1.49E+00. Sample per second: 27253
# SLIM_BPR_Recommender: Epoch 434 of 445. Elapsed time 26.67 sec
# Processed 12638 (100.0%) in 0.52 sec. BPR loss is 1.48E+00. Sample per second: 24156
# SLIM_BPR_Recommender: Epoch 435 of 445. Elapsed time 26.73 sec
# Processed 12638 (100.0%) in 0.58 sec. BPR loss is 1.46E+00. Sample per second: 21657
# SLIM_BPR_Recommender: Epoch 436 of 445. Elapsed time 26.79 sec
# Processed 12638 (100.0%) in 0.64 sec. BPR loss is 1.45E+00. Sample per second: 19704
# SLIM_BPR_Recommender: Epoch 437 of 445. Elapsed time 26.85 sec
# Processed 12638 (100.0%) in 0.70 sec. BPR loss is 1.51E+00. Sample per second: 18027
# SLIM_BPR_Recommender: Epoch 438 of 445. Elapsed time 26.91 sec
# Processed 12638 (100.0%) in 0.76 sec. BPR loss is 1.44E+00. Sample per second: 16555
# SLIM_BPR_Recommender: Epoch 439 of 445. Elapsed time 26.97 sec
# Processed 12638 (100.0%) in 0.82 sec. BPR loss is 1.51E+00. Sample per second: 15339
# SLIM_BPR_Recommender: Epoch 440 of 445. Elapsed time 27.03 sec
# Processed 12638 (100.0%) in 0.89 sec. BPR loss is 1.49E+00. Sample per second: 14245
# SLIM_BPR_Recommender: Epoch 441 of 445. Elapsed time 27.10 sec
# Processed 12638 (100.0%) in 0.95 sec. BPR loss is 1.50E+00. Sample per second: 13326
# SLIM_BPR_Recommender: Epoch 442 of 445. Elapsed time 27.16 sec
# Processed 12638 (100.0%) in 1.01 sec. BPR loss is 1.56E+00. Sample per second: 12518
# SLIM_BPR_Recommender: Epoch 443 of 445. Elapsed time 27.22 sec
# Processed 12638 (100.0%) in 0.07 sec. BPR loss is 1.46E+00. Sample per second: 176229
# SLIM_BPR_Recommender: Epoch 444 of 445. Elapsed time 27.28 sec
# Processed 12638 (100.0%) in 0.13 sec. BPR loss is 1.48E+00. Sample per second: 95250
# SLIM_BPR_Recommender: Epoch 445 of 445. Elapsed time 27.34 sec
# SLIM_BPR_Recommender: Terminating at epoch 445. Elapsed time 38.39 sec
# Deallocating Cython objects

# %%
P3aRecall=P3alphaRecommender(URM_train)
P3aRecall.fit(**best_pars_recall_dict["P3alphaRecommender"])
# Out:
# P3alphaRecommender: URM Detected 166 ( 1.3%) users with no interactions.
# P3alphaRecommender: URM Detected 63 ( 0.3%) items with no interactions.
# P3alphaRecommender: Similarity column 22222 (100.0%), 892.51 column/sec. Elapsed time 24.90 sec

# %%
P3a=P3alphaRecommender(URM_train)
P3a.fit(**best_pars_dict["P3alphaRecommender"])
# Out:
# P3alphaRecommender: URM Detected 166 ( 1.3%) users with no interactions.
# P3alphaRecommender: URM Detected 63 ( 0.3%) items with no interactions.
# P3alphaRecommender: Similarity column 22222 (100.0%), 3250.93 column/sec. Elapsed time 6.84 sec

# %%
IALSrec = IALSRecommender(URM_train)
IALSrec.fit(**best_pars_dict["IALSRecommender"])
# Out:
# IALSRecommender: URM Detected 166 ( 1.3%) users with no interactions.
# IALSRecommender: URM Detected 63 ( 0.3%) items with no interactions.
# IALSRecommender: Epoch 1 of 10. Elapsed time 1.44 min
# IALSRecommender: Epoch 2 of 10. Elapsed time 2.93 min
# IALSRecommender: Epoch 3 of 10. Elapsed time 4.39 min
# IALSRecommender: Epoch 4 of 10. Elapsed time 5.86 min
# IALSRecommender: Epoch 5 of 10. Elapsed time 7.30 min
# IALSRecommender: Epoch 6 of 10. Elapsed time 8.76 min
# IALSRecommender: Epoch 7 of 10. Elapsed time 10.23 min
# IALSRecommender: Epoch 8 of 10. Elapsed time 11.66 min
# IALSRecommender: Epoch 9 of 10. Elapsed time 13.13 min
# IALSRecommender: Epoch 10 of 10. Elapsed time 14.59 min
# IALSRecommender: Terminating at epoch 10. Elapsed time 14.59 min

# %%
new_similarityRecall = 0.3648920858420368 * SLIM_ElasticRecall.W_sparse + 0.30413965737024856 * RP3BetaRecall.W_sparse + 0.053940767085383985 * item_knnRecall.W_sparse + 0.27702748970233065 * P3aRecall.W_sparse
candidate_gen = ItemKNNCustomSimilarityRecommender(URM_train)
candidate_gen.fit(new_similarityRecall)
# Out:
# ItemKNNCustomSimilarityRecommender: URM Detected 166 ( 1.3%) users with no interactions.
# ItemKNNCustomSimilarityRecommender: URM Detected 63 ( 0.3%) items with no interactions.

# %%
other_algorithms = {
    "TopPop": topPop,
    "RP3beta": RP3Beta,
    "SLIM": SLIM_Elastic,
    "KNN": item_knn,
    "EASER": ease_r,
    "best_hybrid": best_hybrid,
    "SLIMbpr":SLIM_bpr,
    "P3alpha":P3a,
    "IALS": IALSrec,
    "candidate_generator": candidate_gen
}

# %%
cutoff = 249
n_estimators = 1323
learning_rate =0.03253703223058349
reg_alpha = 26.431827628978155
reg_lambda = 0.11504013550215164
max_depth = 2
max_leaves = 8
grow_policy = "depthwise"
objective = "pairwise"
booster = "gbtree"
random_seed = None


training_dataframe=create_dataframe_with_label(URM_train,URM_test,other_algorithms,cutoff)
groups = training_dataframe.groupby("UserID").size().values

y_train = training_dataframe["Label"]
X_train = training_dataframe.drop(columns=["Label"])

X_train["UserID"] = X_train["UserID"].astype("category")
X_train["ItemID"] = X_train["ItemID"].astype("category")


XGB_model = XGBRanker(objective='rank:{}'.format(objective),
    n_estimators = int(n_estimators),
    random_state = random_seed,
    learning_rate = learning_rate,
    reg_alpha = reg_alpha,
    reg_lambda = reg_lambda,
    max_depth = int(max_depth),
    max_leaves = int(max_leaves),
    grow_policy = grow_policy,
    verbosity = 0, # 2 if self.verbose else 0,
    booster = booster,
    enable_categorical = True,
    tree_method = "hist",  # Supported tree methods are `gpu_hist`, `approx`, and `hist`.
    )

XGB_model.fit(X_train,
    y_train,
    group=groups,
    verbose=True)
# Out:
# 100%|██████████| 12638/12638 [00:17<00:00, 737.50it/s]
# 100%|██████████| 12638/12638 [02:38<00:00, 79.55it/s]
# XGBRanker(base_score=None, booster='gbtree', callbacks=None,
#           colsample_bylevel=None, colsample_bynode=None, colsample_bytree=None,
#           device=None, early_stopping_rounds=None, enable_categorical=True,
#           eval_metric=None, feature_types=None, gamma=None,
#           grow_policy='depthwise', importance_type=None,
#           interaction_constraints=None, learning_rate=0.03253703223058349,
#           max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#           max_delta_step=None, max_depth=2, max_leaves=8, min_child_weight=None,
#           missing=nan, monotone_constraints=None, multi_strategy=None,
#           n_estimators=1323, n_jobs=None, num_parallel_tree=None,
#           objective='rank:pairwise', ...)

# %% [markdown]
# ## Generate submission

# %%
SLIM_ElasticRecall = SLIMElasticNetRecommender(URM_all)
SLIM_ElasticRecall.fit(**best_pars_recall_dict["SLIMElasticNetRecommender"]
    
)
# Out:
# SLIMElasticNetRecommender: Processed 7104 (32.0%) in 5.00 min. Items per second: 23.67
# SLIMElasticNetRecommender: Processed 15128 (68.1%) in 10.00 min. Items per second: 25.21
# SLIMElasticNetRecommender: Processed 22222 (100.0%) in 14.11 min. Items per second: 26.25

# %%
SLIM_Elastic = SLIMElasticNetRecommender(URM_all)
SLIM_Elastic.fit(**best_pars_dict["SLIMElasticNetRecommender"]
    
)
# Out:
# SLIMElasticNetRecommender: Processed 9107 (41.0%) in 5.00 min. Items per second: 30.35
# SLIMElasticNetRecommender: Processed 19396 (87.3%) in 10.00 min. Items per second: 32.32
# SLIMElasticNetRecommender: Processed 22222 (100.0%) in 11.12 min. Items per second: 33.29

# %%
RP3Beta = RP3betaRecommender(URM_all)
RP3Beta.fit(
    **best_pars_dict["RP3betaRecommender"]
)
# Out:
# RP3betaRecommender: Similarity column 22222 (100.0%), 3116.43 column/sec. Elapsed time 7.13 sec

# %%
RP3BetaRecall = RP3betaRecommender(URM_all)
RP3BetaRecall.fit(
    **best_pars_recall_dict["RP3betaRecommender"]
)
# Out:
# RP3betaRecommender: Similarity column 22222 (100.0%), 1311.66 column/sec. Elapsed time 16.94 sec

# %%
P3aRecall=P3alphaRecommender(URM_all)
P3aRecall.fit(**best_pars_recall_dict["P3alphaRecommender"])
# Out:
# P3alphaRecommender: Similarity column 22222 (100.0%), 803.27 column/sec. Elapsed time 27.66 sec

# %%
topPop = TopPop(URM_all)
topPop.fit()

# %%
item_knn = ItemKNNCFRecommender(URM_all)
item_knn.fit(**best_pars_dict["ItemKNNCFRecommender"])
# Out:
# Similarity column 22222 (100.0%), 4194.95 column/sec. Elapsed time 5.30 sec

# %%
item_knnRecall = ItemKNNCFRecommender(URM_all)
item_knnRecall.fit(**best_pars_recall_dict["ItemKNNCFRecommender"])
# Out:
# Similarity column 22222 (100.0%), 4224.07 column/sec. Elapsed time 5.26 sec

# %%
ease_r = EASE_R_Recommender(URM_all)
ease_r.fit(**best_pars_dict["EASE_R_Recommender"])
# Out:
# EASE_R_Recommender: Fitting model...
# EASE_R_Recommender: Fitting model... done in 7.46 min

# %%
new_similarity = 0.6 * SLIM_Elastic.W_sparse + 0.2 * RP3Beta.W_sparse + 0.2 * item_knn.W_sparse
best_hybrid = ItemKNNCustomSimilarityRecommender(URM_all)
best_hybrid.fit(new_similarity)

# %%
SLIM_bpr=SLIM_BPR_Cython(URM_all)
SLIM_bpr.fit(**best_pars_dict["SLIM_BPR_Cython"])
# Out:
# SLIM_BPR_Recommender: Automatic selection of fastest train mode. Available RAM is 25585.00 MB (79.68%) of 32110.00 MB, required is 1975.27 MB. Using dense matrix.
# Processed 12638 (100.0%) in 0.86 sec. BPR loss is 6.05E-03. Sample per second: 14690
# SLIM_BPR_Recommender: Epoch 1 of 445. Elapsed time 0.07 sec
# Processed 12638 (100.0%) in 0.93 sec. BPR loss is 1.65E-02. Sample per second: 13629
# SLIM_BPR_Recommender: Epoch 2 of 445. Elapsed time 0.14 sec
# Processed 12638 (100.0%) in 1.00 sec. BPR loss is 2.95E-02. Sample per second: 12691
# SLIM_BPR_Recommender: Epoch 3 of 445. Elapsed time 0.21 sec
# Processed 12638 (100.0%) in 1.07 sec. BPR loss is 3.73E-02. Sample per second: 11830
# SLIM_BPR_Recommender: Epoch 4 of 445. Elapsed time 0.28 sec
# Processed 12638 (100.0%) in 0.14 sec. BPR loss is 4.88E-02. Sample per second: 91239
# SLIM_BPR_Recommender: Epoch 5 of 445. Elapsed time 0.35 sec
# Processed 12638 (100.0%) in 0.21 sec. BPR loss is 5.66E-02. Sample per second: 58812
# SLIM_BPR_Recommender: Epoch 6 of 445. Elapsed time 0.43 sec
# Processed 12638 (100.0%) in 0.29 sec. BPR loss is 7.17E-02. Sample per second: 44209
# SLIM_BPR_Recommender: Epoch 7 of 445. Elapsed time 0.50 sec
# Processed 12638 (100.0%) in 0.36 sec. BPR loss is 8.10E-02. Sample per second: 35363
# SLIM_BPR_Recommender: Epoch 8 of 445. Elapsed time 0.57 sec
# Processed 12638 (100.0%) in 0.43 sec. BPR loss is 9.34E-02. Sample per second: 29450
# SLIM_BPR_Recommender: Epoch 9 of 445. Elapsed time 0.64 sec
# Processed 12638 (100.0%) in 0.50 sec. BPR loss is 1.03E-01. Sample per second: 25296
# SLIM_BPR_Recommender: Epoch 10 of 445. Elapsed time 0.71 sec
# Processed 12638 (100.0%) in 0.57 sec. BPR loss is 1.11E-01. Sample per second: 22143
# SLIM_BPR_Recommender: Epoch 11 of 445. Elapsed time 0.78 sec
# Processed 12638 (100.0%) in 0.64 sec. BPR loss is 1.18E-01. Sample per second: 19721
# SLIM_BPR_Recommender: Epoch 12 of 445. Elapsed time 0.85 sec
# Processed 12638 (100.0%) in 0.71 sec. BPR loss is 1.41E-01. Sample per second: 17816
# SLIM_BPR_Recommender: Epoch 13 of 445. Elapsed time 0.92 sec
# Processed 12638 (100.0%) in 0.78 sec. BPR loss is 1.39E-01. Sample per second: 16221
# SLIM_BPR_Recommender: Epoch 14 of 445. Elapsed time 0.99 sec
# Processed 12638 (100.0%) in 0.85 sec. BPR loss is 1.53E-01. Sample per second: 14894
# SLIM_BPR_Recommender: Epoch 15 of 445. Elapsed time 1.06 sec
# Processed 12638 (100.0%) in 0.92 sec. BPR loss is 1.59E-01. Sample per second: 13804
# SLIM_BPR_Recommender: Epoch 16 of 445. Elapsed time 1.13 sec
# Processed 12638 (100.0%) in 0.99 sec. BPR loss is 1.70E-01. Sample per second: 12812
# SLIM_BPR_Recommender: Epoch 17 of 445. Elapsed time 1.20 sec
# Processed 12638 (100.0%) in 1.05 sec. BPR loss is 1.67E-01. Sample per second: 11981
# SLIM_BPR_Recommender: Epoch 18 of 445. Elapsed time 1.27 sec
# Processed 12638 (100.0%) in 0.12 sec. BPR loss is 1.84E-01. Sample per second: 101923
# SLIM_BPR_Recommender: Epoch 19 of 445. Elapsed time 1.33 sec
# Processed 12638 (100.0%) in 0.19 sec. BPR loss is 1.97E-01. Sample per second: 66808
# SLIM_BPR_Recommender: Epoch 20 of 445. Elapsed time 1.40 sec
# Processed 12638 (100.0%) in 0.26 sec. BPR loss is 2.08E-01. Sample per second: 48865
# SLIM_BPR_Recommender: Epoch 21 of 445. Elapsed time 1.47 sec
# Processed 12638 (100.0%) in 0.33 sec. BPR loss is 2.23E-01. Sample per second: 38461
# SLIM_BPR_Recommender: Epoch 22 of 445. Elapsed time 1.54 sec
# Processed 12638 (100.0%) in 0.40 sec. BPR loss is 2.13E-01. Sample per second: 31544
# SLIM_BPR_Recommender: Epoch 23 of 445. Elapsed time 1.61 sec
# Processed 12638 (100.0%) in 0.47 sec. BPR loss is 2.18E-01. Sample per second: 26625
# SLIM_BPR_Recommender: Epoch 24 of 445. Elapsed time 1.69 sec
# Processed 12638 (100.0%) in 0.55 sec. BPR loss is 2.36E-01. Sample per second: 23106
# SLIM_BPR_Recommender: Epoch 25 of 445. Elapsed time 1.76 sec
# Processed 12638 (100.0%) in 0.63 sec. BPR loss is 2.38E-01. Sample per second: 20047
# SLIM_BPR_Recommender: Epoch 26 of 445. Elapsed time 1.84 sec
# Processed 12638 (100.0%) in 0.70 sec. BPR loss is 2.55E-01. Sample per second: 18106
# SLIM_BPR_Recommender: Epoch 27 of 445. Elapsed time 1.91 sec
# Processed 12638 (100.0%) in 0.77 sec. BPR loss is 2.80E-01. Sample per second: 16486
# SLIM_BPR_Recommender: Epoch 28 of 445. Elapsed time 1.98 sec
# Processed 12638 (100.0%) in 0.83 sec. BPR loss is 2.80E-01. Sample per second: 15137
# SLIM_BPR_Recommender: Epoch 29 of 445. Elapsed time 2.05 sec
# Processed 12638 (100.0%) in 0.91 sec. BPR loss is 2.79E-01. Sample per second: 13951
# SLIM_BPR_Recommender: Epoch 30 of 445. Elapsed time 2.12 sec
# Processed 12638 (100.0%) in 0.97 sec. BPR loss is 2.90E-01. Sample per second: 12965
# SLIM_BPR_Recommender: Epoch 31 of 445. Elapsed time 2.19 sec
# Processed 12638 (100.0%) in 1.04 sec. BPR loss is 3.01E-01. Sample per second: 12135
# SLIM_BPR_Recommender: Epoch 32 of 445. Elapsed time 2.25 sec
# Processed 12638 (100.0%) in 0.11 sec. BPR loss is 2.98E-01. Sample per second: 114055
# SLIM_BPR_Recommender: Epoch 33 of 445. Elapsed time 2.32 sec
# Processed 12638 (100.0%) in 0.18 sec. BPR loss is 3.10E-01. Sample per second: 70633
# SLIM_BPR_Recommender: Epoch 34 of 445. Elapsed time 2.39 sec
# Processed 12638 (100.0%) in 0.25 sec. BPR loss is 2.89E-01. Sample per second: 50132
# SLIM_BPR_Recommender: Epoch 35 of 445. Elapsed time 2.46 sec
# Processed 12638 (100.0%) in 0.32 sec. BPR loss is 3.40E-01. Sample per second: 39118
# SLIM_BPR_Recommender: Epoch 36 of 445. Elapsed time 2.53 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 3.37E-01. Sample per second: 32267
# SLIM_BPR_Recommender: Epoch 37 of 445. Elapsed time 2.60 sec
# Processed 12638 (100.0%) in 0.46 sec. BPR loss is 3.29E-01. Sample per second: 27321
# SLIM_BPR_Recommender: Epoch 38 of 445. Elapsed time 2.67 sec
# Processed 12638 (100.0%) in 0.53 sec. BPR loss is 3.67E-01. Sample per second: 23773
# SLIM_BPR_Recommender: Epoch 39 of 445. Elapsed time 2.74 sec
# Processed 12638 (100.0%) in 0.60 sec. BPR loss is 3.64E-01. Sample per second: 20996
# SLIM_BPR_Recommender: Epoch 40 of 445. Elapsed time 2.81 sec
# Processed 12638 (100.0%) in 0.67 sec. BPR loss is 3.69E-01. Sample per second: 18865
# SLIM_BPR_Recommender: Epoch 41 of 445. Elapsed time 2.88 sec
# Processed 12638 (100.0%) in 0.74 sec. BPR loss is 3.66E-01. Sample per second: 17150
# SLIM_BPR_Recommender: Epoch 42 of 445. Elapsed time 2.95 sec
# Processed 12638 (100.0%) in 0.80 sec. BPR loss is 3.72E-01. Sample per second: 15719
# SLIM_BPR_Recommender: Epoch 43 of 445. Elapsed time 3.02 sec
# Processed 12638 (100.0%) in 0.87 sec. BPR loss is 3.84E-01. Sample per second: 14500
# SLIM_BPR_Recommender: Epoch 44 of 445. Elapsed time 3.08 sec
# Processed 12638 (100.0%) in 0.94 sec. BPR loss is 4.12E-01. Sample per second: 13455
# SLIM_BPR_Recommender: Epoch 45 of 445. Elapsed time 3.15 sec
# Processed 12638 (100.0%) in 1.01 sec. BPR loss is 4.19E-01. Sample per second: 12527
# SLIM_BPR_Recommender: Epoch 46 of 445. Elapsed time 3.22 sec
# Processed 12638 (100.0%) in 0.08 sec. BPR loss is 4.01E-01. Sample per second: 161525
# SLIM_BPR_Recommender: Epoch 47 of 445. Elapsed time 3.29 sec
# Processed 12638 (100.0%) in 0.15 sec. BPR loss is 4.07E-01. Sample per second: 86803
# SLIM_BPR_Recommender: Epoch 48 of 445. Elapsed time 3.36 sec
# Processed 12638 (100.0%) in 0.21 sec. BPR loss is 4.09E-01. Sample per second: 58961
# SLIM_BPR_Recommender: Epoch 49 of 445. Elapsed time 3.43 sec
# Processed 12638 (100.0%) in 0.28 sec. BPR loss is 4.45E-01. Sample per second: 44638
# SLIM_BPR_Recommender: Epoch 50 of 445. Elapsed time 3.49 sec
# Processed 12638 (100.0%) in 0.35 sec. BPR loss is 4.40E-01. Sample per second: 35801
# SLIM_BPR_Recommender: Epoch 51 of 445. Elapsed time 3.56 sec
# Processed 12638 (100.0%) in 0.42 sec. BPR loss is 4.27E-01. Sample per second: 29981
# SLIM_BPR_Recommender: Epoch 52 of 445. Elapsed time 3.63 sec
# Processed 12638 (100.0%) in 0.49 sec. BPR loss is 4.42E-01. Sample per second: 25721
# SLIM_BPR_Recommender: Epoch 53 of 445. Elapsed time 3.70 sec
# Processed 12638 (100.0%) in 0.56 sec. BPR loss is 4.51E-01. Sample per second: 22472
# SLIM_BPR_Recommender: Epoch 54 of 445. Elapsed time 3.77 sec
# Processed 12638 (100.0%) in 0.63 sec. BPR loss is 4.45E-01. Sample per second: 19925
# SLIM_BPR_Recommender: Epoch 55 of 445. Elapsed time 3.84 sec
# Processed 12638 (100.0%) in 0.70 sec. BPR loss is 4.49E-01. Sample per second: 17927
# SLIM_BPR_Recommender: Epoch 56 of 445. Elapsed time 3.92 sec
# Processed 12638 (100.0%) in 0.78 sec. BPR loss is 4.99E-01. Sample per second: 16285
# SLIM_BPR_Recommender: Epoch 57 of 445. Elapsed time 3.99 sec
# Processed 12638 (100.0%) in 0.85 sec. BPR loss is 5.08E-01. Sample per second: 14926
# SLIM_BPR_Recommender: Epoch 58 of 445. Elapsed time 4.06 sec
# Processed 12638 (100.0%) in 0.92 sec. BPR loss is 4.92E-01. Sample per second: 13799
# SLIM_BPR_Recommender: Epoch 59 of 445. Elapsed time 4.13 sec
# Processed 12638 (100.0%) in 0.98 sec. BPR loss is 4.92E-01. Sample per second: 12828
# SLIM_BPR_Recommender: Epoch 60 of 445. Elapsed time 4.20 sec
# Processed 12638 (100.0%) in 1.05 sec. BPR loss is 5.00E-01. Sample per second: 11991
# SLIM_BPR_Recommender: Epoch 61 of 445. Elapsed time 4.26 sec
# Processed 12638 (100.0%) in 0.12 sec. BPR loss is 4.86E-01. Sample per second: 103946
# SLIM_BPR_Recommender: Epoch 62 of 445. Elapsed time 4.33 sec
# Processed 12638 (100.0%) in 0.19 sec. BPR loss is 5.19E-01. Sample per second: 65850
# SLIM_BPR_Recommender: Epoch 63 of 445. Elapsed time 4.40 sec
# Processed 12638 (100.0%) in 0.26 sec. BPR loss is 5.35E-01. Sample per second: 47836
# SLIM_BPR_Recommender: Epoch 64 of 445. Elapsed time 4.48 sec
# Processed 12638 (100.0%) in 0.34 sec. BPR loss is 4.97E-01. Sample per second: 37566
# SLIM_BPR_Recommender: Epoch 65 of 445. Elapsed time 4.55 sec
# Processed 12638 (100.0%) in 0.41 sec. BPR loss is 5.33E-01. Sample per second: 31072
# SLIM_BPR_Recommender: Epoch 66 of 445. Elapsed time 4.62 sec
# Processed 12638 (100.0%) in 0.47 sec. BPR loss is 5.30E-01. Sample per second: 26701
# SLIM_BPR_Recommender: Epoch 67 of 445. Elapsed time 4.68 sec
# Processed 12638 (100.0%) in 0.54 sec. BPR loss is 5.33E-01. Sample per second: 23329
# SLIM_BPR_Recommender: Epoch 68 of 445. Elapsed time 4.75 sec
# Processed 12638 (100.0%) in 0.61 sec. BPR loss is 5.61E-01. Sample per second: 20698
# SLIM_BPR_Recommender: Epoch 69 of 445. Elapsed time 4.82 sec
# Processed 12638 (100.0%) in 0.68 sec. BPR loss is 5.65E-01. Sample per second: 18605
# SLIM_BPR_Recommender: Epoch 70 of 445. Elapsed time 4.89 sec
# Processed 12638 (100.0%) in 0.75 sec. BPR loss is 5.91E-01. Sample per second: 16959
# SLIM_BPR_Recommender: Epoch 71 of 445. Elapsed time 4.96 sec
# Processed 12638 (100.0%) in 0.81 sec. BPR loss is 5.88E-01. Sample per second: 15561
# SLIM_BPR_Recommender: Epoch 72 of 445. Elapsed time 5.02 sec
# Processed 12638 (100.0%) in 0.88 sec. BPR loss is 5.95E-01. Sample per second: 14364
# SLIM_BPR_Recommender: Epoch 73 of 445. Elapsed time 5.09 sec
# Processed 12638 (100.0%) in 0.95 sec. BPR loss is 6.00E-01. Sample per second: 13349
# SLIM_BPR_Recommender: Epoch 74 of 445. Elapsed time 5.16 sec
# Processed 12638 (100.0%) in 1.01 sec. BPR loss is 5.89E-01. Sample per second: 12453
# SLIM_BPR_Recommender: Epoch 75 of 445. Elapsed time 5.23 sec
# Processed 12638 (100.0%) in 0.09 sec. BPR loss is 5.81E-01. Sample per second: 146482
# SLIM_BPR_Recommender: Epoch 76 of 445. Elapsed time 5.30 sec
# Processed 12638 (100.0%) in 0.16 sec. BPR loss is 5.77E-01. Sample per second: 79168
# SLIM_BPR_Recommender: Epoch 77 of 445. Elapsed time 5.37 sec
# Processed 12638 (100.0%) in 0.23 sec. BPR loss is 6.03E-01. Sample per second: 55020
# SLIM_BPR_Recommender: Epoch 78 of 445. Elapsed time 5.44 sec
# Processed 12638 (100.0%) in 0.30 sec. BPR loss is 6.31E-01. Sample per second: 41856
# SLIM_BPR_Recommender: Epoch 79 of 445. Elapsed time 5.51 sec
# Processed 12638 (100.0%) in 0.37 sec. BPR loss is 6.20E-01. Sample per second: 33914
# SLIM_BPR_Recommender: Epoch 80 of 445. Elapsed time 5.59 sec
# Processed 12638 (100.0%) in 0.44 sec. BPR loss is 6.03E-01. Sample per second: 28423
# SLIM_BPR_Recommender: Epoch 81 of 445. Elapsed time 5.66 sec
# Processed 12638 (100.0%) in 0.52 sec. BPR loss is 6.46E-01. Sample per second: 24451
# SLIM_BPR_Recommender: Epoch 82 of 445. Elapsed time 5.73 sec
# Processed 12638 (100.0%) in 0.59 sec. BPR loss is 6.13E-01. Sample per second: 21522
# SLIM_BPR_Recommender: Epoch 83 of 445. Elapsed time 5.80 sec
# Processed 12638 (100.0%) in 0.66 sec. BPR loss is 6.36E-01. Sample per second: 19240
# SLIM_BPR_Recommender: Epoch 84 of 445. Elapsed time 5.87 sec
# Processed 12638 (100.0%) in 0.72 sec. BPR loss is 6.15E-01. Sample per second: 17443
# SLIM_BPR_Recommender: Epoch 85 of 445. Elapsed time 5.94 sec
# Processed 12638 (100.0%) in 0.79 sec. BPR loss is 6.52E-01. Sample per second: 15941
# SLIM_BPR_Recommender: Epoch 86 of 445. Elapsed time 6.00 sec
# Processed 12638 (100.0%) in 0.86 sec. BPR loss is 6.54E-01. Sample per second: 14689
# SLIM_BPR_Recommender: Epoch 87 of 445. Elapsed time 6.07 sec
# Processed 12638 (100.0%) in 0.93 sec. BPR loss is 6.69E-01. Sample per second: 13595
# SLIM_BPR_Recommender: Epoch 88 of 445. Elapsed time 6.14 sec
# Processed 12638 (100.0%) in 1.00 sec. BPR loss is 6.81E-01. Sample per second: 12630
# SLIM_BPR_Recommender: Epoch 89 of 445. Elapsed time 6.21 sec
# Processed 12638 (100.0%) in 0.07 sec. BPR loss is 6.66E-01. Sample per second: 180093
# SLIM_BPR_Recommender: Epoch 90 of 445. Elapsed time 6.28 sec
# Processed 12638 (100.0%) in 0.14 sec. BPR loss is 6.47E-01. Sample per second: 89940
# SLIM_BPR_Recommender: Epoch 91 of 445. Elapsed time 6.35 sec
# Processed 12638 (100.0%) in 0.21 sec. BPR loss is 6.63E-01. Sample per second: 60144
# SLIM_BPR_Recommender: Epoch 92 of 445. Elapsed time 6.42 sec
# Processed 12638 (100.0%) in 0.28 sec. BPR loss is 6.56E-01. Sample per second: 44681
# SLIM_BPR_Recommender: Epoch 93 of 445. Elapsed time 6.49 sec
# Processed 12638 (100.0%) in 0.35 sec. BPR loss is 6.87E-01. Sample per second: 35729
# SLIM_BPR_Recommender: Epoch 94 of 445. Elapsed time 6.56 sec
# Processed 12638 (100.0%) in 0.42 sec. BPR loss is 6.74E-01. Sample per second: 29984
# SLIM_BPR_Recommender: Epoch 95 of 445. Elapsed time 6.63 sec
# Processed 12638 (100.0%) in 0.49 sec. BPR loss is 7.37E-01. Sample per second: 25661
# SLIM_BPR_Recommender: Epoch 96 of 445. Elapsed time 6.70 sec
# Processed 12638 (100.0%) in 0.57 sec. BPR loss is 6.93E-01. Sample per second: 22294
# SLIM_BPR_Recommender: Epoch 97 of 445. Elapsed time 6.78 sec
# Processed 12638 (100.0%) in 0.64 sec. BPR loss is 7.02E-01. Sample per second: 19867
# SLIM_BPR_Recommender: Epoch 98 of 445. Elapsed time 6.85 sec
# Processed 12638 (100.0%) in 0.71 sec. BPR loss is 7.26E-01. Sample per second: 17891
# SLIM_BPR_Recommender: Epoch 99 of 445. Elapsed time 6.92 sec
# Processed 12638 (100.0%) in 0.77 sec. BPR loss is 7.35E-01. Sample per second: 16315
# SLIM_BPR_Recommender: Epoch 100 of 445. Elapsed time 6.99 sec
# Processed 12638 (100.0%) in 0.85 sec. BPR loss is 7.35E-01. Sample per second: 14918
# SLIM_BPR_Recommender: Epoch 101 of 445. Elapsed time 7.06 sec
# Processed 12638 (100.0%) in 0.92 sec. BPR loss is 7.51E-01. Sample per second: 13772
# SLIM_BPR_Recommender: Epoch 102 of 445. Elapsed time 7.13 sec
# Processed 12638 (100.0%) in 0.99 sec. BPR loss is 7.17E-01. Sample per second: 12805
# SLIM_BPR_Recommender: Epoch 103 of 445. Elapsed time 7.20 sec
# Processed 12638 (100.0%) in 1.06 sec. BPR loss is 7.37E-01. Sample per second: 11959
# SLIM_BPR_Recommender: Epoch 104 of 445. Elapsed time 7.27 sec
# Processed 12638 (100.0%) in 0.13 sec. BPR loss is 7.72E-01. Sample per second: 99358
# SLIM_BPR_Recommender: Epoch 105 of 445. Elapsed time 7.34 sec
# Processed 12638 (100.0%) in 0.19 sec. BPR loss is 7.39E-01. Sample per second: 64855
# SLIM_BPR_Recommender: Epoch 106 of 445. Elapsed time 7.41 sec
# Processed 12638 (100.0%) in 0.27 sec. BPR loss is 7.74E-01. Sample per second: 47276
# SLIM_BPR_Recommender: Epoch 107 of 445. Elapsed time 7.48 sec
# Processed 12638 (100.0%) in 0.34 sec. BPR loss is 7.47E-01. Sample per second: 37216
# SLIM_BPR_Recommender: Epoch 108 of 445. Elapsed time 7.55 sec
# Processed 12638 (100.0%) in 0.41 sec. BPR loss is 8.02E-01. Sample per second: 30771
# SLIM_BPR_Recommender: Epoch 109 of 445. Elapsed time 7.62 sec
# Processed 12638 (100.0%) in 0.48 sec. BPR loss is 7.74E-01. Sample per second: 26202
# SLIM_BPR_Recommender: Epoch 110 of 445. Elapsed time 7.69 sec
# Processed 12638 (100.0%) in 0.55 sec. BPR loss is 7.79E-01. Sample per second: 22752
# SLIM_BPR_Recommender: Epoch 111 of 445. Elapsed time 7.77 sec
# Processed 12638 (100.0%) in 0.63 sec. BPR loss is 8.03E-01. Sample per second: 20193
# SLIM_BPR_Recommender: Epoch 112 of 445. Elapsed time 7.84 sec
# Processed 12638 (100.0%) in 0.69 sec. BPR loss is 8.04E-01. Sample per second: 18182
# SLIM_BPR_Recommender: Epoch 113 of 445. Elapsed time 7.91 sec
# Processed 12638 (100.0%) in 0.76 sec. BPR loss is 7.56E-01. Sample per second: 16545
# SLIM_BPR_Recommender: Epoch 114 of 445. Elapsed time 7.97 sec
# Processed 12638 (100.0%) in 0.84 sec. BPR loss is 8.15E-01. Sample per second: 15109
# SLIM_BPR_Recommender: Epoch 115 of 445. Elapsed time 8.05 sec
# Processed 12638 (100.0%) in 0.91 sec. BPR loss is 8.23E-01. Sample per second: 13943
# SLIM_BPR_Recommender: Epoch 116 of 445. Elapsed time 8.12 sec
# Processed 12638 (100.0%) in 0.97 sec. BPR loss is 8.36E-01. Sample per second: 12972
# SLIM_BPR_Recommender: Epoch 117 of 445. Elapsed time 8.19 sec
# Processed 12638 (100.0%) in 1.04 sec. BPR loss is 8.25E-01. Sample per second: 12104
# SLIM_BPR_Recommender: Epoch 118 of 445. Elapsed time 8.25 sec
# Processed 12638 (100.0%) in 0.11 sec. BPR loss is 8.00E-01. Sample per second: 112152
# SLIM_BPR_Recommender: Epoch 119 of 445. Elapsed time 8.32 sec
# Processed 12638 (100.0%) in 0.18 sec. BPR loss is 8.57E-01. Sample per second: 69522
# SLIM_BPR_Recommender: Epoch 120 of 445. Elapsed time 8.39 sec
# Processed 12638 (100.0%) in 0.25 sec. BPR loss is 8.44E-01. Sample per second: 50004
# SLIM_BPR_Recommender: Epoch 121 of 445. Elapsed time 8.46 sec
# Processed 12638 (100.0%) in 0.32 sec. BPR loss is 8.24E-01. Sample per second: 39440
# SLIM_BPR_Recommender: Epoch 122 of 445. Elapsed time 8.53 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 8.14E-01. Sample per second: 32553
# SLIM_BPR_Recommender: Epoch 123 of 445. Elapsed time 8.60 sec
# Processed 12638 (100.0%) in 0.45 sec. BPR loss is 8.87E-01. Sample per second: 27813
# SLIM_BPR_Recommender: Epoch 124 of 445. Elapsed time 8.67 sec
# Processed 12638 (100.0%) in 0.52 sec. BPR loss is 8.55E-01. Sample per second: 24253
# SLIM_BPR_Recommender: Epoch 125 of 445. Elapsed time 8.73 sec
# Processed 12638 (100.0%) in 0.59 sec. BPR loss is 8.70E-01. Sample per second: 21359
# SLIM_BPR_Recommender: Epoch 126 of 445. Elapsed time 8.80 sec
# Processed 12638 (100.0%) in 0.66 sec. BPR loss is 8.78E-01. Sample per second: 19081
# SLIM_BPR_Recommender: Epoch 127 of 445. Elapsed time 8.87 sec
# Processed 12638 (100.0%) in 0.73 sec. BPR loss is 8.91E-01. Sample per second: 17257
# SLIM_BPR_Recommender: Epoch 128 of 445. Elapsed time 8.94 sec
# Processed 12638 (100.0%) in 0.80 sec. BPR loss is 8.41E-01. Sample per second: 15737
# SLIM_BPR_Recommender: Epoch 129 of 445. Elapsed time 9.01 sec
# Processed 12638 (100.0%) in 0.87 sec. BPR loss is 8.76E-01. Sample per second: 14527
# SLIM_BPR_Recommender: Epoch 130 of 445. Elapsed time 9.08 sec
# Processed 12638 (100.0%) in 0.94 sec. BPR loss is 8.67E-01. Sample per second: 13482
# SLIM_BPR_Recommender: Epoch 131 of 445. Elapsed time 9.15 sec
# Processed 12638 (100.0%) in 1.01 sec. BPR loss is 9.00E-01. Sample per second: 12557
# SLIM_BPR_Recommender: Epoch 132 of 445. Elapsed time 9.22 sec
# Processed 12638 (100.0%) in 0.08 sec. BPR loss is 9.20E-01. Sample per second: 166663
# SLIM_BPR_Recommender: Epoch 133 of 445. Elapsed time 9.29 sec
# Processed 12638 (100.0%) in 0.14 sec. BPR loss is 9.21E-01. Sample per second: 87704
# SLIM_BPR_Recommender: Epoch 134 of 445. Elapsed time 9.36 sec
# Processed 12638 (100.0%) in 0.21 sec. BPR loss is 8.83E-01. Sample per second: 59698
# SLIM_BPR_Recommender: Epoch 135 of 445. Elapsed time 9.42 sec
# Processed 12638 (100.0%) in 0.28 sec. BPR loss is 9.30E-01. Sample per second: 44684
# SLIM_BPR_Recommender: Epoch 136 of 445. Elapsed time 9.49 sec
# Processed 12638 (100.0%) in 0.35 sec. BPR loss is 8.91E-01. Sample per second: 36055
# SLIM_BPR_Recommender: Epoch 137 of 445. Elapsed time 9.56 sec
# Processed 12638 (100.0%) in 0.42 sec. BPR loss is 9.21E-01. Sample per second: 30019
# SLIM_BPR_Recommender: Epoch 138 of 445. Elapsed time 9.63 sec
# Processed 12638 (100.0%) in 0.49 sec. BPR loss is 9.72E-01. Sample per second: 25929
# SLIM_BPR_Recommender: Epoch 139 of 445. Elapsed time 9.70 sec
# Processed 12638 (100.0%) in 0.56 sec. BPR loss is 9.19E-01. Sample per second: 22746
# SLIM_BPR_Recommender: Epoch 140 of 445. Elapsed time 9.77 sec
# Processed 12638 (100.0%) in 0.62 sec. BPR loss is 9.17E-01. Sample per second: 20222
# SLIM_BPR_Recommender: Epoch 141 of 445. Elapsed time 9.84 sec
# Processed 12638 (100.0%) in 0.69 sec. BPR loss is 9.28E-01. Sample per second: 18229
# SLIM_BPR_Recommender: Epoch 142 of 445. Elapsed time 9.90 sec
# Processed 12638 (100.0%) in 0.76 sec. BPR loss is 9.84E-01. Sample per second: 16554
# SLIM_BPR_Recommender: Epoch 143 of 445. Elapsed time 9.97 sec
# Processed 12638 (100.0%) in 0.83 sec. BPR loss is 9.12E-01. Sample per second: 15187
# SLIM_BPR_Recommender: Epoch 144 of 445. Elapsed time 10.04 sec
# Processed 12638 (100.0%) in 0.90 sec. BPR loss is 9.73E-01. Sample per second: 14014
# SLIM_BPR_Recommender: Epoch 145 of 445. Elapsed time 10.11 sec
# Processed 12638 (100.0%) in 0.97 sec. BPR loss is 9.55E-01. Sample per second: 13037
# SLIM_BPR_Recommender: Epoch 146 of 445. Elapsed time 10.18 sec
# Processed 12638 (100.0%) in 1.04 sec. BPR loss is 9.93E-01. Sample per second: 12176
# SLIM_BPR_Recommender: Epoch 147 of 445. Elapsed time 10.25 sec
# Processed 12638 (100.0%) in 0.11 sec. BPR loss is 9.49E-01. Sample per second: 118252
# SLIM_BPR_Recommender: Epoch 148 of 445. Elapsed time 10.32 sec
# Processed 12638 (100.0%) in 0.17 sec. BPR loss is 9.72E-01. Sample per second: 72293
# SLIM_BPR_Recommender: Epoch 149 of 445. Elapsed time 10.39 sec
# Processed 12638 (100.0%) in 0.25 sec. BPR loss is 1.01E+00. Sample per second: 51271
# SLIM_BPR_Recommender: Epoch 150 of 445. Elapsed time 10.46 sec
# Processed 12638 (100.0%) in 0.32 sec. BPR loss is 9.39E-01. Sample per second: 39883
# SLIM_BPR_Recommender: Epoch 151 of 445. Elapsed time 10.53 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 9.72E-01. Sample per second: 32607
# SLIM_BPR_Recommender: Epoch 152 of 445. Elapsed time 10.60 sec
# Processed 12638 (100.0%) in 0.46 sec. BPR loss is 9.34E-01. Sample per second: 27708
# SLIM_BPR_Recommender: Epoch 153 of 445. Elapsed time 10.67 sec
# Processed 12638 (100.0%) in 0.52 sec. BPR loss is 9.74E-01. Sample per second: 24096
# SLIM_BPR_Recommender: Epoch 154 of 445. Elapsed time 10.74 sec
# Processed 12638 (100.0%) in 0.59 sec. BPR loss is 1.02E+00. Sample per second: 21242
# SLIM_BPR_Recommender: Epoch 155 of 445. Elapsed time 10.81 sec
# Processed 12638 (100.0%) in 0.66 sec. BPR loss is 1.05E+00. Sample per second: 19108
# SLIM_BPR_Recommender: Epoch 156 of 445. Elapsed time 10.87 sec
# Processed 12638 (100.0%) in 0.73 sec. BPR loss is 9.71E-01. Sample per second: 17361
# SLIM_BPR_Recommender: Epoch 157 of 445. Elapsed time 10.94 sec
# Processed 12638 (100.0%) in 0.79 sec. BPR loss is 1.03E+00. Sample per second: 15899
# SLIM_BPR_Recommender: Epoch 158 of 445. Elapsed time 11.01 sec
# Processed 12638 (100.0%) in 0.86 sec. BPR loss is 1.00E+00. Sample per second: 14633
# SLIM_BPR_Recommender: Epoch 159 of 445. Elapsed time 11.07 sec
# Processed 12638 (100.0%) in 0.94 sec. BPR loss is 1.01E+00. Sample per second: 13506
# SLIM_BPR_Recommender: Epoch 160 of 445. Elapsed time 11.15 sec
# Processed 12638 (100.0%) in 1.01 sec. BPR loss is 1.08E+00. Sample per second: 12571
# SLIM_BPR_Recommender: Epoch 161 of 445. Elapsed time 11.22 sec
# Processed 12638 (100.0%) in 0.08 sec. BPR loss is 1.03E+00. Sample per second: 165901
# SLIM_BPR_Recommender: Epoch 162 of 445. Elapsed time 11.29 sec
# Processed 12638 (100.0%) in 0.14 sec. BPR loss is 1.07E+00. Sample per second: 87056
# SLIM_BPR_Recommender: Epoch 163 of 445. Elapsed time 11.36 sec
# Processed 12638 (100.0%) in 0.21 sec. BPR loss is 1.01E+00. Sample per second: 59661
# SLIM_BPR_Recommender: Epoch 164 of 445. Elapsed time 11.42 sec
# Processed 12638 (100.0%) in 0.28 sec. BPR loss is 1.04E+00. Sample per second: 44691
# SLIM_BPR_Recommender: Epoch 165 of 445. Elapsed time 11.49 sec
# Processed 12638 (100.0%) in 0.35 sec. BPR loss is 1.07E+00. Sample per second: 35796
# SLIM_BPR_Recommender: Epoch 166 of 445. Elapsed time 11.56 sec
# Processed 12638 (100.0%) in 0.42 sec. BPR loss is 1.07E+00. Sample per second: 29943
# SLIM_BPR_Recommender: Epoch 167 of 445. Elapsed time 11.63 sec
# Processed 12638 (100.0%) in 0.50 sec. BPR loss is 1.03E+00. Sample per second: 25489
# SLIM_BPR_Recommender: Epoch 168 of 445. Elapsed time 11.71 sec
# Processed 12638 (100.0%) in 0.59 sec. BPR loss is 1.00E+00. Sample per second: 21582
# SLIM_BPR_Recommender: Epoch 169 of 445. Elapsed time 11.80 sec
# Processed 12638 (100.0%) in 0.66 sec. BPR loss is 1.04E+00. Sample per second: 19128
# SLIM_BPR_Recommender: Epoch 170 of 445. Elapsed time 11.87 sec
# Processed 12638 (100.0%) in 0.73 sec. BPR loss is 1.10E+00. Sample per second: 17234
# SLIM_BPR_Recommender: Epoch 171 of 445. Elapsed time 11.94 sec
# Processed 12638 (100.0%) in 0.80 sec. BPR loss is 1.05E+00. Sample per second: 15725
# SLIM_BPR_Recommender: Epoch 172 of 445. Elapsed time 12.01 sec
# Processed 12638 (100.0%) in 0.87 sec. BPR loss is 1.07E+00. Sample per second: 14459
# SLIM_BPR_Recommender: Epoch 173 of 445. Elapsed time 12.08 sec
# Processed 12638 (100.0%) in 0.94 sec. BPR loss is 1.05E+00. Sample per second: 13384
# SLIM_BPR_Recommender: Epoch 174 of 445. Elapsed time 12.16 sec
# Processed 12638 (100.0%) in 1.02 sec. BPR loss is 1.06E+00. Sample per second: 12439
# SLIM_BPR_Recommender: Epoch 175 of 445. Elapsed time 12.23 sec
# Processed 12638 (100.0%) in 0.09 sec. BPR loss is 1.12E+00. Sample per second: 145599
# SLIM_BPR_Recommender: Epoch 176 of 445. Elapsed time 12.30 sec
# Processed 12638 (100.0%) in 0.16 sec. BPR loss is 1.10E+00. Sample per second: 80153
# SLIM_BPR_Recommender: Epoch 177 of 445. Elapsed time 12.37 sec
# Processed 12638 (100.0%) in 0.23 sec. BPR loss is 1.13E+00. Sample per second: 55596
# SLIM_BPR_Recommender: Epoch 178 of 445. Elapsed time 12.44 sec
# Processed 12638 (100.0%) in 0.30 sec. BPR loss is 1.03E+00. Sample per second: 42447
# SLIM_BPR_Recommender: Epoch 179 of 445. Elapsed time 12.51 sec
# Processed 12638 (100.0%) in 0.36 sec. BPR loss is 1.13E+00. Sample per second: 34723
# SLIM_BPR_Recommender: Epoch 180 of 445. Elapsed time 12.57 sec
# Processed 12638 (100.0%) in 0.43 sec. BPR loss is 1.15E+00. Sample per second: 29181
# SLIM_BPR_Recommender: Epoch 181 of 445. Elapsed time 12.64 sec
# Processed 12638 (100.0%) in 0.50 sec. BPR loss is 1.11E+00. Sample per second: 25207
# SLIM_BPR_Recommender: Epoch 182 of 445. Elapsed time 12.71 sec
# Processed 12638 (100.0%) in 0.57 sec. BPR loss is 1.08E+00. Sample per second: 22065
# SLIM_BPR_Recommender: Epoch 183 of 445. Elapsed time 12.78 sec
# Processed 12638 (100.0%) in 0.64 sec. BPR loss is 1.10E+00. Sample per second: 19631
# SLIM_BPR_Recommender: Epoch 184 of 445. Elapsed time 12.85 sec
# Processed 12638 (100.0%) in 0.72 sec. BPR loss is 1.11E+00. Sample per second: 17656
# SLIM_BPR_Recommender: Epoch 185 of 445. Elapsed time 12.93 sec
# Processed 12638 (100.0%) in 0.78 sec. BPR loss is 1.10E+00. Sample per second: 16101
# SLIM_BPR_Recommender: Epoch 186 of 445. Elapsed time 13.00 sec
# Processed 12638 (100.0%) in 0.86 sec. BPR loss is 1.19E+00. Sample per second: 14768
# SLIM_BPR_Recommender: Epoch 187 of 445. Elapsed time 13.07 sec
# Processed 12638 (100.0%) in 0.93 sec. BPR loss is 1.17E+00. Sample per second: 13597
# SLIM_BPR_Recommender: Epoch 188 of 445. Elapsed time 13.14 sec
# Processed 12638 (100.0%) in 1.00 sec. BPR loss is 1.13E+00. Sample per second: 12587
# SLIM_BPR_Recommender: Epoch 189 of 445. Elapsed time 13.22 sec
# Processed 12638 (100.0%) in 0.08 sec. BPR loss is 1.13E+00. Sample per second: 156000
# SLIM_BPR_Recommender: Epoch 190 of 445. Elapsed time 13.29 sec
# Processed 12638 (100.0%) in 0.16 sec. BPR loss is 1.12E+00. Sample per second: 80698
# SLIM_BPR_Recommender: Epoch 191 of 445. Elapsed time 13.37 sec
# Processed 12638 (100.0%) in 0.23 sec. BPR loss is 1.14E+00. Sample per second: 54440
# SLIM_BPR_Recommender: Epoch 192 of 445. Elapsed time 13.44 sec
# Processed 12638 (100.0%) in 0.31 sec. BPR loss is 1.17E+00. Sample per second: 40852
# SLIM_BPR_Recommender: Epoch 193 of 445. Elapsed time 13.52 sec
# Processed 12638 (100.0%) in 0.38 sec. BPR loss is 1.20E+00. Sample per second: 32776
# SLIM_BPR_Recommender: Epoch 194 of 445. Elapsed time 13.60 sec
# Processed 12638 (100.0%) in 0.46 sec. BPR loss is 1.15E+00. Sample per second: 27379
# SLIM_BPR_Recommender: Epoch 195 of 445. Elapsed time 13.67 sec
# Processed 12638 (100.0%) in 0.54 sec. BPR loss is 1.20E+00. Sample per second: 23481
# SLIM_BPR_Recommender: Epoch 196 of 445. Elapsed time 13.75 sec
# Processed 12638 (100.0%) in 0.62 sec. BPR loss is 1.17E+00. Sample per second: 20436
# SLIM_BPR_Recommender: Epoch 197 of 445. Elapsed time 13.83 sec
# Processed 12638 (100.0%) in 0.70 sec. BPR loss is 1.16E+00. Sample per second: 18147
# SLIM_BPR_Recommender: Epoch 198 of 445. Elapsed time 13.91 sec
# Processed 12638 (100.0%) in 0.77 sec. BPR loss is 1.23E+00. Sample per second: 16325
# SLIM_BPR_Recommender: Epoch 199 of 445. Elapsed time 13.99 sec
# Processed 12638 (100.0%) in 0.84 sec. BPR loss is 1.19E+00. Sample per second: 14956
# SLIM_BPR_Recommender: Epoch 200 of 445. Elapsed time 14.06 sec
# Processed 12638 (100.0%) in 0.91 sec. BPR loss is 1.20E+00. Sample per second: 13826
# SLIM_BPR_Recommender: Epoch 201 of 445. Elapsed time 14.13 sec
# Processed 12638 (100.0%) in 0.98 sec. BPR loss is 1.22E+00. Sample per second: 12846
# SLIM_BPR_Recommender: Epoch 202 of 445. Elapsed time 14.19 sec
# Processed 12638 (100.0%) in 1.05 sec. BPR loss is 1.27E+00. Sample per second: 12011
# SLIM_BPR_Recommender: Epoch 203 of 445. Elapsed time 14.26 sec
# Processed 12638 (100.0%) in 0.12 sec. BPR loss is 1.19E+00. Sample per second: 105435
# SLIM_BPR_Recommender: Epoch 204 of 445. Elapsed time 14.33 sec
# Processed 12638 (100.0%) in 0.19 sec. BPR loss is 1.26E+00. Sample per second: 66227
# SLIM_BPR_Recommender: Epoch 205 of 445. Elapsed time 14.40 sec
# Processed 12638 (100.0%) in 0.26 sec. BPR loss is 1.26E+00. Sample per second: 48496
# SLIM_BPR_Recommender: Epoch 206 of 445. Elapsed time 14.47 sec
# Processed 12638 (100.0%) in 0.33 sec. BPR loss is 1.23E+00. Sample per second: 38573
# SLIM_BPR_Recommender: Epoch 207 of 445. Elapsed time 14.54 sec
# Processed 12638 (100.0%) in 0.40 sec. BPR loss is 1.22E+00. Sample per second: 31923
# SLIM_BPR_Recommender: Epoch 208 of 445. Elapsed time 14.61 sec
# Processed 12638 (100.0%) in 0.46 sec. BPR loss is 1.23E+00. Sample per second: 27308
# SLIM_BPR_Recommender: Epoch 209 of 445. Elapsed time 14.67 sec
# Processed 12638 (100.0%) in 0.53 sec. BPR loss is 1.21E+00. Sample per second: 23832
# SLIM_BPR_Recommender: Epoch 210 of 445. Elapsed time 14.74 sec
# Processed 12638 (100.0%) in 0.60 sec. BPR loss is 1.29E+00. Sample per second: 21077
# SLIM_BPR_Recommender: Epoch 211 of 445. Elapsed time 14.81 sec
# Processed 12638 (100.0%) in 0.67 sec. BPR loss is 1.24E+00. Sample per second: 18939
# SLIM_BPR_Recommender: Epoch 212 of 445. Elapsed time 14.88 sec
# Processed 12638 (100.0%) in 0.74 sec. BPR loss is 1.20E+00. Sample per second: 17161
# SLIM_BPR_Recommender: Epoch 213 of 445. Elapsed time 14.95 sec
# Processed 12638 (100.0%) in 0.80 sec. BPR loss is 1.21E+00. Sample per second: 15754
# SLIM_BPR_Recommender: Epoch 214 of 445. Elapsed time 15.01 sec
# Processed 12638 (100.0%) in 0.87 sec. BPR loss is 1.22E+00. Sample per second: 14522
# SLIM_BPR_Recommender: Epoch 215 of 445. Elapsed time 15.08 sec
# Processed 12638 (100.0%) in 0.94 sec. BPR loss is 1.24E+00. Sample per second: 13501
# SLIM_BPR_Recommender: Epoch 216 of 445. Elapsed time 15.15 sec
# Processed 12638 (100.0%) in 1.00 sec. BPR loss is 1.27E+00. Sample per second: 12599
# SLIM_BPR_Recommender: Epoch 217 of 445. Elapsed time 15.21 sec
# Processed 12638 (100.0%) in 0.07 sec. BPR loss is 1.28E+00. Sample per second: 176038
# SLIM_BPR_Recommender: Epoch 218 of 445. Elapsed time 15.28 sec
# Processed 12638 (100.0%) in 0.14 sec. BPR loss is 1.28E+00. Sample per second: 87525
# SLIM_BPR_Recommender: Epoch 219 of 445. Elapsed time 15.36 sec
# Processed 12638 (100.0%) in 0.22 sec. BPR loss is 1.27E+00. Sample per second: 58682
# SLIM_BPR_Recommender: Epoch 220 of 445. Elapsed time 15.43 sec
# Processed 12638 (100.0%) in 0.29 sec. BPR loss is 1.33E+00. Sample per second: 43862
# SLIM_BPR_Recommender: Epoch 221 of 445. Elapsed time 15.50 sec
# Processed 12638 (100.0%) in 0.36 sec. BPR loss is 1.26E+00. Sample per second: 35434
# SLIM_BPR_Recommender: Epoch 222 of 445. Elapsed time 15.57 sec
# Processed 12638 (100.0%) in 0.42 sec. BPR loss is 1.29E+00. Sample per second: 29746
# SLIM_BPR_Recommender: Epoch 223 of 445. Elapsed time 15.64 sec
# Processed 12638 (100.0%) in 0.49 sec. BPR loss is 1.32E+00. Sample per second: 25649
# SLIM_BPR_Recommender: Epoch 224 of 445. Elapsed time 15.70 sec
# Processed 12638 (100.0%) in 0.56 sec. BPR loss is 1.29E+00. Sample per second: 22540
# SLIM_BPR_Recommender: Epoch 225 of 445. Elapsed time 15.77 sec
# Processed 12638 (100.0%) in 0.63 sec. BPR loss is 1.35E+00. Sample per second: 20006
# SLIM_BPR_Recommender: Epoch 226 of 445. Elapsed time 15.84 sec
# Processed 12638 (100.0%) in 0.70 sec. BPR loss is 1.26E+00. Sample per second: 18018
# SLIM_BPR_Recommender: Epoch 227 of 445. Elapsed time 15.91 sec
# Processed 12638 (100.0%) in 0.77 sec. BPR loss is 1.29E+00. Sample per second: 16398
# SLIM_BPR_Recommender: Epoch 228 of 445. Elapsed time 15.98 sec
# Processed 12638 (100.0%) in 0.84 sec. BPR loss is 1.30E+00. Sample per second: 15047
# SLIM_BPR_Recommender: Epoch 229 of 445. Elapsed time 16.05 sec
# Processed 12638 (100.0%) in 0.91 sec. BPR loss is 1.34E+00. Sample per second: 13920
# SLIM_BPR_Recommender: Epoch 230 of 445. Elapsed time 16.12 sec
# Processed 12638 (100.0%) in 0.98 sec. BPR loss is 1.27E+00. Sample per second: 12937
# SLIM_BPR_Recommender: Epoch 231 of 445. Elapsed time 16.19 sec
# Processed 12638 (100.0%) in 1.04 sec. BPR loss is 1.30E+00. Sample per second: 12102
# SLIM_BPR_Recommender: Epoch 232 of 445. Elapsed time 16.26 sec
# Processed 12638 (100.0%) in 0.11 sec. BPR loss is 1.29E+00. Sample per second: 111002
# SLIM_BPR_Recommender: Epoch 233 of 445. Elapsed time 16.33 sec
# Processed 12638 (100.0%) in 0.18 sec. BPR loss is 1.33E+00. Sample per second: 69009
# SLIM_BPR_Recommender: Epoch 234 of 445. Elapsed time 16.40 sec
# Processed 12638 (100.0%) in 0.25 sec. BPR loss is 1.37E+00. Sample per second: 50202
# SLIM_BPR_Recommender: Epoch 235 of 445. Elapsed time 16.46 sec
# Processed 12638 (100.0%) in 0.32 sec. BPR loss is 1.31E+00. Sample per second: 39239
# SLIM_BPR_Recommender: Epoch 236 of 445. Elapsed time 16.53 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 1.32E+00. Sample per second: 32488
# SLIM_BPR_Recommender: Epoch 237 of 445. Elapsed time 16.60 sec
# Processed 12638 (100.0%) in 0.46 sec. BPR loss is 1.30E+00. Sample per second: 27706
# SLIM_BPR_Recommender: Epoch 238 of 445. Elapsed time 16.67 sec
# Processed 12638 (100.0%) in 0.53 sec. BPR loss is 1.34E+00. Sample per second: 23943
# SLIM_BPR_Recommender: Epoch 239 of 445. Elapsed time 16.74 sec
# Processed 12638 (100.0%) in 0.60 sec. BPR loss is 1.30E+00. Sample per second: 20916
# SLIM_BPR_Recommender: Epoch 240 of 445. Elapsed time 16.82 sec
# Processed 12638 (100.0%) in 0.68 sec. BPR loss is 1.41E+00. Sample per second: 18570
# SLIM_BPR_Recommender: Epoch 241 of 445. Elapsed time 16.89 sec
# Processed 12638 (100.0%) in 0.76 sec. BPR loss is 1.46E+00. Sample per second: 16690
# SLIM_BPR_Recommender: Epoch 242 of 445. Elapsed time 16.97 sec
# Processed 12638 (100.0%) in 0.83 sec. BPR loss is 1.42E+00. Sample per second: 15157
# SLIM_BPR_Recommender: Epoch 243 of 445. Elapsed time 17.04 sec
# Processed 12638 (100.0%) in 0.91 sec. BPR loss is 1.35E+00. Sample per second: 13862
# SLIM_BPR_Recommender: Epoch 244 of 445. Elapsed time 17.12 sec
# Processed 12638 (100.0%) in 0.99 sec. BPR loss is 1.37E+00. Sample per second: 12795
# SLIM_BPR_Recommender: Epoch 245 of 445. Elapsed time 17.20 sec
# Processed 12638 (100.0%) in 1.06 sec. BPR loss is 1.35E+00. Sample per second: 11870
# SLIM_BPR_Recommender: Epoch 246 of 445. Elapsed time 17.28 sec
# Processed 12638 (100.0%) in 0.14 sec. BPR loss is 1.34E+00. Sample per second: 91154
# SLIM_BPR_Recommender: Epoch 247 of 445. Elapsed time 17.35 sec
# Processed 12638 (100.0%) in 0.22 sec. BPR loss is 1.41E+00. Sample per second: 58608
# SLIM_BPR_Recommender: Epoch 248 of 445. Elapsed time 17.43 sec
# Processed 12638 (100.0%) in 0.30 sec. BPR loss is 1.35E+00. Sample per second: 42701
# SLIM_BPR_Recommender: Epoch 249 of 445. Elapsed time 17.51 sec
# Processed 12638 (100.0%) in 0.37 sec. BPR loss is 1.35E+00. Sample per second: 34023
# SLIM_BPR_Recommender: Epoch 250 of 445. Elapsed time 17.58 sec
# Processed 12638 (100.0%) in 0.45 sec. BPR loss is 1.43E+00. Sample per second: 28245
# SLIM_BPR_Recommender: Epoch 251 of 445. Elapsed time 17.66 sec
# Processed 12638 (100.0%) in 0.52 sec. BPR loss is 1.41E+00. Sample per second: 24299
# SLIM_BPR_Recommender: Epoch 252 of 445. Elapsed time 17.73 sec
# Processed 12638 (100.0%) in 0.59 sec. BPR loss is 1.46E+00. Sample per second: 21356
# SLIM_BPR_Recommender: Epoch 253 of 445. Elapsed time 17.80 sec
# Processed 12638 (100.0%) in 0.66 sec. BPR loss is 1.45E+00. Sample per second: 19057
# SLIM_BPR_Recommender: Epoch 254 of 445. Elapsed time 17.87 sec
# Processed 12638 (100.0%) in 0.73 sec. BPR loss is 1.49E+00. Sample per second: 17291
# SLIM_BPR_Recommender: Epoch 255 of 445. Elapsed time 17.94 sec
# Processed 12638 (100.0%) in 0.80 sec. BPR loss is 1.40E+00. Sample per second: 15819
# SLIM_BPR_Recommender: Epoch 256 of 445. Elapsed time 18.01 sec
# Processed 12638 (100.0%) in 0.87 sec. BPR loss is 1.45E+00. Sample per second: 14583
# SLIM_BPR_Recommender: Epoch 257 of 445. Elapsed time 18.08 sec
# Processed 12638 (100.0%) in 0.93 sec. BPR loss is 1.45E+00. Sample per second: 13535
# SLIM_BPR_Recommender: Epoch 258 of 445. Elapsed time 18.15 sec
# Processed 12638 (100.0%) in 1.01 sec. BPR loss is 1.39E+00. Sample per second: 12573
# SLIM_BPR_Recommender: Epoch 259 of 445. Elapsed time 18.22 sec
# Processed 12638 (100.0%) in 0.07 sec. BPR loss is 1.41E+00. Sample per second: 171886
# SLIM_BPR_Recommender: Epoch 260 of 445. Elapsed time 18.28 sec
# Processed 12638 (100.0%) in 0.14 sec. BPR loss is 1.46E+00. Sample per second: 88689
# SLIM_BPR_Recommender: Epoch 261 of 445. Elapsed time 18.35 sec
# Processed 12638 (100.0%) in 0.21 sec. BPR loss is 1.42E+00. Sample per second: 60175
# SLIM_BPR_Recommender: Epoch 262 of 445. Elapsed time 18.42 sec
# Processed 12638 (100.0%) in 0.28 sec. BPR loss is 1.39E+00. Sample per second: 44891
# SLIM_BPR_Recommender: Epoch 263 of 445. Elapsed time 18.49 sec
# Processed 12638 (100.0%) in 0.35 sec. BPR loss is 1.45E+00. Sample per second: 36152
# SLIM_BPR_Recommender: Epoch 264 of 445. Elapsed time 18.56 sec
# Processed 12638 (100.0%) in 0.42 sec. BPR loss is 1.41E+00. Sample per second: 30396
# SLIM_BPR_Recommender: Epoch 265 of 445. Elapsed time 18.63 sec
# Processed 12638 (100.0%) in 0.48 sec. BPR loss is 1.44E+00. Sample per second: 26155
# SLIM_BPR_Recommender: Epoch 266 of 445. Elapsed time 18.69 sec
# Processed 12638 (100.0%) in 0.55 sec. BPR loss is 1.53E+00. Sample per second: 22924
# SLIM_BPR_Recommender: Epoch 267 of 445. Elapsed time 18.76 sec
# Processed 12638 (100.0%) in 0.62 sec. BPR loss is 1.47E+00. Sample per second: 20322
# SLIM_BPR_Recommender: Epoch 268 of 445. Elapsed time 18.83 sec
# Processed 12638 (100.0%) in 0.69 sec. BPR loss is 1.47E+00. Sample per second: 18247
# SLIM_BPR_Recommender: Epoch 269 of 445. Elapsed time 18.90 sec
# Processed 12638 (100.0%) in 0.76 sec. BPR loss is 1.48E+00. Sample per second: 16552
# SLIM_BPR_Recommender: Epoch 270 of 445. Elapsed time 18.97 sec
# Processed 12638 (100.0%) in 0.83 sec. BPR loss is 1.47E+00. Sample per second: 15165
# SLIM_BPR_Recommender: Epoch 271 of 445. Elapsed time 19.04 sec
# Processed 12638 (100.0%) in 0.90 sec. BPR loss is 1.46E+00. Sample per second: 13999
# SLIM_BPR_Recommender: Epoch 272 of 445. Elapsed time 19.11 sec
# Processed 12638 (100.0%) in 0.97 sec. BPR loss is 1.48E+00. Sample per second: 12998
# SLIM_BPR_Recommender: Epoch 273 of 445. Elapsed time 19.18 sec
# Processed 12638 (100.0%) in 1.04 sec. BPR loss is 1.41E+00. Sample per second: 12150
# SLIM_BPR_Recommender: Epoch 274 of 445. Elapsed time 19.25 sec
# Processed 12638 (100.0%) in 0.11 sec. BPR loss is 1.46E+00. Sample per second: 117515
# SLIM_BPR_Recommender: Epoch 275 of 445. Elapsed time 19.32 sec
# Processed 12638 (100.0%) in 0.18 sec. BPR loss is 1.38E+00. Sample per second: 71677
# SLIM_BPR_Recommender: Epoch 276 of 445. Elapsed time 19.39 sec
# Processed 12638 (100.0%) in 0.25 sec. BPR loss is 1.53E+00. Sample per second: 50465
# SLIM_BPR_Recommender: Epoch 277 of 445. Elapsed time 19.46 sec
# Processed 12638 (100.0%) in 0.33 sec. BPR loss is 1.49E+00. Sample per second: 38858
# SLIM_BPR_Recommender: Epoch 278 of 445. Elapsed time 19.54 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 1.45E+00. Sample per second: 32009
# SLIM_BPR_Recommender: Epoch 279 of 445. Elapsed time 19.61 sec
# Processed 12638 (100.0%) in 0.46 sec. BPR loss is 1.54E+00. Sample per second: 27169
# SLIM_BPR_Recommender: Epoch 280 of 445. Elapsed time 19.68 sec
# Processed 12638 (100.0%) in 0.53 sec. BPR loss is 1.51E+00. Sample per second: 23625
# SLIM_BPR_Recommender: Epoch 281 of 445. Elapsed time 19.75 sec
# Processed 12638 (100.0%) in 0.61 sec. BPR loss is 1.45E+00. Sample per second: 20747
# SLIM_BPR_Recommender: Epoch 282 of 445. Elapsed time 19.82 sec
# Processed 12638 (100.0%) in 0.69 sec. BPR loss is 1.50E+00. Sample per second: 18403
# SLIM_BPR_Recommender: Epoch 283 of 445. Elapsed time 19.90 sec
# Processed 12638 (100.0%) in 0.76 sec. BPR loss is 1.47E+00. Sample per second: 16548
# SLIM_BPR_Recommender: Epoch 284 of 445. Elapsed time 19.97 sec
# Processed 12638 (100.0%) in 0.84 sec. BPR loss is 1.46E+00. Sample per second: 15068
# SLIM_BPR_Recommender: Epoch 285 of 445. Elapsed time 20.05 sec
# Processed 12638 (100.0%) in 0.92 sec. BPR loss is 1.59E+00. Sample per second: 13766
# SLIM_BPR_Recommender: Epoch 286 of 445. Elapsed time 20.13 sec
# Processed 12638 (100.0%) in 0.99 sec. BPR loss is 1.52E+00. Sample per second: 12721
# SLIM_BPR_Recommender: Epoch 287 of 445. Elapsed time 20.20 sec
# Processed 12638 (100.0%) in 1.07 sec. BPR loss is 1.48E+00. Sample per second: 11798
# SLIM_BPR_Recommender: Epoch 288 of 445. Elapsed time 20.28 sec
# Processed 12638 (100.0%) in 0.15 sec. BPR loss is 1.55E+00. Sample per second: 85557
# SLIM_BPR_Recommender: Epoch 289 of 445. Elapsed time 20.36 sec
# Processed 12638 (100.0%) in 0.22 sec. BPR loss is 1.57E+00. Sample per second: 56525
# SLIM_BPR_Recommender: Epoch 290 of 445. Elapsed time 20.43 sec
# Processed 12638 (100.0%) in 0.30 sec. BPR loss is 1.50E+00. Sample per second: 42136
# SLIM_BPR_Recommender: Epoch 291 of 445. Elapsed time 20.51 sec
# Processed 12638 (100.0%) in 0.38 sec. BPR loss is 1.49E+00. Sample per second: 33496
# SLIM_BPR_Recommender: Epoch 292 of 445. Elapsed time 20.59 sec
# Processed 12638 (100.0%) in 0.45 sec. BPR loss is 1.54E+00. Sample per second: 27845
# SLIM_BPR_Recommender: Epoch 293 of 445. Elapsed time 20.66 sec
# Processed 12638 (100.0%) in 0.53 sec. BPR loss is 1.60E+00. Sample per second: 23900
# SLIM_BPR_Recommender: Epoch 294 of 445. Elapsed time 20.74 sec
# Processed 12638 (100.0%) in 0.60 sec. BPR loss is 1.55E+00. Sample per second: 21013
# SLIM_BPR_Recommender: Epoch 295 of 445. Elapsed time 20.81 sec
# Processed 12638 (100.0%) in 0.67 sec. BPR loss is 1.67E+00. Sample per second: 18872
# SLIM_BPR_Recommender: Epoch 296 of 445. Elapsed time 20.88 sec
# Processed 12638 (100.0%) in 0.74 sec. BPR loss is 1.55E+00. Sample per second: 17140
# SLIM_BPR_Recommender: Epoch 297 of 445. Elapsed time 20.95 sec
# Processed 12638 (100.0%) in 0.80 sec. BPR loss is 1.51E+00. Sample per second: 15713
# SLIM_BPR_Recommender: Epoch 298 of 445. Elapsed time 21.02 sec
# Processed 12638 (100.0%) in 0.87 sec. BPR loss is 1.48E+00. Sample per second: 14513
# SLIM_BPR_Recommender: Epoch 299 of 445. Elapsed time 21.08 sec
# Processed 12638 (100.0%) in 0.94 sec. BPR loss is 1.50E+00. Sample per second: 13472
# SLIM_BPR_Recommender: Epoch 300 of 445. Elapsed time 21.15 sec
# Processed 12638 (100.0%) in 1.00 sec. BPR loss is 1.56E+00. Sample per second: 12579
# SLIM_BPR_Recommender: Epoch 301 of 445. Elapsed time 21.22 sec
# Processed 12638 (100.0%) in 0.07 sec. BPR loss is 1.63E+00. Sample per second: 176759
# SLIM_BPR_Recommender: Epoch 302 of 445. Elapsed time 21.28 sec
# Processed 12638 (100.0%) in 0.14 sec. BPR loss is 1.53E+00. Sample per second: 91324
# SLIM_BPR_Recommender: Epoch 303 of 445. Elapsed time 21.35 sec
# Processed 12638 (100.0%) in 0.21 sec. BPR loss is 1.53E+00. Sample per second: 61135
# SLIM_BPR_Recommender: Epoch 304 of 445. Elapsed time 21.42 sec
# Processed 12638 (100.0%) in 0.28 sec. BPR loss is 1.60E+00. Sample per second: 45730
# SLIM_BPR_Recommender: Epoch 305 of 445. Elapsed time 21.49 sec
# Processed 12638 (100.0%) in 0.35 sec. BPR loss is 1.61E+00. Sample per second: 36365
# SLIM_BPR_Recommender: Epoch 306 of 445. Elapsed time 21.56 sec
# Processed 12638 (100.0%) in 0.42 sec. BPR loss is 1.53E+00. Sample per second: 30300
# SLIM_BPR_Recommender: Epoch 307 of 445. Elapsed time 21.63 sec
# Processed 12638 (100.0%) in 0.49 sec. BPR loss is 1.54E+00. Sample per second: 25890
# SLIM_BPR_Recommender: Epoch 308 of 445. Elapsed time 21.70 sec
# Processed 12638 (100.0%) in 0.57 sec. BPR loss is 1.59E+00. Sample per second: 21981
# SLIM_BPR_Recommender: Epoch 309 of 445. Elapsed time 21.79 sec
# Processed 12638 (100.0%) in 0.66 sec. BPR loss is 1.64E+00. Sample per second: 19123
# SLIM_BPR_Recommender: Epoch 310 of 445. Elapsed time 21.87 sec
# Processed 12638 (100.0%) in 0.74 sec. BPR loss is 1.67E+00. Sample per second: 17161
# SLIM_BPR_Recommender: Epoch 311 of 445. Elapsed time 21.95 sec
# Processed 12638 (100.0%) in 0.81 sec. BPR loss is 1.62E+00. Sample per second: 15653
# SLIM_BPR_Recommender: Epoch 312 of 445. Elapsed time 22.02 sec
# Processed 12638 (100.0%) in 0.89 sec. BPR loss is 1.61E+00. Sample per second: 14222
# SLIM_BPR_Recommender: Epoch 313 of 445. Elapsed time 22.10 sec
# Processed 12638 (100.0%) in 0.96 sec. BPR loss is 1.65E+00. Sample per second: 13162
# SLIM_BPR_Recommender: Epoch 314 of 445. Elapsed time 22.17 sec
# Processed 12638 (100.0%) in 1.04 sec. BPR loss is 1.65E+00. Sample per second: 12161
# SLIM_BPR_Recommender: Epoch 315 of 445. Elapsed time 22.25 sec
# Processed 12638 (100.0%) in 0.11 sec. BPR loss is 1.60E+00. Sample per second: 116951
# SLIM_BPR_Recommender: Epoch 316 of 445. Elapsed time 22.32 sec
# Processed 12638 (100.0%) in 0.18 sec. BPR loss is 1.65E+00. Sample per second: 71481
# SLIM_BPR_Recommender: Epoch 317 of 445. Elapsed time 22.39 sec
# Processed 12638 (100.0%) in 0.25 sec. BPR loss is 1.63E+00. Sample per second: 51325
# SLIM_BPR_Recommender: Epoch 318 of 445. Elapsed time 22.46 sec
# Processed 12638 (100.0%) in 0.32 sec. BPR loss is 1.58E+00. Sample per second: 40016
# SLIM_BPR_Recommender: Epoch 319 of 445. Elapsed time 22.53 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 1.68E+00. Sample per second: 32794
# SLIM_BPR_Recommender: Epoch 320 of 445. Elapsed time 22.60 sec
# Processed 12638 (100.0%) in 0.45 sec. BPR loss is 1.72E+00. Sample per second: 27784
# SLIM_BPR_Recommender: Epoch 321 of 445. Elapsed time 22.67 sec
# Processed 12638 (100.0%) in 0.52 sec. BPR loss is 1.63E+00. Sample per second: 24097
# SLIM_BPR_Recommender: Epoch 322 of 445. Elapsed time 22.74 sec
# Processed 12638 (100.0%) in 0.59 sec. BPR loss is 1.73E+00. Sample per second: 21292
# SLIM_BPR_Recommender: Epoch 323 of 445. Elapsed time 22.81 sec
# Processed 12638 (100.0%) in 0.67 sec. BPR loss is 1.63E+00. Sample per second: 18890
# SLIM_BPR_Recommender: Epoch 324 of 445. Elapsed time 22.88 sec
# Processed 12638 (100.0%) in 0.74 sec. BPR loss is 1.64E+00. Sample per second: 17030
# ...
# Processed 12638 (100.0%) in 0.71 sec. BPR loss is 1.72E+00. Sample per second: 17834
# SLIM_BPR_Recommender: Epoch 339 of 445. Elapsed time 23.92 sec
# Processed 12638 (100.0%) in 0.78 sec. BPR loss is 1.73E+00. Sample per second: 16260
# SLIM_BPR_Recommender: Epoch 340 of 445. Elapsed time 23.99 sec
# Processed 12638 (100.0%) in 0.85 sec. BPR loss is 1.70E+00. Sample per second: 14927
# SLIM_BPR_Recommender: Epoch 341 of 445. Elapsed time 24.06 sec
# Processed 12638 (100.0%) in 0.92 sec. BPR loss is 1.67E+00. Sample per second: 13731
# SLIM_BPR_Recommender: Epoch 342 of 445. Elapsed time 24.13 sec
# Processed 12638 (100.0%) in 1.00 sec. BPR loss is 1.63E+00. Sample per second: 12698
# SLIM_BPR_Recommender: Epoch 343 of 445. Elapsed time 24.21 sec
# Processed 12638 (100.0%) in 1.07 sec. BPR loss is 1.77E+00. Sample per second: 11782
# SLIM_BPR_Recommender: Epoch 344 of 445. Elapsed time 24.28 sec
# Processed 12638 (100.0%) in 0.15 sec. BPR loss is 1.72E+00. Sample per second: 85810
# SLIM_BPR_Recommender: Epoch 345 of 445. Elapsed time 24.36 sec
# Processed 12638 (100.0%) in 0.23 sec. BPR loss is 1.69E+00. Sample per second: 55899
# SLIM_BPR_Recommender: Epoch 346 of 445. Elapsed time 24.44 sec
# Processed 12638 (100.0%) in 0.31 sec. BPR loss is 1.69E+00. Sample per second: 41243
# SLIM_BPR_Recommender: Epoch 347 of 445. Elapsed time 24.52 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 1.67E+00. Sample per second: 32768
# SLIM_BPR_Recommender: Epoch 348 of 445. Elapsed time 24.60 sec
# Processed 12638 (100.0%) in 0.46 sec. BPR loss is 1.70E+00. Sample per second: 27266
# SLIM_BPR_Recommender: Epoch 349 of 445. Elapsed time 24.67 sec
# Processed 12638 (100.0%) in 0.54 sec. BPR loss is 1.67E+00. Sample per second: 23419
# SLIM_BPR_Recommender: Epoch 350 of 445. Elapsed time 24.75 sec
# Processed 12638 (100.0%) in 0.62 sec. BPR loss is 1.79E+00. Sample per second: 20513
# SLIM_BPR_Recommender: Epoch 351 of 445. Elapsed time 24.83 sec
# Processed 12638 (100.0%) in 0.69 sec. BPR loss is 1.65E+00. Sample per second: 18272
# SLIM_BPR_Recommender: Epoch 352 of 445. Elapsed time 24.90 sec
# Processed 12638 (100.0%) in 0.77 sec. BPR loss is 1.81E+00. Sample per second: 16446
# SLIM_BPR_Recommender: Epoch 353 of 445. Elapsed time 24.98 sec
# Processed 12638 (100.0%) in 0.84 sec. BPR loss is 1.78E+00. Sample per second: 14976
# SLIM_BPR_Recommender: Epoch 354 of 445. Elapsed time 25.05 sec
# Processed 12638 (100.0%) in 0.92 sec. BPR loss is 1.84E+00. Sample per second: 13762
# SLIM_BPR_Recommender: Epoch 355 of 445. Elapsed time 25.13 sec
# Processed 12638 (100.0%) in 0.99 sec. BPR loss is 1.79E+00. Sample per second: 12709
# SLIM_BPR_Recommender: Epoch 356 of 445. Elapsed time 25.21 sec
# Processed 12638 (100.0%) in 1.07 sec. BPR loss is 1.75E+00. Sample per second: 11811
# SLIM_BPR_Recommender: Epoch 357 of 445. Elapsed time 25.28 sec
# Processed 12638 (100.0%) in 0.15 sec. BPR loss is 1.82E+00. Sample per second: 86662
# SLIM_BPR_Recommender: Epoch 358 of 445. Elapsed time 25.36 sec
# Processed 12638 (100.0%) in 0.22 sec. BPR loss is 1.76E+00. Sample per second: 56535
# SLIM_BPR_Recommender: Epoch 359 of 445. Elapsed time 25.43 sec
# Processed 12638 (100.0%) in 0.30 sec. BPR loss is 1.70E+00. Sample per second: 42044
# SLIM_BPR_Recommender: Epoch 360 of 445. Elapsed time 25.51 sec
# Processed 12638 (100.0%) in 0.38 sec. BPR loss is 1.75E+00. Sample per second: 33496
# SLIM_BPR_Recommender: Epoch 361 of 445. Elapsed time 25.59 sec
# Processed 12638 (100.0%) in 0.45 sec. BPR loss is 1.76E+00. Sample per second: 27963
# SLIM_BPR_Recommender: Epoch 362 of 445. Elapsed time 25.66 sec
# Processed 12638 (100.0%) in 0.53 sec. BPR loss is 1.84E+00. Sample per second: 23964
# SLIM_BPR_Recommender: Epoch 363 of 445. Elapsed time 25.74 sec
# Processed 12638 (100.0%) in 0.61 sec. BPR loss is 1.76E+00. Sample per second: 20857
# SLIM_BPR_Recommender: Epoch 364 of 445. Elapsed time 25.82 sec
# Processed 12638 (100.0%) in 0.68 sec. BPR loss is 1.75E+00. Sample per second: 18574
# SLIM_BPR_Recommender: Epoch 365 of 445. Elapsed time 25.89 sec
# Processed 12638 (100.0%) in 0.76 sec. BPR loss is 1.80E+00. Sample per second: 16728
# SLIM_BPR_Recommender: Epoch 366 of 445. Elapsed time 25.97 sec
# Processed 12638 (100.0%) in 0.83 sec. BPR loss is 1.78E+00. Sample per second: 15238
# SLIM_BPR_Recommender: Epoch 367 of 445. Elapsed time 26.04 sec
# Processed 12638 (100.0%) in 0.90 sec. BPR loss is 1.79E+00. Sample per second: 14009
# SLIM_BPR_Recommender: Epoch 368 of 445. Elapsed time 26.11 sec
# Processed 12638 (100.0%) in 0.97 sec. BPR loss is 1.80E+00. Sample per second: 13046
# SLIM_BPR_Recommender: Epoch 369 of 445. Elapsed time 26.18 sec
# Processed 12638 (100.0%) in 1.04 sec. BPR loss is 1.78E+00. Sample per second: 12207
# SLIM_BPR_Recommender: Epoch 370 of 445. Elapsed time 26.25 sec
# Processed 12638 (100.0%) in 0.10 sec. BPR loss is 1.76E+00. Sample per second: 120377
# SLIM_BPR_Recommender: Epoch 371 of 445. Elapsed time 26.32 sec
# Processed 12638 (100.0%) in 0.17 sec. BPR loss is 1.81E+00. Sample per second: 72847
# SLIM_BPR_Recommender: Epoch 372 of 445. Elapsed time 26.39 sec
# Processed 12638 (100.0%) in 0.24 sec. BPR loss is 1.79E+00. Sample per second: 52282
# SLIM_BPR_Recommender: Epoch 373 of 445. Elapsed time 26.45 sec
# Processed 12638 (100.0%) in 0.31 sec. BPR loss is 1.88E+00. Sample per second: 40530
# SLIM_BPR_Recommender: Epoch 374 of 445. Elapsed time 26.52 sec
# Processed 12638 (100.0%) in 0.38 sec. BPR loss is 1.75E+00. Sample per second: 33363
# SLIM_BPR_Recommender: Epoch 375 of 445. Elapsed time 26.59 sec
# Processed 12638 (100.0%) in 0.45 sec. BPR loss is 1.83E+00. Sample per second: 28243
# SLIM_BPR_Recommender: Epoch 376 of 445. Elapsed time 26.66 sec
# Processed 12638 (100.0%) in 0.51 sec. BPR loss is 1.81E+00. Sample per second: 24617
# SLIM_BPR_Recommender: Epoch 377 of 445. Elapsed time 26.72 sec
# Processed 12638 (100.0%) in 0.58 sec. BPR loss is 1.70E+00. Sample per second: 21830
# SLIM_BPR_Recommender: Epoch 378 of 445. Elapsed time 26.79 sec
# Processed 12638 (100.0%) in 0.65 sec. BPR loss is 1.79E+00. Sample per second: 19574
# SLIM_BPR_Recommender: Epoch 379 of 445. Elapsed time 26.86 sec
# Processed 12638 (100.0%) in 0.71 sec. BPR loss is 1.78E+00. Sample per second: 17765
# SLIM_BPR_Recommender: Epoch 380 of 445. Elapsed time 26.92 sec
# Processed 12638 (100.0%) in 0.78 sec. BPR loss is 1.79E+00. Sample per second: 16241
# SLIM_BPR_Recommender: Epoch 381 of 445. Elapsed time 26.99 sec
# Processed 12638 (100.0%) in 0.84 sec. BPR loss is 1.79E+00. Sample per second: 14975
# SLIM_BPR_Recommender: Epoch 382 of 445. Elapsed time 27.05 sec
# Processed 12638 (100.0%) in 0.91 sec. BPR loss is 1.91E+00. Sample per second: 13857
# SLIM_BPR_Recommender: Epoch 383 of 445. Elapsed time 27.12 sec
# Processed 12638 (100.0%) in 0.98 sec. BPR loss is 1.84E+00. Sample per second: 12895
# SLIM_BPR_Recommender: Epoch 384 of 445. Elapsed time 27.19 sec
# Processed 12638 (100.0%) in 1.05 sec. BPR loss is 1.92E+00. Sample per second: 12093
# SLIM_BPR_Recommender: Epoch 385 of 445. Elapsed time 27.26 sec
# Processed 12638 (100.0%) in 0.11 sec. BPR loss is 1.78E+00. Sample per second: 115931
# SLIM_BPR_Recommender: Epoch 386 of 445. Elapsed time 27.32 sec
# Processed 12638 (100.0%) in 0.18 sec. BPR loss is 1.83E+00. Sample per second: 71289
# SLIM_BPR_Recommender: Epoch 387 of 445. Elapsed time 27.39 sec
# Processed 12638 (100.0%) in 0.25 sec. BPR loss is 1.91E+00. Sample per second: 51124
# SLIM_BPR_Recommender: Epoch 388 of 445. Elapsed time 27.46 sec
# Processed 12638 (100.0%) in 0.32 sec. BPR loss is 1.84E+00. Sample per second: 40039
# SLIM_BPR_Recommender: Epoch 389 of 445. Elapsed time 27.53 sec
# Processed 12638 (100.0%) in 0.39 sec. BPR loss is 1.89E+00. Sample per second: 32788
# SLIM_BPR_Recommender: Epoch 390 of 445. Elapsed time 27.60 sec
# Processed 12638 (100.0%) in 0.45 sec. BPR loss is 1.83E+00. Sample per second: 27963
# SLIM_BPR_Recommender: Epoch 391 of 445. Elapsed time 27.66 sec
# Processed 12638 (100.0%) in 0.52 sec. BPR loss is 1.88E+00. Sample per second: 24277
# SLIM_BPR_Recommender: Epoch 392 of 445. Elapsed time 27.73 sec
# Processed 12638 (100.0%) in 0.59 sec. BPR loss is 1.91E+00. Sample per second: 21460
# SLIM_BPR_Recommender: Epoch 393 of 445. Elapsed time 27.80 sec
# Processed 12638 (100.0%) in 0.66 sec. BPR loss is 1.85E+00. Sample per second: 19243
# SLIM_BPR_Recommender: Epoch 394 of 445. Elapsed time 27.87 sec
# Processed 12638 (100.0%) in 0.72 sec. BPR loss is 1.81E+00. Sample per second: 17441
# SLIM_BPR_Recommender: Epoch 395 of 445. Elapsed time 27.94 sec
# Processed 12638 (100.0%) in 0.79 sec. BPR loss is 1.81E+00. Sample per second: 15905
# SLIM_BPR_Recommender: Epoch 396 of 445. Elapsed time 28.01 sec
# Processed 12638 (100.0%) in 0.86 sec. BPR loss is 1.84E+00. Sample per second: 14625
# SLIM_BPR_Recommender: Epoch 397 of 445. Elapsed time 28.07 sec
# Processed 12638 (100.0%) in 0.93 sec. BPR loss is 1.92E+00. Sample per second: 13596
# SLIM_BPR_Recommender: Epoch 398 of 445. Elapsed time 28.14 sec
# Processed 12638 (100.0%) in 1.00 sec. BPR loss is 1.91E+00. Sample per second: 12696
# SLIM_BPR_Recommender: Epoch 399 of 445. Elapsed time 28.21 sec
# Processed 12638 (100.0%) in 1.06 sec. BPR loss is 1.86E+00. Sample per second: 11893
# SLIM_BPR_Recommender: Epoch 400 of 445. Elapsed time 28.27 sec
# Processed 12638 (100.0%) in 0.13 sec. BPR loss is 1.80E+00. Sample per second: 96833
# SLIM_BPR_Recommender: Epoch 401 of 445. Elapsed time 28.34 sec
# Processed 12638 (100.0%) in 0.20 sec. BPR loss is 1.85E+00. Sample per second: 63726
# SLIM_BPR_Recommender: Epoch 402 of 445. Elapsed time 28.41 sec
# Processed 12638 (100.0%) in 0.27 sec. BPR loss is 2.03E+00. Sample per second: 47309
# SLIM_BPR_Recommender: Epoch 403 of 445. Elapsed time 28.48 sec
# Processed 12638 (100.0%) in 0.34 sec. BPR loss is 1.85E+00. Sample per second: 37363
# SLIM_BPR_Recommender: Epoch 404 of 445. Elapsed time 28.55 sec
# Processed 12638 (100.0%) in 0.40 sec. BPR loss is 1.80E+00. Sample per second: 31246
# SLIM_BPR_Recommender: Epoch 405 of 445. Elapsed time 28.62 sec
# Processed 12638 (100.0%) in 0.47 sec. BPR loss is 1.96E+00. Sample per second: 26691
# SLIM_BPR_Recommender: Epoch 406 of 445. Elapsed time 28.68 sec
# Processed 12638 (100.0%) in 0.54 sec. BPR loss is 1.92E+00. Sample per second: 23463
# SLIM_BPR_Recommender: Epoch 407 of 445. Elapsed time 28.75 sec
# Processed 12638 (100.0%) in 0.61 sec. BPR loss is 1.94E+00. Sample per second: 20838
# SLIM_BPR_Recommender: Epoch 408 of 445. Elapsed time 28.82 sec
# Processed 12638 (100.0%) in 0.67 sec. BPR loss is 1.86E+00. Sample per second: 18764
# SLIM_BPR_Recommender: Epoch 409 of 445. Elapsed time 28.88 sec
# Processed 12638 (100.0%) in 0.74 sec. BPR loss is 1.86E+00. Sample per second: 17012
# SLIM_BPR_Recommender: Epoch 410 of 445. Elapsed time 28.95 sec
# Processed 12638 (100.0%) in 0.81 sec. BPR loss is 1.88E+00. Sample per second: 15575
# SLIM_BPR_Recommender: Epoch 411 of 445. Elapsed time 29.02 sec
# Processed 12638 (100.0%) in 0.88 sec. BPR loss is 1.96E+00. Sample per second: 14370
# SLIM_BPR_Recommender: Epoch 412 of 445. Elapsed time 29.09 sec
# Processed 12638 (100.0%) in 0.95 sec. BPR loss is 1.88E+00. Sample per second: 13324
# SLIM_BPR_Recommender: Epoch 413 of 445. Elapsed time 29.16 sec
# Processed 12638 (100.0%) in 1.02 sec. BPR loss is 1.90E+00. Sample per second: 12424
# SLIM_BPR_Recommender: Epoch 414 of 445. Elapsed time 29.23 sec
# Processed 12638 (100.0%) in 0.09 sec. BPR loss is 1.88E+00. Sample per second: 144501
# SLIM_BPR_Recommender: Epoch 415 of 445. Elapsed time 29.30 sec
# Processed 12638 (100.0%) in 0.15 sec. BPR loss is 1.98E+00. Sample per second: 81733
# SLIM_BPR_Recommender: Epoch 416 of 445. Elapsed time 29.37 sec
# Processed 12638 (100.0%) in 0.22 sec. BPR loss is 1.95E+00. Sample per second: 56434
# SLIM_BPR_Recommender: Epoch 417 of 445. Elapsed time 29.44 sec
# Processed 12638 (100.0%) in 0.30 sec. BPR loss is 1.85E+00. Sample per second: 42800
# SLIM_BPR_Recommender: Epoch 418 of 445. Elapsed time 29.51 sec
# Processed 12638 (100.0%) in 0.37 sec. BPR loss is 2.00E+00. Sample per second: 34268
# SLIM_BPR_Recommender: Epoch 419 of 445. Elapsed time 29.58 sec
# Processed 12638 (100.0%) in 0.44 sec. BPR loss is 1.95E+00. Sample per second: 28833
# SLIM_BPR_Recommender: Epoch 420 of 445. Elapsed time 29.65 sec
# Processed 12638 (100.0%) in 0.51 sec. BPR loss is 1.91E+00. Sample per second: 24974
# SLIM_BPR_Recommender: Epoch 421 of 445. Elapsed time 29.72 sec
# Processed 12638 (100.0%) in 0.57 sec. BPR loss is 1.97E+00. Sample per second: 22005
# SLIM_BPR_Recommender: Epoch 422 of 445. Elapsed time 29.79 sec
# Processed 12638 (100.0%) in 0.64 sec. BPR loss is 1.96E+00. Sample per second: 19601
# SLIM_BPR_Recommender: Epoch 423 of 445. Elapsed time 29.86 sec
# Processed 12638 (100.0%) in 0.71 sec. BPR loss is 2.00E+00. Sample per second: 17739
# SLIM_BPR_Recommender: Epoch 424 of 445. Elapsed time 29.92 sec
# Processed 12638 (100.0%) in 0.78 sec. BPR loss is 1.93E+00. Sample per second: 16182
# SLIM_BPR_Recommender: Epoch 425 of 445. Elapsed time 29.99 sec
# Processed 12638 (100.0%) in 0.85 sec. BPR loss is 1.96E+00. Sample per second: 14849
# SLIM_BPR_Recommender: Epoch 426 of 445. Elapsed time 30.06 sec
# Processed 12638 (100.0%) in 0.92 sec. BPR loss is 1.93E+00. Sample per second: 13740
# SLIM_BPR_Recommender: Epoch 427 of 445. Elapsed time 30.13 sec
# Processed 12638 (100.0%) in 0.99 sec. BPR loss is 1.88E+00. Sample per second: 12795
# SLIM_BPR_Recommender: Epoch 428 of 445. Elapsed time 30.20 sec
# Processed 12638 (100.0%) in 1.06 sec. BPR loss is 2.05E+00. Sample per second: 11932
# SLIM_BPR_Recommender: Epoch 429 of 445. Elapsed time 30.27 sec
# Processed 12638 (100.0%) in 0.13 sec. BPR loss is 1.90E+00. Sample per second: 95945
# SLIM_BPR_Recommender: Epoch 430 of 445. Elapsed time 30.34 sec
# Processed 12638 (100.0%) in 0.20 sec. BPR loss is 1.92E+00. Sample per second: 62469
# SLIM_BPR_Recommender: Epoch 431 of 445. Elapsed time 30.41 sec
# Processed 12638 (100.0%) in 0.27 sec. BPR loss is 1.94E+00. Sample per second: 46523
# SLIM_BPR_Recommender: Epoch 432 of 445. Elapsed time 30.48 sec
# Processed 12638 (100.0%) in 0.34 sec. BPR loss is 1.92E+00. Sample per second: 36900
# SLIM_BPR_Recommender: Epoch 433 of 445. Elapsed time 30.55 sec
# Processed 12638 (100.0%) in 0.41 sec. BPR loss is 1.93E+00. Sample per second: 30723
# SLIM_BPR_Recommender: Epoch 434 of 445. Elapsed time 30.62 sec
# Processed 12638 (100.0%) in 0.48 sec. BPR loss is 1.96E+00. Sample per second: 26415
# SLIM_BPR_Recommender: Epoch 435 of 445. Elapsed time 30.69 sec
# Processed 12638 (100.0%) in 0.55 sec. BPR loss is 1.91E+00. Sample per second: 23119
# SLIM_BPR_Recommender: Epoch 436 of 445. Elapsed time 30.76 sec
# Processed 12638 (100.0%) in 0.62 sec. BPR loss is 1.92E+00. Sample per second: 20434
# SLIM_BPR_Recommender: Epoch 437 of 445. Elapsed time 30.83 sec
# Processed 12638 (100.0%) in 0.69 sec. BPR loss is 2.01E+00. Sample per second: 18355
# SLIM_BPR_Recommender: Epoch 438 of 445. Elapsed time 30.90 sec
# Processed 12638 (100.0%) in 0.76 sec. BPR loss is 2.04E+00. Sample per second: 16667
# SLIM_BPR_Recommender: Epoch 439 of 445. Elapsed time 30.97 sec
# Processed 12638 (100.0%) in 0.83 sec. BPR loss is 2.01E+00. Sample per second: 15234
# SLIM_BPR_Recommender: Epoch 440 of 445. Elapsed time 31.04 sec
# Processed 12638 (100.0%) in 0.90 sec. BPR loss is 2.00E+00. Sample per second: 14055
# SLIM_BPR_Recommender: Epoch 441 of 445. Elapsed time 31.11 sec
# Processed 12638 (100.0%) in 0.97 sec. BPR loss is 2.06E+00. Sample per second: 13007
# SLIM_BPR_Recommender: Epoch 442 of 445. Elapsed time 31.18 sec
# Processed 12638 (100.0%) in 1.04 sec. BPR loss is 1.99E+00. Sample per second: 12121
# SLIM_BPR_Recommender: Epoch 443 of 445. Elapsed time 31.25 sec
# Processed 12638 (100.0%) in 0.11 sec. BPR loss is 1.96E+00. Sample per second: 112648
# SLIM_BPR_Recommender: Epoch 444 of 445. Elapsed time 31.32 sec
# Processed 12638 (100.0%) in 0.18 sec. BPR loss is 1.99E+00. Sample per second: 69855
# SLIM_BPR_Recommender: Epoch 445 of 445. Elapsed time 31.39 sec
# SLIM_BPR_Recommender: Terminating at epoch 445. Elapsed time 43.97 sec
# Deallocating Cython objects

# %%
P3a=P3alphaRecommender(URM_all)
P3a.fit(**best_pars_dict["P3alphaRecommender"])
# Out:
# P3alphaRecommender: Similarity column 22222 (100.0%), 3089.29 column/sec. Elapsed time 7.19 sec

# %%
IALSrec = IALSRecommender(URM_all)
IALSrec.fit(**best_pars_dict["IALSRecommender"])
# Out:
# IALSRecommender: Epoch 1 of 10. Elapsed time 1.53 min
# IALSRecommender: Epoch 2 of 10. Elapsed time 3.19 min
# IALSRecommender: Epoch 3 of 10. Elapsed time 4.84 min
# IALSRecommender: Epoch 4 of 10. Elapsed time 6.40 min
# IALSRecommender: Epoch 5 of 10. Elapsed time 7.96 min
# IALSRecommender: Epoch 6 of 10. Elapsed time 9.52 min
# IALSRecommender: Epoch 7 of 10. Elapsed time 11.12 min
# IALSRecommender: Epoch 8 of 10. Elapsed time 12.62 min
# IALSRecommender: Epoch 9 of 10. Elapsed time 14.39 min
# IALSRecommender: Epoch 10 of 10. Elapsed time 15.90 min
# IALSRecommender: Terminating at epoch 10. Elapsed time 15.90 min

# %%
new_similarityRecall = 0.3648920858420368 * SLIM_ElasticRecall.W_sparse + 0.30413965737024856 * RP3BetaRecall.W_sparse + 0.053940767085383985 * item_knnRecall.W_sparse + 0.27702748970233065 * P3aRecall.W_sparse
candidate_gen = ItemKNNCustomSimilarityRecommender(URM_all)
candidate_gen.fit(new_similarityRecall)

# %%
other_algorithms = {
    "TopPop": topPop,
    "RP3beta": RP3Beta,
    "SLIM": SLIM_Elastic,
    "KNN": item_knn,
    "EASER": ease_r,
    "best_hybrid": best_hybrid,
    "SLIMbpr":SLIM_bpr,
    "P3alpha":P3a,
    "IALS": IALSrec,
    "candidate_generator": candidate_gen
}
# Out:
# Deallocating Cython objects

# %%
final_dataframe=create_dataframe_without_label(URM_all,other_algorithms,249)
# Out:
# 100%|██████████| 12638/12638 [00:18<00:00, 700.38it/s]
# 100%|██████████| 12638/12638 [02:48<00:00, 75.00it/s]

# %%
final_dataframe["UserID"] = final_dataframe["UserID"].astype("category")
final_dataframe["ItemID"] = final_dataframe["ItemID"].astype("category")

# %%
def generate_submission_xgb(model,dataframe):
        
        hour = str(int(datetime.now().strftime("%H"))+1)

        current_datetime = datetime.now().strftime("%M:%S")
    
        output_file = f'submission_{hour + ":" + current_datetime}.csv'
    
    


        with open(output_file, 'w', newline='') as csvfile:
            writer = csv.writer(csvfile)

            # Write the header
            writer.writerow(['user_id', 'item_list'])
        
        
        
        
    
            # Generate and write recommendations for each user
            for user_id in tqdm(df_users["UserID"]):
                if user_id in original_id:
                    X_to_predict = dataframe[dataframe["UserID"] == user_original_ID_to_index[user_id]].copy()
                    preds = model.predict(X_to_predict)
                    X_to_predict["rank"] = preds
                    X_to_predict = X_to_predict.sort_values(by = "rank", ascending = False)
                    recommended_items = np.array(X_to_predict["ItemID"])[:10]
                    writer.writerow([user_id, ' '.join(map(str,[item_original_ID_to_index[item_original_ID_to_index== val].index[0] for val in recommended_items] ))])
                else:
                    writer.writerow([user_id, ' '.join(map(str,[item_original_ID_to_index[item_original_ID_to_index == val].index[0] for val in topPop.recommend(user_original_ID_to_index[3])[:10]] ))])
        
        return output_file

# %%
output_file = generate_submission_xgb(XGB_model,final_dataframe)
# Out:
# 100%|██████████| 10882/10882 [02:23<00:00, 75.72it/s]
